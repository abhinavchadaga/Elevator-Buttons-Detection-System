# %% [markdown]
# # Training Notebook
#
# Train Cascade Mask-RCNN
#
# Add a couple additional things:
# - Validation Loop using loss
# - Checkpoint based off of best validation metrics
# - Custom COCO Style Dataloaders

# %%
# Setup detectron2 logger
import detectron2
from detectron2.utils.logger import setup_logger

setup_logger()

# python libraries
import numpy as np
import os, json, random, math, time, datetime, logging
import torch, cv2
import matplotlib.pyplot as plt

# %matplotlib inline

# d2 libraries
from detectron2 import model_zoo
from detectron2.engine import DefaultTrainer, DefaultPredictor
from detectron2.evaluation import COCOEvaluator, inference_on_dataset
from detectron2.config import get_cfg
from detectron2.utils import comm
from detectron2.utils.logger import log_every_n_seconds
from detectron2.utils.visualizer import Visualizer, ColorMode
from detectron2.engine.hooks import EvalHook, BestCheckpointer
from detectron2.data import (
    MetadataCatalog,
    DatasetCatalog,
    build_detection_train_loader,
    build_detection_test_loader,
    get_detection_dataset_dicts,
    DatasetMapper,
)
import detectron2.data.transforms as T

# my stuff
from data_utils import read_split_file, random_split_mixed_set, register_dataset
import elevator_datasets

# %% [markdown]
# ### Randomly Split Data
#
# For reproducibility we seed the shuffler with the value 10

# %%
random_split_mixed_set(
    img_dir=elevator_datasets.MIXED_SRC,
    split_ratio=elevator_datasets.MIXED_SPLIT_RATIO,
    seed=10,
)
datasets = read_split_file(elevator_datasets.MIXED_SPLIT_FILE_PATH)

# %% [markdown]
# ### Register data splits with metadata

# %%
for name, im_paths in zip(["train", "val", "test"], datasets):
    DatasetCatalog.register(
        name=name, func=lambda im_paths=im_paths: register_dataset(im_paths=im_paths)
    )
    MetadataCatalog.get(name=name).thing_classes = ["label", "button"]
    MetadataCatalog.get(name=name).thing_colors = [(0, 255, 0), (0, 0, 255)]

# %%
trainset = DatasetCatalog.get("train")
print("trainset length: ", len(trainset))
# Out:
# trainset length:  70

# %% [markdown]
# ### View Training Data Samples
#
# Ensure that data is annotated correctly

# %%
for d in random.sample(trainset, 5):
    img = cv2.imread(d["file_name"])
    visualizer = Visualizer(
        img[:, :, ::-1],
        metadata=MetadataCatalog.get("train"),
        scale=1,
        instance_mode=ColorMode.SEGMENTATION,
    )
    out = visualizer.draw_dataset_dict(d)
    plt.imshow(out.get_image())
    plt.axis("off")
    plt.show()

# %% [markdown]
# ### Validation Loop using Validation Loss

# %%
def validation_loop(model: torch.nn, dataloader: torch.utils.data.DataLoader) -> dict:
    """
    Validate model on the given dataloader. Put model in training mode to output loss
    dict but do not backpropogate gradients. Largely adapted from train_loop.py and
    inference_on_dataset

    Args:
        model (torch.nn): model to validate
        dataloader (torch.utils.data.DataLoader): validation dataloader set to training
            mode

    Returns:
        dict: {"validation_loss": val_loss}
    """
    model.train()
    num_batches = len(dataloader)
    num_warmup = min(5, num_batches - 1)
    start_time = time.perf_counter()
    total_compute_time = 0
    losses = []
    for idx, data in enumerate(dataloader):
        if idx == num_warmup:
            start_time = time.perf_counter()
            total_compute_time = 0
        start_compute_time = time.perf_counter()
        if torch.cuda.is_available():
            torch.cuda.synchronize()
        total_compute_time += time.perf_counter() - start_compute_time
        iters_after_start = idx + 1 - num_warmup * int(idx >= num_warmup)
        seconds_per_img = total_compute_time / iters_after_start
        if idx >= num_warmup * 2 or seconds_per_img > 5:
            total_seconds_per_img = (
                time.perf_counter() - start_time
            ) / iters_after_start
            eta = datetime.timedelta(
                seconds=int(total_seconds_per_img) * (num_batches - idx - 1)
            )
            log_every_n_seconds(
                logging.INFO,
                "Loss on Validation  done {}/{}. {:.4f} s / img. ETA={}".format(
                    idx + 1, num_batches, seconds_per_img, str(eta)
                ),
                n=5,
            )

        batch_loss_dict = model(data)
        batch_loss_dict = {
            k: v.detach().cpu().item() if isinstance(v, torch.Tensor) else float(v)
            for k, v in batch_loss_dict.items()
        }
        total_batch_loss = sum(loss for loss in batch_loss_dict.values())
        losses.append(total_batch_loss)
    val_loss = np.mean(losses)
    comm.synchronize()
    log_every_n_seconds(logging.INFO, f"VALIDATION_LOSS: {val_loss:.5f}")
    return {"validation_loss": val_loss}

# %% [markdown]
# ### Define a Custom Trainer
#
# Add custom hooks and dataloader

# %%
class Trainer(DefaultTrainer):
    @classmethod
    def build_train_loader(cls, cfg):
        return build_detection_train_loader(
            dataset=get_detection_dataset_dicts(
                cfg.DATASETS.TRAIN[0], filter_empty=False
            ),
            mapper=DatasetMapper(
                is_train=True,
                augmentations=[
                    T.ResizeScale(
                        min_scale=0.1,
                        max_scale=2.0,
                        target_height=1024,
                        target_width=1024,
                    ),
                    T.FixedSizeCrop(crop_size=(1024, 1024), pad=False),
                ],
                image_format="RGB",
                use_instance_mask=True,
                recompute_boxes=True,
            ),
            total_batch_size=cfg.SOLVER.IMS_PER_BATCH,
            num_workers=cfg.DATALOADER.NUM_WORKERS,
        )

    @classmethod
    def build_validation_loader(cls, cfg):
        return build_detection_test_loader(
            dataset=get_detection_dataset_dicts(
                cfg.DATASETS.VAL[0], filter_empty=False
            ),
            mapper=DatasetMapper(
                is_train=True,
                augmentations=[
                    T.ResizeShortestEdge(short_edge_length=1024, max_size=1024)
                ],
                image_format="BGR",
                use_instance_mask=True,
            ),
        )

    def build_hooks(self) -> list:
        """
        Overwrite the evaluation loop and checkpoint using best validation loss

        Returns:
            list: list of hooks
        """
        hooks = super().build_hooks()
        # remove existing EvalHook
        if comm.is_main_process():
            del hooks[-2]
            del hooks[-2]
        else:
            del hooks[-1]
        hooks.extend(
            [
                EvalHook(
                    eval_period=self.cfg.TEST.EVAL_PERIOD,
                    eval_function=lambda: validation_loop(
                        self.model,
                        self.build_validation_loader(self.cfg),
                    ),
                    eval_after_train=True,
                ),
                BestCheckpointer(
                    eval_period=self.cfg.TEST.EVAL_PERIOD,
                    checkpointer=self.checkpointer,
                    val_metric="validation_loss",
                    mode="min",
                ),
            ]
        )
        return hooks

# %% [markdown]
# ### Define Config for Building Model

# %%
mask_rcnn_res50 = "COCO-InstanceSegmentation/mask_rcnn_R_50_FPN_3x.yaml"
mask_rcnn_res101 = "COCO-InstanceSegmentation/mask_rcnn_R_101_FPN_3x.yaml"
cascade_mask_rcnn_res50 = "Misc/cascade_mask_rcnn_R_50_FPN_3x.yaml"

base_cfg = mask_rcnn_res101

cfg = get_cfg()
cfg.merge_from_file(
    model_zoo.get_config_file(base_cfg)
)

# start from pretrained weights
cfg.MODEL.WEIGHTS = model_zoo.get_checkpoint_url(base_cfg)

# assign datasets and adjust ROI HEADS to match num classes
cfg.DATASETS.TRAIN = ("train",)
cfg.DATASETS.VAL = ("val",)
cfg.DATASETS.TEST = ("test",)
cfg.DATALOADER.FILTER_EMPTY_ANNOTATIONS = False
cfg.INPUT.RANDOM_FLIP = "none"
cfg.MODEL.ROI_HEADS.NUM_CLASSES = 2

# Calculate training logic
epochs = 100
batch_size = 2
eval_period = 2
iters_per_epoch = math.ceil(len(trainset) / batch_size)

cfg.SOLVER.IMS_PER_BATCH = batch_size
cfg.SOLVER.MAX_ITER = iters_per_epoch * epochs
cfg.TEST.EVAL_PERIOD = iters_per_epoch * eval_period
cfg.SOLVER.BASE_LR = 0.00025
cfg.SOLVER.STEPS = [int(0.7 * cfg.SOLVER.MAX_ITER), int(0.8 * cfg.SOLVER.MAX_ITER)]
cfg.SOLVER.WARMUP_ITERS = int(0.067 * cfg.SOLVER.MAX_ITER)

# SAVE DIR
cfg.OUTPUT_DIR = "./output"

# %% [markdown]
# ### Train Configured Model
#
# Use modified DefaultTrainer

# %%
os.makedirs(cfg.OUTPUT_DIR, exist_ok=True)
trainer = Trainer(cfg)
trainer.resume_or_load(resume=False)
trainer.train()
# Out:
# [02/20 14:50:46 d2.engine.defaults]: Model:
# GeneralizedRCNN(
#   (backbone): FPN(
#     (fpn_lateral2): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral3): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral4): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output4): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral5): Conv2d(2048, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output5): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (top_block): LastLevelMaxPool()
#     (bottom_up): ResNet(
#       (stem): BasicStem(
#         (conv1): Conv2d(
#           3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False
#           (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#         )
#       )
#       (res2): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#         )
#       )
#       (res3): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             256, 128, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#         (3): BottleneckBlock(
#           (conv1): Conv2d(
#             512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#       )
#       (res4): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             512, 256, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (3): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (4): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (5): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (6): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (7): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (8): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (9): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (10): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (11): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (12): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (13): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (14): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (15): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (16): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (17): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (18): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (19): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (20): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (21): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (22): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#       )
#       (res5): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             1024, 512, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#         )
#       )
#     )
#   )
#   (proposal_generator): RPN(
#     (rpn_head): StandardRPNHead(
#       (conv): Conv2d(
#         256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)
#         (activation): ReLU()
#       )
#       (objectness_logits): Conv2d(256, 3, kernel_size=(1, 1), stride=(1, 1))
#       (anchor_deltas): Conv2d(256, 12, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (anchor_generator): DefaultAnchorGenerator(
#       (cell_anchors): BufferList()
#     )
#   )
#   (roi_heads): StandardROIHeads(
#     (box_pooler): ROIPooler(
#       (level_poolers): ModuleList(
#         (0): ROIAlign(output_size=(7, 7), spatial_scale=0.25, sampling_ratio=0, aligned=True)
#         (1): ROIAlign(output_size=(7, 7), spatial_scale=0.125, sampling_ratio=0, aligned=True)
#         (2): ROIAlign(output_size=(7, 7), spatial_scale=0.0625, sampling_ratio=0, aligned=True)
#         (3): ROIAlign(output_size=(7, 7), spatial_scale=0.03125, sampling_ratio=0, aligned=True)
#       )
#     )
#     (box_head): FastRCNNConvFCHead(
#       (flatten): Flatten(start_dim=1, end_dim=-1)
#       (fc1): Linear(in_features=12544, out_features=1024, bias=True)
#       (fc_relu1): ReLU()
#       (fc2): Linear(in_features=1024, out_features=1024, bias=True)
#       (fc_relu2): ReLU()
#     )
#     (box_predictor): FastRCNNOutputLayers(
#       (cls_score): Linear(in_features=1024, out_features=3, bias=True)
#       (bbox_pred): Linear(in_features=1024, out_features=8, bias=True)
#     )
#     (mask_pooler): ROIPooler(
#       (level_poolers): ModuleList(
#         (0): ROIAlign(output_size=(14, 14), spatial_scale=0.25, sampling_ratio=0, aligned=True)
#         (1): ROIAlign(output_size=(14, 14), spatial_scale=0.125, sampling_ratio=0, aligned=True)
#         (2): ROIAlign(output_size=(14, 14), spatial_scale=0.0625, sampling_ratio=0, aligned=True)
#         (3): ROIAlign(output_size=(14, 14), spatial_scale=0.03125, sampling_ratio=0, aligned=True)
#       )
#     )
#     (mask_head): MaskRCNNConvUpsampleHead(
#       (mask_fcn1): Conv2d(
#         256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)
#         (activation): ReLU()
#       )
#       (mask_fcn2): Conv2d(
#         256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)
#         (activation): ReLU()
#       )
#       (mask_fcn3): Conv2d(
#         256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)
#         (activation): ReLU()
#       )
#       (mask_fcn4): Conv2d(
#         256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)
#         (activation): ReLU()
#       )
#       (deconv): ConvTranspose2d(256, 256, kernel_size=(2, 2), stride=(2, 2))
#       (deconv_relu): ReLU()
#       (predictor): Conv2d(256, 2, kernel_size=(1, 1), stride=(1, 1))
#     )
#   )
# )
# [02/20 14:50:48 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in training: [ResizeScale(min_scale=0.1, max_scale=2.0, target_height=1024, target_width=1024), FixedSizeCrop(crop_size=(1024, 1024), pad=False)]
# [02/20 14:50:48 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [02/20 14:50:48 d2.data.common]: Serializing 70 elements to byte tensors and concatenating them all ...
# [02/20 14:50:49 d2.data.common]: Serialized dataset takes 12.61 MiB
# [02/20 14:50:49 d2.checkpoint.detection_checkpoint]: [DetectionCheckpointer] Loading from https://dl.fbaipublicfiles.com/detectron2/COCO-InstanceSegmentation/mask_rcnn_R_101_FPN_3x/138205316/model_final_a3ec72.pkl ...
# Skip loading parameter 'roi_heads.box_predictor.cls_score.weight' to the model due to incompatible shapes: (81, 1024) in the checkpoint but (3, 1024) in the model! You might want to double check if this is expected.
# Skip loading parameter 'roi_heads.box_predictor.cls_score.bias' to the model due to incompatible shapes: (81,) in the checkpoint but (3,) in the model! You might want to double check if this is expected.
# Skip loading parameter 'roi_heads.box_predictor.bbox_pred.weight' to the model due to incompatible shapes: (320, 1024) in the checkpoint but (8, 1024) in the model! You might want to double check if this is expected.
# Skip loading parameter 'roi_heads.box_predictor.bbox_pred.bias' to the model due to incompatible shapes: (320,) in the checkpoint but (8,) in the model! You might want to double check if this is expected.
# Skip loading parameter 'roi_heads.mask_head.predictor.weight' to the model due to incompatible shapes: (80, 256, 1, 1) in the checkpoint but (2, 256, 1, 1) in the model! You might want to double check if this is expected.
# Skip loading parameter 'roi_heads.mask_head.predictor.bias' to the model due to incompatible shapes: (80,) in the checkpoint but (2,) in the model! You might want to double check if this is expected.
# Some model parameters or buffers are not found in the checkpoint:
# roi_heads.box_predictor.bbox_pred.{bias, weight}
# roi_heads.box_predictor.cls_score.{bias, weight}
# roi_heads.mask_head.predictor.{bias, weight}
# [02/20 14:50:49 d2.engine.train_loop]: Starting training from iteration 0
# /home/abhinavchadaga/miniforge3/envs/d2/lib/python3.8/site-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at /opt/conda/conda-bld/pytorch_1670525541702/work/aten/src/ATen/native/TensorShape.cpp:3190.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# [02/20 14:50:54 d2.utils.events]:  eta: 0:13:24  iter: 19  total_loss: 3.143  loss_cls: 0.9634  loss_box_reg: 0.7486  loss_mask: 0.6846  loss_rpn_cls: 0.5472  loss_rpn_loc: 0.103  time: 0.2089  last_time: 0.1088  data_time: 0.0228  last_data_time: 0.0005   lr: 2.0529e-05  max_mem: 3818M
# [02/20 14:50:58 d2.utils.events]:  eta: 0:12:59  iter: 39  total_loss: 2.443  loss_cls: 0.7592  loss_box_reg: 0.7301  loss_mask: 0.6457  loss_rpn_cls: 0.09114  loss_rpn_loc: 0.0714  time: 0.2080  last_time: 0.2247  data_time: 0.0053  last_data_time: 0.0017   lr: 4.1875e-05  max_mem: 3818M
# [02/20 14:51:02 d2.utils.events]:  eta: 0:12:38  iter: 59  total_loss: 2.172  loss_cls: 0.6555  loss_box_reg: 0.7692  loss_mask: 0.5686  loss_rpn_cls: 0.03929  loss_rpn_loc: 0.105  time: 0.2044  last_time: 0.2054  data_time: 0.0038  last_data_time: 0.0316   lr: 6.3221e-05  max_mem: 3818M
# [02/20 14:51:05 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in training: [ResizeShortestEdge(short_edge_length=(1024, 1024), max_size=1024)]
# [02/20 14:51:05 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [02/20 14:51:05 d2.data.common]: Serializing 10 elements to byte tensors and concatenating them all ...
# [02/20 14:51:05 d2.data.common]: Serialized dataset takes 2.69 MiB
# [02/20 14:51:07 detectron2]: VALIDATION_LOSS: 1.92597
# [02/20 14:51:07 d2.engine.hooks]: Saved first model at 1.92597 @ 69 steps
# [02/20 14:51:09 d2.utils.events]:  eta: 0:12:50  iter: 79  total_loss: 1.884  loss_cls: 0.5714  loss_box_reg: 0.7264  loss_mask: 0.4847  loss_rpn_cls: 0.02776  loss_rpn_loc: 0.06929  validation_loss: 1.926  time: 0.2078  last_time: 0.2247  data_time: 0.0035  last_data_time: 0.0017   lr: 8.4567e-05  max_mem: 3818M
# [02/20 14:51:14 d2.utils.events]:  eta: 0:12:51  iter: 99  total_loss: 1.827  loss_cls: 0.5541  loss_box_reg: 0.7647  loss_mask: 0.3956  loss_rpn_cls: 0.02368  loss_rpn_loc: 0.08039  validation_loss: 1.926  time: 0.2084  last_time: 0.2404  data_time: 0.0096  last_data_time: 0.0003   lr: 0.00010591  max_mem: 3818M
# [02/20 14:51:18 d2.utils.events]:  eta: 0:12:43  iter: 119  total_loss: 1.698  loss_cls: 0.4904  loss_box_reg: 0.6748  loss_mask: 0.3618  loss_rpn_cls: 0.03886  loss_rpn_loc: 0.09271  validation_loss: 1.926  time: 0.2069  last_time: 0.2401  data_time: 0.0037  last_data_time: 0.0006   lr: 0.00012726  max_mem: 3818M
# [02/20 14:51:22 d2.utils.events]:  eta: 0:12:39  iter: 139  total_loss: 1.58  loss_cls: 0.4274  loss_box_reg: 0.6752  loss_mask: 0.273  loss_rpn_cls: 0.05412  loss_rpn_loc: 0.09347  validation_loss: 1.926  time: 0.2064  last_time: 0.2354  data_time: 0.0092  last_data_time: 0.0020   lr: 0.00014861  max_mem: 3818M
# [02/20 14:51:22 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in training: [ResizeShortestEdge(short_edge_length=(1024, 1024), max_size=1024)]
# [02/20 14:51:22 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [02/20 14:51:22 d2.data.common]: Serializing 10 elements to byte tensors and concatenating them all ...
# [02/20 14:51:22 d2.data.common]: Serialized dataset takes 2.69 MiB
# [02/20 14:51:24 detectron2]: VALIDATION_LOSS: 1.43560
# [02/20 14:51:25 d2.engine.hooks]: Saved best model as latest eval score for validation_loss is 1.43560, better than last best score 1.92597 @ iteration 69.
# [02/20 14:51:29 d2.utils.events]:  eta: 0:12:31  iter: 159  total_loss: 1.357  loss_cls: 0.3833  loss_box_reg: 0.625  loss_mask: 0.2523  loss_rpn_cls: 0.02421  loss_rpn_loc: 0.07544  validation_loss: 1.436  time: 0.2067  last_time: 0.2220  data_time: 0.0027  last_data_time: 0.0020   lr: 0.00016995  max_mem: 3818M
# [02/20 14:51:33 d2.utils.events]:  eta: 0:12:26  iter: 179  total_loss: 1.286  loss_cls: 0.3263  loss_box_reg: 0.5962  loss_mask: 0.2127  loss_rpn_cls: 0.01888  loss_rpn_loc: 0.06913  validation_loss: 1.436  time: 0.2070  last_time: 0.2390  data_time: 0.0034  last_data_time: 0.0004   lr: 0.0001913  max_mem: 3818M
# [02/20 14:51:38 d2.utils.events]:  eta: 0:12:28  iter: 199  total_loss: 1.079  loss_cls: 0.3039  loss_box_reg: 0.5031  loss_mask: 0.1881  loss_rpn_cls: 0.01587  loss_rpn_loc: 0.06737  validation_loss: 1.436  time: 0.2090  last_time: 0.2303  data_time: 0.0101  last_data_time: 0.0013   lr: 0.00021264  max_mem: 3818M
# [02/20 14:51:40 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in training: [ResizeShortestEdge(short_edge_length=(1024, 1024), max_size=1024)]
# [02/20 14:51:40 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [02/20 14:51:40 d2.data.common]: Serializing 10 elements to byte tensors and concatenating them all ...
# [02/20 14:51:40 d2.data.common]: Serialized dataset takes 2.69 MiB
# [02/20 14:51:42 detectron2]: VALIDATION_LOSS: 0.91958
# [02/20 14:51:43 d2.engine.hooks]: Saved best model as latest eval score for validation_loss is 0.91958, better than last best score 1.43560 @ iteration 139.
# [02/20 14:51:45 d2.utils.events]:  eta: 0:12:24  iter: 219  total_loss: 0.9746  loss_cls: 0.2409  loss_box_reg: 0.3664  loss_mask: 0.1646  loss_rpn_cls: 0.01554  loss_rpn_loc: 0.06086  validation_loss: 0.9196  time: 0.2101  last_time: 0.1884  data_time: 0.0033  last_data_time: 0.0030   lr: 0.00023399  max_mem: 3818M
# [02/20 14:51:49 d2.utils.events]:  eta: 0:12:20  iter: 239  total_loss: 0.7636  loss_cls: 0.2128  loss_box_reg: 0.2631  loss_mask: 0.1587  loss_rpn_cls: 0.01126  loss_rpn_loc: 0.0745  validation_loss: 0.9196  time: 0.2105  last_time: 0.2415  data_time: 0.0033  last_data_time: 0.0014   lr: 0.00025  max_mem: 3818M
# [02/20 14:51:53 d2.utils.events]:  eta: 0:12:17  iter: 259  total_loss: 0.7566  loss_cls: 0.2355  loss_box_reg: 0.266  loss_mask: 0.1594  loss_rpn_cls: 0.01869  loss_rpn_loc: 0.08084  validation_loss: 0.9196  time: 0.2110  last_time: 0.2360  data_time: 0.0027  last_data_time: 0.0030   lr: 0.00025  max_mem: 3818M
# [02/20 14:51:58 d2.utils.events]:  eta: 0:12:15  iter: 279  total_loss: 0.7013  loss_cls: 0.1908  loss_box_reg: 0.2409  loss_mask: 0.1575  loss_rpn_cls: 0.02057  loss_rpn_loc: 0.07015  validation_loss: 0.9196  time: 0.2118  last_time: 0.2220  data_time: 0.0040  last_data_time: 0.0011   lr: 0.00025  max_mem: 3818M
# [02/20 14:51:58 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in training: [ResizeShortestEdge(short_edge_length=(1024, 1024), max_size=1024)]
# [02/20 14:51:58 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [02/20 14:51:58 d2.data.common]: Serializing 10 elements to byte tensors and concatenating them all ...
# [02/20 14:51:58 d2.data.common]: Serialized dataset takes 2.69 MiB
# [02/20 14:52:00 detectron2]: VALIDATION_LOSS: 0.73605
# [02/20 14:52:01 d2.engine.hooks]: Saved best model as latest eval score for validation_loss is 0.73605, better than last best score 0.91958 @ iteration 209.
# [02/20 14:52:05 d2.utils.events]:  eta: 0:12:07  iter: 299  total_loss: 0.5821  loss_cls: 0.1562  loss_box_reg: 0.1984  loss_mask: 0.1387  loss_rpn_cls: 0.01098  loss_rpn_loc: 0.05756  validation_loss: 0.736  time: 0.2114  last_time: 0.1528  data_time: 0.0027  last_data_time: 0.0006   lr: 0.00025  max_mem: 3818M
# [02/20 14:52:09 d2.utils.events]:  eta: 0:12:02  iter: 319  total_loss: 0.6494  loss_cls: 0.1928  loss_box_reg: 0.2164  loss_mask: 0.1472  loss_rpn_cls: 0.01558  loss_rpn_loc: 0.07589  validation_loss: 0.736  time: 0.2108  last_time: 0.2427  data_time: 0.0033  last_data_time: 0.0031   lr: 0.00025  max_mem: 3818M
# [02/20 14:52:13 d2.utils.events]:  eta: 0:11:57  iter: 339  total_loss: 0.6452  loss_cls: 0.1662  loss_box_reg: 0.1961  loss_mask: 0.1553  loss_rpn_cls: 0.0179  loss_rpn_loc: 0.05864  validation_loss: 0.736  time: 0.2110  last_time: 0.2353  data_time: 0.0026  last_data_time: 0.0031   lr: 0.00025  max_mem: 3818M
# [02/20 14:52:16 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in training: [ResizeShortestEdge(short_edge_length=(1024, 1024), max_size=1024)]
# [02/20 14:52:16 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [02/20 14:52:16 d2.data.common]: Serializing 10 elements to byte tensors and concatenating them all ...
# [02/20 14:52:16 d2.data.common]: Serialized dataset takes 2.69 MiB
# [02/20 14:52:17 detectron2]: VALIDATION_LOSS: 0.71090
# [02/20 14:52:18 d2.engine.hooks]: Saved best model as latest eval score for validation_loss is 0.71090, better than last best score 0.73605 @ iteration 279.
# [02/20 14:52:20 d2.utils.events]:  eta: 0:11:54  iter: 359  total_loss: 0.5918  loss_cls: 0.1393  loss_box_reg: 0.1894  loss_mask: 0.1612  loss_rpn_cls: 0.01114  loss_rpn_loc: 0.07031  validation_loss: 0.7109  time: 0.2115  last_time: 0.2319  data_time: 0.0058  last_data_time: 0.0028   lr: 0.00025  max_mem: 3818M
# [02/20 14:52:24 d2.utils.events]:  eta: 0:11:51  iter: 379  total_loss: 0.6756  loss_cls: 0.1834  loss_box_reg: 0.2464  loss_mask: 0.1401  loss_rpn_cls: 0.01687  loss_rpn_loc: 0.07346  validation_loss: 0.7109  time: 0.2114  last_time: 0.2438  data_time: 0.0042  last_data_time: 0.0045   lr: 0.00025  max_mem: 3818M
# [02/20 14:52:28 d2.utils.events]:  eta: 0:11:44  iter: 399  total_loss: 0.5488  loss_cls: 0.1752  loss_box_reg: 0.176  loss_mask: 0.1332  loss_rpn_cls: 0.01266  loss_rpn_loc: 0.0522  validation_loss: 0.7109  time: 0.2108  last_time: 0.1960  data_time: 0.0029  last_data_time: 0.0038   lr: 0.00025  max_mem: 3818M
# [02/20 14:52:33 d2.utils.events]:  eta: 0:11:39  iter: 419  total_loss: 0.6025  loss_cls: 0.1531  loss_box_reg: 0.1972  loss_mask: 0.1427  loss_rpn_cls: 0.01449  loss_rpn_loc: 0.08056  validation_loss: 0.7109  time: 0.2108  last_time: 0.2409  data_time: 0.0051  last_data_time: 0.0079   lr: 0.00025  max_mem: 3818M
# [02/20 14:52:33 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in training: [ResizeShortestEdge(short_edge_length=(1024, 1024), max_size=1024)]
# [02/20 14:52:33 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [02/20 14:52:33 d2.data.common]: Serializing 10 elements to byte tensors and concatenating them all ...
# [02/20 14:52:33 d2.data.common]: Serialized dataset takes 2.69 MiB
# [02/20 14:52:35 detectron2]: VALIDATION_LOSS: 0.66370
# [02/20 14:52:35 d2.engine.hooks]: Saved best model as latest eval score for validation_loss is 0.66370, better than last best score 0.71090 @ iteration 349.
# [02/20 14:52:39 d2.utils.events]:  eta: 0:11:35  iter: 439  total_loss: 0.7274  loss_cls: 0.1655  loss_box_reg: 0.2473  loss_mask: 0.187  loss_rpn_cls: 0.01434  loss_rpn_loc: 0.09392  validation_loss: 0.6637  time: 0.2100  last_time: 0.2211  data_time: 0.0040  last_data_time: 0.0025   lr: 0.00025  max_mem: 3818M
# [02/20 14:52:44 d2.utils.events]:  eta: 0:11:30  iter: 459  total_loss: 0.5309  loss_cls: 0.1557  loss_box_reg: 0.1938  loss_mask: 0.136  loss_rpn_cls: 0.00486  loss_rpn_loc: 0.04526  validation_loss: 0.6637  time: 0.2102  last_time: 0.1730  data_time: 0.0031  last_data_time: 0.0004   lr: 0.00025  max_mem: 3818M
# [02/20 14:52:48 d2.utils.events]:  eta: 0:11:26  iter: 479  total_loss: 0.5955  loss_cls: 0.1336  loss_box_reg: 0.1972  loss_mask: 0.145  loss_rpn_cls: 0.008301  loss_rpn_loc: 0.06806  validation_loss: 0.6637  time: 0.2111  last_time: 0.2222  data_time: 0.0093  last_data_time: 0.0016   lr: 0.00025  max_mem: 3818M
# [02/20 14:52:51 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in training: [ResizeShortestEdge(short_edge_length=(1024, 1024), max_size=1024)]
# [02/20 14:52:51 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [02/20 14:52:51 d2.data.common]: Serializing 10 elements to byte tensors and concatenating them all ...
# [02/20 14:52:51 d2.data.common]: Serialized dataset takes 2.69 MiB
# [02/20 14:52:53 detectron2]: VALIDATION_LOSS: 0.65459
# [02/20 14:52:53 d2.engine.hooks]: Saved best model as latest eval score for validation_loss is 0.65459, better than last best score 0.66370 @ iteration 419.
# [02/20 14:52:55 d2.utils.events]:  eta: 0:11:23  iter: 499  total_loss: 0.4917  loss_cls: 0.1357  loss_box_reg: 0.1763  loss_mask: 0.1224  loss_rpn_cls: 0.007607  loss_rpn_loc: 0.05241  validation_loss: 0.6546  time: 0.2116  last_time: 0.2504  data_time: 0.0032  last_data_time: 0.0150   lr: 0.00025  max_mem: 3818M
# [02/20 14:52:59 d2.utils.events]:  eta: 0:11:18  iter: 519  total_loss: 0.5102  loss_cls: 0.137  loss_box_reg: 0.1923  loss_mask: 0.116  loss_rpn_cls: 0.01314  loss_rpn_loc: 0.06688  validation_loss: 0.6546  time: 0.2113  last_time: 0.2243  data_time: 0.0031  last_data_time: 0.0019   lr: 0.00025  max_mem: 3818M
# [02/20 14:53:03 d2.utils.events]:  eta: 0:11:13  iter: 539  total_loss: 0.4921  loss_cls: 0.1121  loss_box_reg: 0.1917  loss_mask: 0.1314  loss_rpn_cls: 0.0109  loss_rpn_loc: 0.05628  validation_loss: 0.6546  time: 0.2108  last_time: 0.2383  data_time: 0.0022  last_data_time: 0.0018   lr: 0.00025  max_mem: 3818M
# [02/20 14:53:08 d2.utils.events]:  eta: 0:11:10  iter: 559  total_loss: 0.5238  loss_cls: 0.1217  loss_box_reg: 0.1899  loss_mask: 0.149  loss_rpn_cls: 0.01098  loss_rpn_loc: 0.04785  validation_loss: 0.6546  time: 0.2110  last_time: 0.2342  data_time: 0.0100  last_data_time: 0.0024   lr: 0.00025  max_mem: 3818M
# [02/20 14:53:08 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in training: [ResizeShortestEdge(short_edge_length=(1024, 1024), max_size=1024)]
# [02/20 14:53:08 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [02/20 14:53:08 d2.data.common]: Serializing 10 elements to byte tensors and concatenating them all ...
# [02/20 14:53:08 d2.data.common]: Serialized dataset takes 2.69 MiB
# [02/20 14:53:10 detectron2]: VALIDATION_LOSS: 0.60576
# [02/20 14:53:11 d2.engine.hooks]: Saved best model as latest eval score for validation_loss is 0.60576, better than last best score 0.65459 @ iteration 489.
# [02/20 14:53:15 d2.utils.events]:  eta: 0:11:03  iter: 579  total_loss: 0.5403  loss_cls: 0.1071  loss_box_reg: 0.1948  loss_mask: 0.134  loss_rpn_cls: 0.01125  loss_rpn_loc: 0.07089  validation_loss: 0.6058  time: 0.2110  last_time: 0.1311  data_time: 0.0024  last_data_time: 0.0029   lr: 0.00025  max_mem: 3818M
# [02/20 14:53:19 d2.utils.events]:  eta: 0:10:59  iter: 599  total_loss: 0.4974  loss_cls: 0.1092  loss_box_reg: 0.1766  loss_mask: 0.1379  loss_rpn_cls: 0.01918  loss_rpn_loc: 0.07184  validation_loss: 0.6058  time: 0.2106  last_time: 0.2427  data_time: 0.0027  last_data_time: 0.0028   lr: 0.00025  max_mem: 3818M
# [02/20 14:53:23 d2.utils.events]:  eta: 0:10:54  iter: 619  total_loss: 0.5225  loss_cls: 0.1211  loss_box_reg: 0.1858  loss_mask: 0.1333  loss_rpn_cls: 0.01516  loss_rpn_loc: 0.05959  validation_loss: 0.6058  time: 0.2104  last_time: 0.1624  data_time: 0.0061  last_data_time: 0.0006   lr: 0.00025  max_mem: 3818M
# [02/20 14:53:25 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in training: [ResizeShortestEdge(short_edge_length=(1024, 1024), max_size=1024)]
# [02/20 14:53:25 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [02/20 14:53:25 d2.data.common]: Serializing 10 elements to byte tensors and concatenating them all ...
# [02/20 14:53:26 d2.data.common]: Serialized dataset takes 2.69 MiB
# [02/20 14:53:27 detectron2]: VALIDATION_LOSS: 0.58966
# [02/20 14:53:28 d2.engine.hooks]: Saved best model as latest eval score for validation_loss is 0.58966, better than last best score 0.60576 @ iteration 559.
# [02/20 14:53:30 d2.utils.events]:  eta: 0:10:50  iter: 639  total_loss: 0.4417  loss_cls: 0.08804  loss_box_reg: 0.1625  loss_mask: 0.1118  loss_rpn_cls: 0.005031  loss_rpn_loc: 0.04714  validation_loss: 0.5897  time: 0.2106  last_time: 0.2373  data_time: 0.0100  last_data_time: 0.0005   lr: 0.00025  max_mem: 3818M
# [02/20 14:53:34 d2.utils.events]:  eta: 0:10:46  iter: 659  total_loss: 0.5374  loss_cls: 0.1095  loss_box_reg: 0.2117  loss_mask: 0.138  loss_rpn_cls: 0.01155  loss_rpn_loc: 0.07897  validation_loss: 0.5897  time: 0.2103  last_time: 0.2203  data_time: 0.0027  last_data_time: 0.0018   lr: 0.00025  max_mem: 3818M
# [02/20 14:53:38 d2.utils.events]:  eta: 0:10:42  iter: 679  total_loss: 0.4339  loss_cls: 0.09648  loss_box_reg: 0.17  loss_mask: 0.1069  loss_rpn_cls: 0.008265  loss_rpn_loc: 0.05571  validation_loss: 0.5897  time: 0.2107  last_time: 0.2386  data_time: 0.0031  last_data_time: 0.0042   lr: 0.00025  max_mem: 3818M
# [02/20 14:53:43 d2.utils.events]:  eta: 0:10:38  iter: 699  total_loss: 0.4666  loss_cls: 0.1155  loss_box_reg: 0.1594  loss_mask: 0.1146  loss_rpn_cls: 0.004216  loss_rpn_loc: 0.05349  validation_loss: 0.5897  time: 0.2107  last_time: 0.1992  data_time: 0.0023  last_data_time: 0.0025   lr: 0.00025  max_mem: 3818M
# [02/20 14:53:43 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in training: [ResizeShortestEdge(short_edge_length=(1024, 1024), max_size=1024)]
# [02/20 14:53:43 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [02/20 14:53:43 d2.data.common]: Serializing 10 elements to byte tensors and concatenating them all ...
# [02/20 14:53:43 d2.data.common]: Serialized dataset takes 2.69 MiB
# [02/20 14:53:45 detectron2]: VALIDATION_LOSS: 0.57946
# [02/20 14:53:45 d2.engine.hooks]: Saved best model as latest eval score for validation_loss is 0.57946, better than last best score 0.58966 @ iteration 629.
# [02/20 14:53:50 d2.utils.events]:  eta: 0:10:33  iter: 719  total_loss: 0.5332  loss_cls: 0.1332  loss_box_reg: 0.1857  loss_mask: 0.1322  loss_rpn_cls: 0.009979  loss_rpn_loc: 0.0572  validation_loss: 0.5795  time: 0.2108  last_time: 0.2205  data_time: 0.0067  last_data_time: 0.0035   lr: 0.00025  max_mem: 3818M
# [02/20 14:53:54 d2.utils.events]:  eta: 0:10:28  iter: 739  total_loss: 0.5544  loss_cls: 0.1232  loss_box_reg: 0.1904  loss_mask: 0.1365  loss_rpn_cls: 0.01076  loss_rpn_loc: 0.07975  validation_loss: 0.5795  time: 0.2107  last_time: 0.1604  data_time: 0.0039  last_data_time: 0.0006   lr: 0.00025  max_mem: 3818M
# [02/20 14:53:58 d2.utils.events]:  eta: 0:10:23  iter: 759  total_loss: 0.4702  loss_cls: 0.1188  loss_box_reg: 0.1718  loss_mask: 0.1192  loss_rpn_cls: 0.008672  loss_rpn_loc: 0.05953  validation_loss: 0.5795  time: 0.2109  last_time: 0.2225  data_time: 0.0039  last_data_time: 0.0117   lr: 0.00025  max_mem: 3818M
# [02/20 14:54:01 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in training: [ResizeShortestEdge(short_edge_length=(1024, 1024), max_size=1024)]
# [02/20 14:54:01 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [02/20 14:54:01 d2.data.common]: Serializing 10 elements to byte tensors and concatenating them all ...
# [02/20 14:54:01 d2.data.common]: Serialized dataset takes 2.69 MiB
# [02/20 14:54:02 detectron2]: VALIDATION_LOSS: 0.57798
# [02/20 14:54:03 d2.engine.hooks]: Saved best model as latest eval score for validation_loss is 0.57798, better than last best score 0.57946 @ iteration 699.
# [02/20 14:54:05 d2.utils.events]:  eta: 0:10:18  iter: 779  total_loss: 0.4368  loss_cls: 0.1038  loss_box_reg: 0.1577  loss_mask: 0.1117  loss_rpn_cls: 0.007259  loss_rpn_loc: 0.0556  validation_loss: 0.578  time: 0.2108  last_time: 0.2370  data_time: 0.0035  last_data_time: 0.0004   lr: 0.00025  max_mem: 3818M
# [02/20 14:54:09 d2.utils.events]:  eta: 0:10:14  iter: 799  total_loss: 0.5126  loss_cls: 0.1145  loss_box_reg: 0.1844  loss_mask: 0.1346  loss_rpn_cls: 0.005925  loss_rpn_loc: 0.05703  validation_loss: 0.578  time: 0.2108  last_time: 0.2402  data_time: 0.0047  last_data_time: 0.0034   lr: 0.00025  max_mem: 3818M
# [02/20 14:54:14 d2.utils.events]:  eta: 0:10:10  iter: 819  total_loss: 0.4753  loss_cls: 0.0999  loss_box_reg: 0.1768  loss_mask: 0.126  loss_rpn_cls: 0.003862  loss_rpn_loc: 0.05921  validation_loss: 0.578  time: 0.2111  last_time: 0.2060  data_time: 0.0031  last_data_time: 0.0006   lr: 0.00025  max_mem: 3818M
# [02/20 14:54:18 d2.utils.events]:  eta: 0:10:06  iter: 839  total_loss: 0.4634  loss_cls: 0.09305  loss_box_reg: 0.1665  loss_mask: 0.1114  loss_rpn_cls: 0.006856  loss_rpn_loc: 0.04533  validation_loss: 0.578  time: 0.2111  last_time: 0.1510  data_time: 0.0040  last_data_time: 0.0020   lr: 0.00025  max_mem: 3818M
# [02/20 14:54:19 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in training: [ResizeShortestEdge(short_edge_length=(1024, 1024), max_size=1024)]
# [02/20 14:54:19 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [02/20 14:54:19 d2.data.common]: Serializing 10 elements to byte tensors and concatenating them all ...
# [02/20 14:54:19 d2.data.common]: Serialized dataset takes 2.69 MiB
# [02/20 14:54:20 detectron2]: VALIDATION_LOSS: 0.59139
# [02/20 14:54:20 d2.engine.hooks]: Not saving as latest eval score for validation_loss is 0.59139, not better than best score 0.57798 @ iteration 769.
# [02/20 14:54:25 d2.utils.events]:  eta: 0:10:01  iter: 859  total_loss: 0.3952  loss_cls: 0.09615  loss_box_reg: 0.1616  loss_mask: 0.1107  loss_rpn_cls: 0.005477  loss_rpn_loc: 0.04913  validation_loss: 0.5914  time: 0.2111  last_time: 0.2254  data_time: 0.0027  last_data_time: 0.0014   lr: 0.00025  max_mem: 3818M
# [02/20 14:54:29 d2.utils.events]:  eta: 0:09:56  iter: 879  total_loss: 0.4212  loss_cls: 0.08962  loss_box_reg: 0.1699  loss_mask: 0.1321  loss_rpn_cls: 0.003926  loss_rpn_loc: 0.04078  validation_loss: 0.5914  time: 0.2112  last_time: 0.1256  data_time: 0.0036  last_data_time: 0.0025   lr: 0.00025  max_mem: 3818M
# ...
# [02/20 15:02:49 d2.utils.events]:  eta: 0:02:19  iter: 2899  total_loss: 0.3902  loss_cls: 0.06749  loss_box_reg: 0.143  loss_mask: 0.1074  loss_rpn_cls: 0.004632  loss_rpn_loc: 0.04774  validation_loss: 0.5504  time: 0.2130  last_time: 0.2437  data_time: 0.0033  last_data_time: 0.0037   lr: 2.5e-06  max_mem: 3818M
# [02/20 15:02:54 d2.utils.events]:  eta: 0:02:14  iter: 2919  total_loss: 0.306  loss_cls: 0.04603  loss_box_reg: 0.1165  loss_mask: 0.0949  loss_rpn_cls: 0.004653  loss_rpn_loc: 0.04014  validation_loss: 0.5504  time: 0.2130  last_time: 0.2323  data_time: 0.0058  last_data_time: 0.0005   lr: 2.5e-06  max_mem: 3818M
# [02/20 15:02:58 d2.utils.events]:  eta: 0:02:10  iter: 2939  total_loss: 0.3559  loss_cls: 0.05424  loss_box_reg: 0.1467  loss_mask: 0.1063  loss_rpn_cls: 0.003402  loss_rpn_loc: 0.03746  validation_loss: 0.5504  time: 0.2130  last_time: 0.2414  data_time: 0.0031  last_data_time: 0.0017   lr: 2.5e-06  max_mem: 3818M
# [02/20 15:02:58 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in training: [ResizeShortestEdge(short_edge_length=(1024, 1024), max_size=1024)]
# [02/20 15:02:58 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [02/20 15:02:58 d2.data.common]: Serializing 10 elements to byte tensors and concatenating them all ...
# [02/20 15:02:59 d2.data.common]: Serialized dataset takes 2.69 MiB
# [02/20 15:03:00 detectron2]: VALIDATION_LOSS: 0.55670
# [02/20 15:03:00 d2.engine.hooks]: Not saving as latest eval score for validation_loss is 0.55670, not better than best score 0.51817 @ iteration 1679.
# [02/20 15:03:05 d2.utils.events]:  eta: 0:02:05  iter: 2959  total_loss: 0.3029  loss_cls: 0.04693  loss_box_reg: 0.1192  loss_mask: 0.106  loss_rpn_cls: 0.003286  loss_rpn_loc: 0.03689  validation_loss: 0.5567  time: 0.2131  last_time: 0.2195  data_time: 0.0094  last_data_time: 0.0020   lr: 2.5e-06  max_mem: 3818M
# [02/20 15:03:09 d2.utils.events]:  eta: 0:02:00  iter: 2979  total_loss: 0.3268  loss_cls: 0.05408  loss_box_reg: 0.1247  loss_mask: 0.1033  loss_rpn_cls: 0.002567  loss_rpn_loc: 0.03049  validation_loss: 0.5567  time: 0.2131  last_time: 0.2247  data_time: 0.0030  last_data_time: 0.0036   lr: 2.5e-06  max_mem: 3818M
# [02/20 15:03:13 d2.utils.events]:  eta: 0:01:56  iter: 2999  total_loss: 0.4088  loss_cls: 0.06431  loss_box_reg: 0.1427  loss_mask: 0.1172  loss_rpn_cls: 0.00497  loss_rpn_loc: 0.05664  validation_loss: 0.5567  time: 0.2130  last_time: 0.2386  data_time: 0.0028  last_data_time: 0.0030   lr: 2.5e-06  max_mem: 3818M
# [02/20 15:03:16 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in training: [ResizeShortestEdge(short_edge_length=(1024, 1024), max_size=1024)]
# [02/20 15:03:16 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [02/20 15:03:16 d2.data.common]: Serializing 10 elements to byte tensors and concatenating them all ...
# [02/20 15:03:16 d2.data.common]: Serialized dataset takes 2.69 MiB
# [02/20 15:03:18 detectron2]: VALIDATION_LOSS: 0.55417
# [02/20 15:03:18 d2.engine.hooks]: Not saving as latest eval score for validation_loss is 0.55417, not better than best score 0.51817 @ iteration 1679.
# [02/20 15:03:20 d2.utils.events]:  eta: 0:01:51  iter: 3019  total_loss: 0.2559  loss_cls: 0.04771  loss_box_reg: 0.09765  loss_mask: 0.08418  loss_rpn_cls: 0.002539  loss_rpn_loc: 0.02792  validation_loss: 0.5542  time: 0.2131  last_time: 0.2419  data_time: 0.0042  last_data_time: 0.0166   lr: 2.5e-06  max_mem: 3818M
# [02/20 15:03:24 d2.utils.events]:  eta: 0:01:47  iter: 3039  total_loss: 0.306  loss_cls: 0.04997  loss_box_reg: 0.1169  loss_mask: 0.08999  loss_rpn_cls: 0.003904  loss_rpn_loc: 0.03889  validation_loss: 0.5542  time: 0.2132  last_time: 0.1758  data_time: 0.0027  last_data_time: 0.0032   lr: 2.5e-06  max_mem: 3818M
# [02/20 15:03:28 d2.utils.events]:  eta: 0:01:42  iter: 3059  total_loss: 0.3495  loss_cls: 0.05519  loss_box_reg: 0.1472  loss_mask: 0.1113  loss_rpn_cls: 0.002849  loss_rpn_loc: 0.04161  validation_loss: 0.5542  time: 0.2131  last_time: 0.1951  data_time: 0.0026  last_data_time: 0.0005   lr: 2.5e-06  max_mem: 3818M
# [02/20 15:03:33 d2.utils.events]:  eta: 0:01:37  iter: 3079  total_loss: 0.2822  loss_cls: 0.04293  loss_box_reg: 0.1074  loss_mask: 0.08625  loss_rpn_cls: 0.002227  loss_rpn_loc: 0.03859  validation_loss: 0.5542  time: 0.2132  last_time: 0.2417  data_time: 0.0095  last_data_time: 0.0007   lr: 2.5e-06  max_mem: 3818M
# [02/20 15:03:33 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in training: [ResizeShortestEdge(short_edge_length=(1024, 1024), max_size=1024)]
# [02/20 15:03:33 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [02/20 15:03:33 d2.data.common]: Serializing 10 elements to byte tensors and concatenating them all ...
# [02/20 15:03:33 d2.data.common]: Serialized dataset takes 2.69 MiB
# [02/20 15:03:35 detectron2]: VALIDATION_LOSS: 0.57205
# [02/20 15:03:35 d2.engine.hooks]: Not saving as latest eval score for validation_loss is 0.57205, not better than best score 0.51817 @ iteration 1679.
# [02/20 15:03:40 d2.utils.events]:  eta: 0:01:32  iter: 3099  total_loss: 0.2806  loss_cls: 0.04553  loss_box_reg: 0.1022  loss_mask: 0.08134  loss_rpn_cls: 0.001605  loss_rpn_loc: 0.02964  validation_loss: 0.572  time: 0.2133  last_time: 0.1469  data_time: 0.0025  last_data_time: 0.0018   lr: 2.5e-06  max_mem: 3818M
# [02/20 15:03:44 d2.utils.events]:  eta: 0:01:28  iter: 3119  total_loss: 0.4384  loss_cls: 0.06433  loss_box_reg: 0.1571  loss_mask: 0.1194  loss_rpn_cls: 0.01177  loss_rpn_loc: 0.06015  validation_loss: 0.572  time: 0.2132  last_time: 0.2341  data_time: 0.0064  last_data_time: 0.0015   lr: 2.5e-06  max_mem: 3818M
# [02/20 15:03:48 d2.utils.events]:  eta: 0:01:23  iter: 3139  total_loss: 0.2869  loss_cls: 0.05743  loss_box_reg: 0.1189  loss_mask: 0.09916  loss_rpn_cls: 0.003821  loss_rpn_loc: 0.03146  validation_loss: 0.572  time: 0.2133  last_time: 0.2004  data_time: 0.0044  last_data_time: 0.0038   lr: 2.5e-06  max_mem: 3818M
# [02/20 15:03:51 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in training: [ResizeShortestEdge(short_edge_length=(1024, 1024), max_size=1024)]
# [02/20 15:03:51 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [02/20 15:03:51 d2.data.common]: Serializing 10 elements to byte tensors and concatenating them all ...
# [02/20 15:03:51 d2.data.common]: Serialized dataset takes 2.69 MiB
# [02/20 15:03:53 detectron2]: VALIDATION_LOSS: 0.55285
# [02/20 15:03:53 d2.engine.hooks]: Not saving as latest eval score for validation_loss is 0.55285, not better than best score 0.51817 @ iteration 1679.
# [02/20 15:03:55 d2.utils.events]:  eta: 0:01:18  iter: 3159  total_loss: 0.4061  loss_cls: 0.0619  loss_box_reg: 0.1331  loss_mask: 0.1177  loss_rpn_cls: 0.006139  loss_rpn_loc: 0.05621  validation_loss: 0.5528  time: 0.2132  last_time: 0.2416  data_time: 0.0040  last_data_time: 0.0003   lr: 2.5e-06  max_mem: 3818M
# [02/20 15:03:59 d2.utils.events]:  eta: 0:01:14  iter: 3179  total_loss: 0.3141  loss_cls: 0.04828  loss_box_reg: 0.1192  loss_mask: 0.1063  loss_rpn_cls: 0.003267  loss_rpn_loc: 0.03351  validation_loss: 0.5528  time: 0.2132  last_time: 0.1691  data_time: 0.0033  last_data_time: 0.0006   lr: 2.5e-06  max_mem: 3818M
# [02/20 15:04:03 d2.utils.events]:  eta: 0:01:09  iter: 3199  total_loss: 0.2985  loss_cls: 0.05356  loss_box_reg: 0.1136  loss_mask: 0.09802  loss_rpn_cls: 0.004668  loss_rpn_loc: 0.03288  validation_loss: 0.5528  time: 0.2132  last_time: 0.1835  data_time: 0.0027  last_data_time: 0.0034   lr: 2.5e-06  max_mem: 3818M
# [02/20 15:04:07 d2.utils.events]:  eta: 0:01:04  iter: 3219  total_loss: 0.3477  loss_cls: 0.05634  loss_box_reg: 0.125  loss_mask: 0.1077  loss_rpn_cls: 0.005534  loss_rpn_loc: 0.04543  validation_loss: 0.5528  time: 0.2132  last_time: 0.2445  data_time: 0.0022  last_data_time: 0.0029   lr: 2.5e-06  max_mem: 3818M
# [02/20 15:04:08 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in training: [ResizeShortestEdge(short_edge_length=(1024, 1024), max_size=1024)]
# [02/20 15:04:08 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [02/20 15:04:08 d2.data.common]: Serializing 10 elements to byte tensors and concatenating them all ...
# [02/20 15:04:08 d2.data.common]: Serialized dataset takes 2.69 MiB
# [02/20 15:04:10 detectron2]: VALIDATION_LOSS: 0.56499
# [02/20 15:04:10 d2.engine.hooks]: Not saving as latest eval score for validation_loss is 0.56499, not better than best score 0.51817 @ iteration 1679.
# [02/20 15:04:14 d2.utils.events]:  eta: 0:00:59  iter: 3239  total_loss: 0.3525  loss_cls: 0.06344  loss_box_reg: 0.1258  loss_mask: 0.1048  loss_rpn_cls: 0.006627  loss_rpn_loc: 0.03435  validation_loss: 0.565  time: 0.2132  last_time: 0.1541  data_time: 0.0025  last_data_time: 0.0023   lr: 2.5e-06  max_mem: 3818M
# [02/20 15:04:18 d2.utils.events]:  eta: 0:00:55  iter: 3259  total_loss: 0.3171  loss_cls: 0.05184  loss_box_reg: 0.12  loss_mask: 0.1043  loss_rpn_cls: 0.002797  loss_rpn_loc: 0.03387  validation_loss: 0.565  time: 0.2131  last_time: 0.2105  data_time: 0.0118  last_data_time: 0.0041   lr: 2.5e-06  max_mem: 3818M
# [02/20 15:04:22 d2.utils.events]:  eta: 0:00:50  iter: 3279  total_loss: 0.3131  loss_cls: 0.04197  loss_box_reg: 0.12  loss_mask: 0.0971  loss_rpn_cls: 0.004666  loss_rpn_loc: 0.03872  validation_loss: 0.565  time: 0.2131  last_time: 0.2173  data_time: 0.0091  last_data_time: 0.0006   lr: 2.5e-06  max_mem: 3818M
# [02/20 15:04:25 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in training: [ResizeShortestEdge(short_edge_length=(1024, 1024), max_size=1024)]
# [02/20 15:04:25 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [02/20 15:04:25 d2.data.common]: Serializing 10 elements to byte tensors and concatenating them all ...
# [02/20 15:04:25 d2.data.common]: Serialized dataset takes 2.69 MiB
# [02/20 15:04:27 detectron2]: VALIDATION_LOSS: 0.56247
# [02/20 15:04:27 d2.engine.hooks]: Not saving as latest eval score for validation_loss is 0.56247, not better than best score 0.51817 @ iteration 1679.
# [02/20 15:04:29 d2.utils.events]:  eta: 0:00:46  iter: 3299  total_loss: 0.3287  loss_cls: 0.04944  loss_box_reg: 0.1369  loss_mask: 0.1033  loss_rpn_cls: 0.004932  loss_rpn_loc: 0.04005  validation_loss: 0.5625  time: 0.2131  last_time: 0.2207  data_time: 0.0035  last_data_time: 0.0018   lr: 2.5e-06  max_mem: 3818M
# [02/20 15:04:33 d2.utils.events]:  eta: 0:00:41  iter: 3319  total_loss: 0.2835  loss_cls: 0.05364  loss_box_reg: 0.1111  loss_mask: 0.09294  loss_rpn_cls: 0.002501  loss_rpn_loc: 0.03937  validation_loss: 0.5625  time: 0.2131  last_time: 0.2324  data_time: 0.0024  last_data_time: 0.0012   lr: 2.5e-06  max_mem: 3818M
# [02/20 15:04:37 d2.utils.events]:  eta: 0:00:36  iter: 3339  total_loss: 0.322  loss_cls: 0.06372  loss_box_reg: 0.1326  loss_mask: 0.09566  loss_rpn_cls: 0.004955  loss_rpn_loc: 0.03672  validation_loss: 0.5625  time: 0.2131  last_time: 0.2371  data_time: 0.0026  last_data_time: 0.0033   lr: 2.5e-06  max_mem: 3818M
# [02/20 15:04:41 d2.utils.events]:  eta: 0:00:32  iter: 3359  total_loss: 0.2951  loss_cls: 0.04773  loss_box_reg: 0.1169  loss_mask: 0.09767  loss_rpn_cls: 0.004046  loss_rpn_loc: 0.03568  validation_loss: 0.5625  time: 0.2131  last_time: 0.2190  data_time: 0.0029  last_data_time: 0.0015   lr: 2.5e-06  max_mem: 3818M
# [02/20 15:04:42 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in training: [ResizeShortestEdge(short_edge_length=(1024, 1024), max_size=1024)]
# [02/20 15:04:42 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [02/20 15:04:42 d2.data.common]: Serializing 10 elements to byte tensors and concatenating them all ...
# [02/20 15:04:42 d2.data.common]: Serialized dataset takes 2.69 MiB
# [02/20 15:04:44 detectron2]: VALIDATION_LOSS: 0.57980
# [02/20 15:04:44 d2.engine.hooks]: Not saving as latest eval score for validation_loss is 0.57980, not better than best score 0.51817 @ iteration 1679.
# [02/20 15:04:48 d2.utils.events]:  eta: 0:00:27  iter: 3379  total_loss: 0.3882  loss_cls: 0.06105  loss_box_reg: 0.127  loss_mask: 0.1108  loss_rpn_cls: 0.009502  loss_rpn_loc: 0.05886  validation_loss: 0.5798  time: 0.2130  last_time: 0.1230  data_time: 0.0031  last_data_time: 0.0039   lr: 2.5e-06  max_mem: 3818M
# [02/20 15:04:52 d2.utils.events]:  eta: 0:00:23  iter: 3399  total_loss: 0.3801  loss_cls: 0.05493  loss_box_reg: 0.1341  loss_mask: 0.1021  loss_rpn_cls: 0.004121  loss_rpn_loc: 0.04891  validation_loss: 0.5798  time: 0.2130  last_time: 0.0947  data_time: 0.0030  last_data_time: 0.0028   lr: 2.5e-06  max_mem: 3818M
# [02/20 15:04:56 d2.utils.events]:  eta: 0:00:18  iter: 3419  total_loss: 0.2942  loss_cls: 0.04225  loss_box_reg: 0.109  loss_mask: 0.0928  loss_rpn_cls: 0.0046  loss_rpn_loc: 0.03624  validation_loss: 0.5798  time: 0.2129  last_time: 0.2408  data_time: 0.0023  last_data_time: 0.0026   lr: 2.5e-06  max_mem: 3818M
# [02/20 15:04:59 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in training: [ResizeShortestEdge(short_edge_length=(1024, 1024), max_size=1024)]
# [02/20 15:04:59 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [02/20 15:04:59 d2.data.common]: Serializing 10 elements to byte tensors and concatenating them all ...
# [02/20 15:04:59 d2.data.common]: Serialized dataset takes 2.69 MiB
# [02/20 15:05:00 detectron2]: VALIDATION_LOSS: 0.54985
# [02/20 15:05:00 d2.engine.hooks]: Not saving as latest eval score for validation_loss is 0.54985, not better than best score 0.51817 @ iteration 1679.
# [02/20 15:05:03 d2.utils.events]:  eta: 0:00:13  iter: 3439  total_loss: 0.3973  loss_cls: 0.06799  loss_box_reg: 0.1636  loss_mask: 0.1142  loss_rpn_cls: 0.006521  loss_rpn_loc: 0.0543  validation_loss: 0.5498  time: 0.2129  last_time: 0.2440  data_time: 0.0025  last_data_time: 0.0006   lr: 2.5e-06  max_mem: 3818M
# [02/20 15:05:07 d2.utils.events]:  eta: 0:00:09  iter: 3459  total_loss: 0.3642  loss_cls: 0.06333  loss_box_reg: 0.1337  loss_mask: 0.12  loss_rpn_cls: 0.003076  loss_rpn_loc: 0.03585  validation_loss: 0.5498  time: 0.2130  last_time: 0.1951  data_time: 0.0029  last_data_time: 0.0008   lr: 2.5e-06  max_mem: 3818M
# [02/20 15:05:11 d2.utils.events]:  eta: 0:00:04  iter: 3479  total_loss: 0.4249  loss_cls: 0.06112  loss_box_reg: 0.1488  loss_mask: 0.1193  loss_rpn_cls: 0.004594  loss_rpn_loc: 0.05172  validation_loss: 0.5498  time: 0.2130  last_time: 0.2020  data_time: 0.0024  last_data_time: 0.0027   lr: 2.5e-06  max_mem: 3818M
# [02/20 15:05:15 d2.utils.events]:  eta: 0:00:00  iter: 3499  total_loss: 0.3274  loss_cls: 0.05751  loss_box_reg: 0.1227  loss_mask: 0.09883  loss_rpn_cls: 0.004541  loss_rpn_loc: 0.03947  validation_loss: 0.5498  time: 0.2130  last_time: 0.2326  data_time: 0.0025  last_data_time: 0.0025   lr: 2.5e-06  max_mem: 3818M
# [02/20 15:05:15 d2.engine.hooks]: Overall training speed: 3498 iterations in 0:12:25 (0.2130 s / it)
# [02/20 15:05:15 d2.engine.hooks]: Total training time: 0:14:25 (0:02:00 on hooks)
# [02/20 15:05:16 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in training: [ResizeShortestEdge(short_edge_length=(1024, 1024), max_size=1024)]
# [02/20 15:05:16 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [02/20 15:05:16 d2.data.common]: Serializing 10 elements to byte tensors and concatenating them all ...
# [02/20 15:05:16 d2.data.common]: Serialized dataset takes 2.69 MiB
# [02/20 15:05:18 detectron2]: VALIDATION_LOSS: 0.55219
# [02/20 15:05:18 d2.engine.hooks]: Not saving as latest eval score for validation_loss is 0.55219, not better than best score 0.51817 @ iteration 1679.

# %% [markdown]
# ### Plot Training and Validation Curves

# %%
def load_json_arr(json_path):
    train, val = [], []
    with open(json_path, "r") as f:
        for line in f:
            l = json.loads(line)
            if "validation_loss" in l:
                val.append(l)
            elif "total_loss" in l:
                train.append(l)
    return train, val

# %%
train_metrics, val_metrics = load_json_arr("new_models/mrcnn101/metrics.json")
train_metrics = train_metrics[2:]

# %%
train_iters = [x["iteration"] for x in train_metrics]
train_loss = [x["total_loss"] for x in train_metrics]

val_iters = [x["iteration"] for x in val_metrics]
val_loss = [x["validation_loss"] for x in val_metrics]

# %%
plt.plot(train_iters, train_loss)
plt.plot(val_iters, val_loss)
plt.xlabel("iters")
plt.ylabel("loss")
plt.title("train/val loss")
plt.legend(["training loss", "validation loss"], loc="upper right")
plt.show()

# %% [markdown]
# ### Evalatuate Model on Held Out Testset
#
# Using Default Predictor with Threshold of 0.7

# %%
cfg.MODEL.WEIGHTS = "new_models/mrcnn101/model_best.pth"
cfg.MODEL.ROI_HEADS.SCORE_THRESH_TEST = 0.7
predictor = DefaultPredictor(cfg)
# Out:
# [02/20 15:38:06 d2.checkpoint.detection_checkpoint]: [DetectionCheckpointer] Loading from new_models/mrcnn101/model_best.pth ...

# %%
evaluator = COCOEvaluator(
    dataset_name="test",
    output_dir=os.path.join("new_models/mrcnn101/inference"),
    allow_cached_coco=False,
    use_fast_impl=False,
)
testloader = build_detection_test_loader(cfg, "test")
print(inference_on_dataset(predictor.model, testloader, evaluator))
# Out:
# [02/20 15:38:13 d2.evaluation.coco_evaluation]: Trying to convert 'test' to COCO format ...
# [02/20 15:38:13 d2.data.datasets.coco]: Converting annotations of dataset 'test' to COCO format ...)
# [02/20 15:38:13 d2.data.datasets.coco]: Converting dataset dicts into COCO format
# [02/20 15:38:13 d2.data.datasets.coco]: Conversion finished, #images: 20, #annotations: 790
# [02/20 15:38:13 d2.data.datasets.coco]: Caching COCO format annotations at 'new_models/mrcnn101/inference/test_coco_format.json' ...
# [02/20 15:38:14 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in inference: [ResizeShortestEdge(short_edge_length=(800, 800), max_size=1333, sample_style='choice')]
# [02/20 15:38:14 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [02/20 15:38:14 d2.data.common]: Serializing 20 elements to byte tensors and concatenating them all ...
# [02/20 15:38:14 d2.data.common]: Serialized dataset takes 2.98 MiB
# [02/20 15:38:14 d2.evaluation.evaluator]: Start inference on 20 batches
# /home/abhinavchadaga/miniforge3/envs/d2/lib/python3.8/site-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at /opt/conda/conda-bld/pytorch_1670525541702/work/aten/src/ATen/native/TensorShape.cpp:3190.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# [02/20 15:38:16 d2.evaluation.evaluator]: Inference done 11/20. Dataloading: 0.0005 s/iter. Inference: 0.0395 s/iter. Eval: 0.0598 s/iter. Total: 0.0998 s/iter. ETA=0:00:00
# [02/20 15:38:18 d2.evaluation.evaluator]: Total inference time: 0:00:03.170503 (0.211367 s / iter per device, on 1 devices)
# [02/20 15:38:18 d2.evaluation.evaluator]: Total inference pure compute time: 0:00:00 (0.043098 s / iter per device, on 1 devices)
# [02/20 15:38:18 d2.evaluation.coco_evaluation]: Preparing results for COCO format ...
# [02/20 15:38:18 d2.evaluation.coco_evaluation]: Saving results to new_models/mrcnn101/inference/coco_instances_results.json
# [02/20 15:38:18 d2.evaluation.coco_evaluation]: Evaluating predictions with official COCO API...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.16s).
# Accumulating evaluation results...
# DONE (t=0.01s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.748
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.947
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.890
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.799
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.754
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.761
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.043
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.407
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.799
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.823
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.797
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.803
# [02/20 15:38:19 d2.evaluation.coco_evaluation]: Evaluation results for bbox:
# |   AP   |  AP50  |  AP75  |  APs   |  APm   |  APl   |
# |:------:|:------:|:------:|:------:|:------:|:------:|
# | 74.752 | 94.742 | 89.027 | 79.858 | 75.427 | 76.098 |
# [02/20 15:38:19 d2.evaluation.coco_evaluation]: Per-category bbox AP:
# | category   | AP     | category   | AP     |
# |:-----------|:-------|:-----------|:-------|
# | label      | 72.726 | button     | 76.777 |
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *segm*
# DONE (t=0.18s).
# Accumulating evaluation results...
# DONE (t=0.01s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.760
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.942
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.904
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.720
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.765
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.792
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.043
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.413
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.813
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.764
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.808
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.833
# [02/20 15:38:19 d2.evaluation.coco_evaluation]: Evaluation results for segm:
# |   AP   |  AP50  |  AP75  |  APs   |  APm   |  APl   |
# |:------:|:------:|:------:|:------:|:------:|:------:|
# | 76.023 | 94.237 | 90.362 | 72.005 | 76.547 | 79.219 |
# [02/20 15:38:19 d2.evaluation.coco_evaluation]: Per-category segm AP:
# | category   | AP     | category   | AP     |
# |:-----------|:-------|:-----------|:-------|
# | label      | 75.501 | button     | 76.546 |
# OrderedDict([('bbox', {'AP': 74.7515809851782, 'AP50': 94.74206791720428, 'AP75': 89.02677674461518, 'APs': 79.85837587518151, 'APm': 75.4273950706907, 'APl': 76.09807739625069, 'AP-label': 72.72579301442971, 'AP-button': 76.77736895592668}), ('segm', {'AP': 76.02343601687596, 'AP50': 94.23679616370396, 'AP75': 90.36189676223727, 'APs': 72.00502793194299, 'APm': 76.54658346574779, 'APl': 79.21948304027124, 'AP-label': 75.5005422108409, 'AP-button': 76.54632982291103})])

# %% [markdown]
# ### View Output of Model on Test Images

# %%
testset = get_detection_dataset_dicts("test", filter_empty=False)
for d in random.sample(testset, 5):
    img = cv2.imread(d["file_name"])
    outputs = predictor(img)
    v = Visualizer(
        img[:, :, ::-1],
        metadata=MetadataCatalog.get("test"),
        scale=1.0,
        instance_mode=ColorMode.SEGMENTATION,
    )
    out = v.draw_instance_predictions(outputs["instances"].to("cpu"))
    plt.imshow(out.get_image())
    plt.axis("off")
    plt.show()
