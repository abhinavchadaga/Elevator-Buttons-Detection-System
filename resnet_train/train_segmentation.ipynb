# %% [markdown]
# # Training Notebook
#
# Training on Mixed and UT-West-Campus datasets. Evaluate on test portion of both
#
# Train Mask-RCNN + ResNet101 Backbone
#
# Add a couple additional things:
# - Validation Loop using loss
# - Checkpoint based off of best validation metrics
# - Custom COCO Style Dataloaders

# %%
# python libraries
import os
import json
import random
import math
import time
import datetime
import logging
from glob import glob

import numpy as np
import torch
import cv2
import matplotlib.pyplot as plt

# d2 libraries
from detectron2 import model_zoo
from detectron2.engine import DefaultTrainer, DefaultPredictor
from detectron2.evaluation import COCOEvaluator, inference_on_dataset
from detectron2.config import get_cfg
from detectron2.utils import comm
from detectron2.utils.logger import log_every_n_seconds
from detectron2.utils.visualizer import Visualizer, ColorMode
from detectron2.engine.hooks import EvalHook, BestCheckpointer
from detectron2.data import (
    MetadataCatalog,
    DatasetCatalog,
    build_detection_train_loader,
    build_detection_test_loader,
    get_detection_dataset_dicts,
    DatasetMapper,
)
import detectron2.data.transforms as T
from detectron2.utils.logger import setup_logger

# my stuff
from data_utils import (
    read_split_file,
    register_dataset,
    random_split_mixed_set,
    random_split_ut_west_campus_set
)

# setup D2 logger
setup_logger()

# %matplotlib inline

# %% [markdown]
# ### Randomly Split Mixed Dataset
#
# For reproducibility we seed the shuffler with the value 10

# %%
# random_split_mixed_set(img_dir="data/panels/mixed", split_ratio=(0.7, 0.1, 0.2), seed=10)
mixed_datasets = read_split_file("data/panels/mixed/split.txt")

# %% [markdown]
# ### Randomly Split UT-West-Campus Dataset

# %%
# random_split_ut_west_campus_set("data/panels/ut_west_campus", split_ratio=(0.7, 0.1, 0.2), seed=10)
ut_west_campus_datasets = read_split_file("data/panels/ut_west_campus/split.txt")

# %% [markdown]
# ### Register Mixed Dataset Splits

# %%
classes = ["label", "button"]
colors = [(0, 255, 0), (0, 0, 255)]

dataset_names = [
    "mixed_train",
    "mixed_val",
    "mixed_test",
    "ut_west_campus_train",
    "ut_west_campus_val",
    "ut_west_campus_test",
]

# register combined training and validation sets
for name, im_paths in zip(dataset_names, mixed_datasets + ut_west_campus_datasets):
    DatasetCatalog.register(
        name=name, func=lambda im_paths=im_paths: register_dataset(im_paths=im_paths)
    )
    MetadataCatalog.get(name=name).set(thing_classes=classes, thing_colors=colors)

elevator_metadata = MetadataCatalog.get("mixed_train")

# %%
mixed_train = DatasetCatalog.get("mixed_train")
ut_west_campus_train = DatasetCatalog.get("ut_west_campus_train")
trainset = mixed_train + ut_west_campus_train
print("total trainset len: ", len(trainset))
# Out:
# total trainset len:  268

# %% [markdown]
# ### Visualize Training Data Samples
#
# Ensure that data is annotated correctly

# %%
for d in random.sample(trainset, 5):
    img = cv2.imread(d["file_name"])
    print(d["file_name"])
    visualizer = Visualizer(
        img[:, :, ::-1],
        metadata=elevator_metadata,
        scale=1,
        instance_mode=ColorMode.SEGMENTATION,
    )
    out = visualizer.draw_dataset_dict(d)
    plt.imshow(out.get_image())
    plt.axis("off")
    plt.show()
# Out:
# data/panels/mixed/mixed_77.jpg
# data/panels/ut_west_campus/norman_hackerman_0.jpg
# data/panels/mixed/mixed_76.jpg
# data/panels/mixed/mixed_23.jpg
# data/panels/ut_west_campus/norman_hackerman_13.jpg

# %% [markdown]
# ### Validation Loop using Validation Loss
#
# as opposed to evaluation metrics (AP, Precision, Recall, etc.)

# %%
def validation_loop(model: torch.nn, dataloader: torch.utils.data.DataLoader) -> dict:
    """
    Validate model on the given dataloader. Put model in training mode to output loss
    dict but do not backpropogate gradients. Largely adapted from train_loop.py and
    inference_on_dataset

    Args:
        model (torch.nn): model to validate
        dataloader (torch.utils.data.DataLoader): validation dataloader set to training
            mode

    Returns:
        dict: {"validation_loss": val_loss}
    """
    model.train()
    num_batches = len(dataloader)
    num_warmup = min(5, num_batches - 1)
    start_time = time.perf_counter()
    total_compute_time = 0
    losses = []
    for idx, data in enumerate(dataloader):
        if idx == num_warmup:
            start_time = time.perf_counter()
            total_compute_time = 0
        start_compute_time = time.perf_counter()
        if torch.cuda.is_available():
            torch.cuda.synchronize()
        total_compute_time += time.perf_counter() - start_compute_time
        iters_after_start = idx + 1 - num_warmup * int(idx >= num_warmup)
        seconds_per_img = total_compute_time / iters_after_start
        if idx >= num_warmup * 2 or seconds_per_img > 5:
            total_seconds_per_img = (
                time.perf_counter() - start_time
            ) / iters_after_start
            eta = datetime.timedelta(
                seconds=int(total_seconds_per_img) * (num_batches - idx - 1)
            )
            log_every_n_seconds(
                logging.INFO,
                "Loss on Validation  done {}/{}. {:.4f} s / img. ETA={}".format(
                    idx + 1, num_batches, seconds_per_img, str(eta)
                ),
                n=5,
            )

        batch_loss_dict = model(data)
        batch_loss_dict = {
            k: v.detach().cpu().item() if isinstance(v, torch.Tensor) else float(v)
            for k, v in batch_loss_dict.items()
        }
        total_batch_loss = sum(loss for loss in batch_loss_dict.values())
        losses.append(total_batch_loss)
    val_loss = np.mean(losses)
    comm.synchronize()
    log_every_n_seconds(logging.INFO, f"VALIDATION_LOSS: {val_loss:.5f}")
    return {"validation_loss": val_loss}

# %% [markdown]
# ### Define a Custom Trainer
#
# Add custom hooks and dataloaders

# %%
class Trainer(DefaultTrainer):
    @classmethod
    def build_train_loader(cls, cfg):
        return build_detection_train_loader(
            dataset=get_detection_dataset_dicts(
                cfg.DATASETS.TRAIN, filter_empty=False
            ),
            mapper=DatasetMapper(
                is_train=True,
                augmentations=[
                    T.ResizeScale(
                        min_scale=0.1,
                        max_scale=2.0,
                        target_height=1024,
                        target_width=1024,
                    ),
                    T.FixedSizeCrop(crop_size=(1024, 1024), pad=False),
                ],
                image_format="RGB",
                use_instance_mask=True,
                recompute_boxes=True,
            ),
            total_batch_size=cfg.SOLVER.IMS_PER_BATCH,
            num_workers=cfg.DATALOADER.NUM_WORKERS,
        )

    @classmethod
    def build_validation_loader(cls, cfg):
        return build_detection_test_loader(
            dataset=get_detection_dataset_dicts(
                cfg.DATASETS.VAL, filter_empty=False
            ),
            mapper=DatasetMapper(
                is_train=True,
                augmentations=[
                    T.ResizeShortestEdge(short_edge_length=1024, max_size=1024)
                ],
                image_format="BGR",
                use_instance_mask=True,
            ),
        )

    def build_hooks(self) -> list:
        """
        Overwrite the evaluation loop and checkpoint using best validation loss

        Returns:
            list: list of hooks
        """
        hooks = super().build_hooks()
        # remove existing EvalHook
        if comm.is_main_process():
            del hooks[-2]
            del hooks[-2]
        else:
            del hooks[-1]
        hooks.extend(
            [
                EvalHook(
                    eval_period=self.cfg.TEST.EVAL_PERIOD,
                    eval_function=lambda: validation_loop(
                        self.model,
                        self.build_validation_loader(self.cfg),
                    ),
                    eval_after_train=True,
                ),
                BestCheckpointer(
                    eval_period=self.cfg.TEST.EVAL_PERIOD,
                    checkpointer=self.checkpointer,
                    val_metric="validation_loss",
                    mode="min",
                ),
            ]
        )
        return hooks

# %% [markdown]
# ### Define Config for Building Model
#
# Use Mask-RCNN w/ ResNet-101 Backbone

# %%
mask_rcnn_res50 = "COCO-InstanceSegmentation/mask_rcnn_R_50_FPN_3x.yaml"
mask_rcnn_res101 = "COCO-InstanceSegmentation/mask_rcnn_R_101_FPN_3x.yaml"
cascade_mask_rcnn_res50 = "Misc/cascade_mask_rcnn_R_50_FPN_3x.yaml"

base_cfg = mask_rcnn_res101

cfg = get_cfg()
cfg.merge_from_file(model_zoo.get_config_file(base_cfg))

# start from pretrained weights
cfg.MODEL.WEIGHTS = model_zoo.get_checkpoint_url(base_cfg)

# assign datasets and adjust ROI HEADS to match num classes
cfg.DATASETS.TRAIN = ("mixed_train", "ut_west_campus_train")
cfg.DATASETS.VAL = ("mixed_val", "ut_west_campus_val")
cfg.DATASETS.TEST = ("mixed_test", "ut_west_campus_test")
cfg.DATALOADER.FILTER_EMPTY_ANNOTATIONS = False
cfg.INPUT.RANDOM_FLIP = "none"
cfg.MODEL.ROI_HEADS.NUM_CLASSES = 2

# Calculate training logic
epochs = 50
batch_size = 2
eval_period = 2
iters_per_epoch = math.ceil(len(trainset) / batch_size)

cfg.SOLVER.IMS_PER_BATCH = batch_size
cfg.SOLVER.MAX_ITER = iters_per_epoch * epochs
cfg.TEST.EVAL_PERIOD = iters_per_epoch * eval_period
cfg.SOLVER.BASE_LR = 0.00025
cfg.SOLVER.STEPS = [int(0.7 * cfg.SOLVER.MAX_ITER), int(0.8 * cfg.SOLVER.MAX_ITER)]
cfg.SOLVER.WARMUP_ITERS = int(0.067 * cfg.SOLVER.MAX_ITER)

# SAVE DIR
cfg.OUTPUT_DIR = "./models/combined_segmentation"

# %% [markdown]
# ### Train Configured Model
#
# Use modified DefaultTrainer

# %%
os.makedirs(cfg.OUTPUT_DIR, exist_ok=True)
trainer = Trainer(cfg)
trainer.resume_or_load(resume=False)
trainer.train()
# Out:
# [02/25 22:17:54 d2.engine.defaults]: Model:
# GeneralizedRCNN(
#   (backbone): FPN(
#     (fpn_lateral2): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral3): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral4): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output4): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral5): Conv2d(2048, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output5): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (top_block): LastLevelMaxPool()
#     (bottom_up): ResNet(
#       (stem): BasicStem(
#         (conv1): Conv2d(
#           3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False
#           (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#         )
#       )
#       (res2): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#         )
#       )
#       (res3): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             256, 128, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#         (3): BottleneckBlock(
#           (conv1): Conv2d(
#             512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#       )
#       (res4): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             512, 256, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (3): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (4): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (5): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (6): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (7): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (8): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (9): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (10): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (11): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (12): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (13): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (14): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (15): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (16): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (17): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (18): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (19): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (20): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (21): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (22): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#       )
#       (res5): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             1024, 512, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#         )
#       )
#     )
#   )
#   (proposal_generator): RPN(
#     (rpn_head): StandardRPNHead(
#       (conv): Conv2d(
#         256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)
#         (activation): ReLU()
#       )
#       (objectness_logits): Conv2d(256, 3, kernel_size=(1, 1), stride=(1, 1))
#       (anchor_deltas): Conv2d(256, 12, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (anchor_generator): DefaultAnchorGenerator(
#       (cell_anchors): BufferList()
#     )
#   )
#   (roi_heads): StandardROIHeads(
#     (box_pooler): ROIPooler(
#       (level_poolers): ModuleList(
#         (0): ROIAlign(output_size=(7, 7), spatial_scale=0.25, sampling_ratio=0, aligned=True)
#         (1): ROIAlign(output_size=(7, 7), spatial_scale=0.125, sampling_ratio=0, aligned=True)
#         (2): ROIAlign(output_size=(7, 7), spatial_scale=0.0625, sampling_ratio=0, aligned=True)
#         (3): ROIAlign(output_size=(7, 7), spatial_scale=0.03125, sampling_ratio=0, aligned=True)
#       )
#     )
#     (box_head): FastRCNNConvFCHead(
#       (flatten): Flatten(start_dim=1, end_dim=-1)
#       (fc1): Linear(in_features=12544, out_features=1024, bias=True)
#       (fc_relu1): ReLU()
#       (fc2): Linear(in_features=1024, out_features=1024, bias=True)
#       (fc_relu2): ReLU()
#     )
#     (box_predictor): FastRCNNOutputLayers(
#       (cls_score): Linear(in_features=1024, out_features=3, bias=True)
#       (bbox_pred): Linear(in_features=1024, out_features=8, bias=True)
#     )
#     (mask_pooler): ROIPooler(
#       (level_poolers): ModuleList(
#         (0): ROIAlign(output_size=(14, 14), spatial_scale=0.25, sampling_ratio=0, aligned=True)
#         (1): ROIAlign(output_size=(14, 14), spatial_scale=0.125, sampling_ratio=0, aligned=True)
#         (2): ROIAlign(output_size=(14, 14), spatial_scale=0.0625, sampling_ratio=0, aligned=True)
#         (3): ROIAlign(output_size=(14, 14), spatial_scale=0.03125, sampling_ratio=0, aligned=True)
#       )
#     )
#     (mask_head): MaskRCNNConvUpsampleHead(
#       (mask_fcn1): Conv2d(
#         256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)
#         (activation): ReLU()
#       )
#       (mask_fcn2): Conv2d(
#         256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)
#         (activation): ReLU()
#       )
#       (mask_fcn3): Conv2d(
#         256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)
#         (activation): ReLU()
#       )
#       (mask_fcn4): Conv2d(
#         256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)
#         (activation): ReLU()
#       )
#       (deconv): ConvTranspose2d(256, 256, kernel_size=(2, 2), stride=(2, 2))
#       (deconv_relu): ReLU()
#       (predictor): Conv2d(256, 2, kernel_size=(1, 1), stride=(1, 1))
#     )
#   )
# )
# [02/25 22:18:20 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in training: [ResizeScale(min_scale=0.1, max_scale=2.0, target_height=1024, target_width=1024), FixedSizeCrop(crop_size=(1024, 1024), pad=False)]
# [02/25 22:18:20 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [02/25 22:18:20 d2.data.common]: Serializing 268 elements to byte tensors and concatenating them all ...
# [02/25 22:18:24 d2.data.common]: Serialized dataset takes 82.87 MiB
# [02/25 22:18:24 d2.checkpoint.detection_checkpoint]: [DetectionCheckpointer] Loading from https://dl.fbaipublicfiles.com/detectron2/COCO-InstanceSegmentation/mask_rcnn_R_101_FPN_3x/138205316/model_final_a3ec72.pkl ...
# Skip loading parameter 'roi_heads.box_predictor.cls_score.weight' to the model due to incompatible shapes: (81, 1024) in the checkpoint but (3, 1024) in the model! You might want to double check if this is expected.
# Skip loading parameter 'roi_heads.box_predictor.cls_score.bias' to the model due to incompatible shapes: (81,) in the checkpoint but (3,) in the model! You might want to double check if this is expected.
# Skip loading parameter 'roi_heads.box_predictor.bbox_pred.weight' to the model due to incompatible shapes: (320, 1024) in the checkpoint but (8, 1024) in the model! You might want to double check if this is expected.
# Skip loading parameter 'roi_heads.box_predictor.bbox_pred.bias' to the model due to incompatible shapes: (320,) in the checkpoint but (8,) in the model! You might want to double check if this is expected.
# Skip loading parameter 'roi_heads.mask_head.predictor.weight' to the model due to incompatible shapes: (80, 256, 1, 1) in the checkpoint but (2, 256, 1, 1) in the model! You might want to double check if this is expected.
# Skip loading parameter 'roi_heads.mask_head.predictor.bias' to the model due to incompatible shapes: (80,) in the checkpoint but (2,) in the model! You might want to double check if this is expected.
# Some model parameters or buffers are not found in the checkpoint:
# roi_heads.box_predictor.bbox_pred.{bias, weight}
# roi_heads.box_predictor.cls_score.{bias, weight}
# roi_heads.mask_head.predictor.{bias, weight}
# [02/25 22:18:24 d2.engine.train_loop]: Starting training from iteration 0
# /home/abhinavchadaga/miniforge3/envs/d2/lib/python3.8/site-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at /opt/conda/conda-bld/pytorch_1670525541702/work/aten/src/ATen/native/TensorShape.cpp:3190.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# [02/25 22:18:30 d2.utils.events]:  eta: 0:25:23  iter: 19  total_loss: 3.323  loss_cls: 0.9332  loss_box_reg: 0.6067  loss_mask: 0.6956  loss_rpn_cls: 0.9855  loss_rpn_loc: 0.1001  time: 0.2116  last_time: 0.2500  data_time: 0.0247  last_data_time: 0.0022   lr: 1.0842e-05  max_mem: 3820M
# [02/25 22:18:34 d2.utils.events]:  eta: 0:26:20  iter: 39  total_loss: 2.68  loss_cls: 0.8591  loss_box_reg: 0.7647  loss_mask: 0.6682  loss_rpn_cls: 0.1758  loss_rpn_loc: 0.1375  time: 0.2215  last_time: 0.1972  data_time: 0.0033  last_data_time: 0.0038   lr: 2.1992e-05  max_mem: 3820M
# [02/25 22:18:39 d2.utils.events]:  eta: 0:25:54  iter: 59  total_loss: 2.242  loss_cls: 0.7492  loss_box_reg: 0.7719  loss_mask: 0.6156  loss_rpn_cls: 0.05566  loss_rpn_loc: 0.0513  time: 0.2191  last_time: 0.2344  data_time: 0.0044  last_data_time: 0.0105   lr: 3.3141e-05  max_mem: 3820M
# [02/25 22:18:43 d2.utils.events]:  eta: 0:25:45  iter: 79  total_loss: 2.115  loss_cls: 0.6431  loss_box_reg: 0.7682  loss_mask: 0.5506  loss_rpn_cls: 0.04041  loss_rpn_loc: 0.09992  time: 0.2187  last_time: 0.2268  data_time: 0.0026  last_data_time: 0.0032   lr: 4.4291e-05  max_mem: 3820M
# [02/25 22:18:47 d2.utils.events]:  eta: 0:25:41  iter: 99  total_loss: 1.839  loss_cls: 0.5889  loss_box_reg: 0.7004  loss_mask: 0.4669  loss_rpn_cls: 0.02151  loss_rpn_loc: 0.05864  time: 0.2171  last_time: 0.2454  data_time: 0.0026  last_data_time: 0.0027   lr: 5.544e-05  max_mem: 3820M
# [02/25 22:18:51 d2.utils.events]:  eta: 0:25:26  iter: 119  total_loss: 1.822  loss_cls: 0.5382  loss_box_reg: 0.6532  loss_mask: 0.4136  loss_rpn_cls: 0.02602  loss_rpn_loc: 0.09793  time: 0.2125  last_time: 0.2284  data_time: 0.0059  last_data_time: 0.0022   lr: 6.659e-05  max_mem: 3820M
# [02/25 22:18:56 d2.utils.events]:  eta: 0:25:29  iter: 139  total_loss: 1.661  loss_cls: 0.5002  loss_box_reg: 0.6872  loss_mask: 0.3377  loss_rpn_cls: 0.01893  loss_rpn_loc: 0.06757  time: 0.2148  last_time: 0.2421  data_time: 0.0074  last_data_time: 0.0038   lr: 7.7739e-05  max_mem: 3820M
# [02/25 22:19:00 d2.utils.events]:  eta: 0:25:29  iter: 159  total_loss: 1.548  loss_cls: 0.4412  loss_box_reg: 0.6251  loss_mask: 0.3084  loss_rpn_cls: 0.01669  loss_rpn_loc: 0.07197  time: 0.2166  last_time: 0.2377  data_time: 0.0035  last_data_time: 0.0032   lr: 8.8889e-05  max_mem: 3820M
# [02/25 22:19:04 d2.utils.events]:  eta: 0:25:21  iter: 179  total_loss: 1.37  loss_cls: 0.4009  loss_box_reg: 0.5917  loss_mask: 0.2839  loss_rpn_cls: 0.01373  loss_rpn_loc: 0.0996  time: 0.2166  last_time: 0.2374  data_time: 0.0034  last_data_time: 0.0041   lr: 0.00010004  max_mem: 3820M
# [02/25 22:19:09 d2.utils.events]:  eta: 0:25:14  iter: 199  total_loss: 1.268  loss_cls: 0.3411  loss_box_reg: 0.6082  loss_mask: 0.2257  loss_rpn_cls: 0.01798  loss_rpn_loc: 0.06238  time: 0.2161  last_time: 0.2037  data_time: 0.0026  last_data_time: 0.0044   lr: 0.00011119  max_mem: 3820M
# [02/25 22:19:13 d2.utils.events]:  eta: 0:25:05  iter: 219  total_loss: 1.259  loss_cls: 0.3575  loss_box_reg: 0.558  loss_mask: 0.2221  loss_rpn_cls: 0.02077  loss_rpn_loc: 0.06965  time: 0.2147  last_time: 0.2315  data_time: 0.0072  last_data_time: 0.0023   lr: 0.00012234  max_mem: 3820M
# [02/25 22:19:17 d2.utils.events]:  eta: 0:25:03  iter: 239  total_loss: 1.099  loss_cls: 0.3323  loss_box_reg: 0.5355  loss_mask: 0.1852  loss_rpn_cls: 0.007964  loss_rpn_loc: 0.05246  time: 0.2154  last_time: 0.2266  data_time: 0.0039  last_data_time: 0.0026   lr: 0.00013349  max_mem: 3820M
# [02/25 22:19:22 d2.utils.events]:  eta: 0:24:59  iter: 259  total_loss: 1.061  loss_cls: 0.305  loss_box_reg: 0.4984  loss_mask: 0.1672  loss_rpn_cls: 0.03459  loss_rpn_loc: 0.07158  time: 0.2152  last_time: 0.1593  data_time: 0.0031  last_data_time: 0.0015   lr: 0.00014464  max_mem: 3820M
# [02/25 22:19:26 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in training: [ResizeShortestEdge(short_edge_length=(1024, 1024), max_size=1024)]
# [02/25 22:19:26 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [02/25 22:19:26 d2.data.common]: Serializing 22 elements to byte tensors and concatenating them all ...
# [02/25 22:19:26 d2.data.common]: Serialized dataset takes 7.37 MiB
# [02/25 22:19:28 detectron2]: Loss on Validation  done 11/22. 0.0000 s / img. ETA=0:00:00
# [02/25 22:19:32 detectron2]: VALIDATION_LOSS: 0.97710
# [02/25 22:19:32 d2.engine.hooks]: Saved first model at 0.97710 @ 267 steps
# [02/25 22:19:35 d2.utils.events]:  eta: 0:24:52  iter: 279  total_loss: 1.047  loss_cls: 0.2723  loss_box_reg: 0.4217  loss_mask: 0.145  loss_rpn_cls: 0.02116  loss_rpn_loc: 0.0739  validation_loss: 0.9771  time: 0.2151  last_time: 0.1882  data_time: 0.0030  last_data_time: 0.0034   lr: 0.00015579  max_mem: 3820M
# [02/25 22:19:39 d2.utils.events]:  eta: 0:24:48  iter: 299  total_loss: 0.8889  loss_cls: 0.2641  loss_box_reg: 0.3806  loss_mask: 0.16  loss_rpn_cls: 0.0208  loss_rpn_loc: 0.08267  validation_loss: 0.9771  time: 0.2148  last_time: 0.2316  data_time: 0.0034  last_data_time: 0.0030   lr: 0.00016694  max_mem: 3820M
# [02/25 22:19:43 d2.utils.events]:  eta: 0:24:45  iter: 319  total_loss: 0.6348  loss_cls: 0.2049  loss_box_reg: 0.2513  loss_mask: 0.1011  loss_rpn_cls: 0.01187  loss_rpn_loc: 0.04854  validation_loss: 0.9771  time: 0.2147  last_time: 0.1249  data_time: 0.0027  last_data_time: 0.0021   lr: 0.00017809  max_mem: 3820M
# [02/25 22:19:48 d2.utils.events]:  eta: 0:24:44  iter: 339  total_loss: 0.6184  loss_cls: 0.1821  loss_box_reg: 0.2389  loss_mask: 0.1068  loss_rpn_cls: 0.015  loss_rpn_loc: 0.05901  validation_loss: 0.9771  time: 0.2156  last_time: 0.2358  data_time: 0.0048  last_data_time: 0.0022   lr: 0.00018923  max_mem: 3820M
# [02/25 22:19:52 d2.utils.events]:  eta: 0:24:40  iter: 359  total_loss: 0.641  loss_cls: 0.2004  loss_box_reg: 0.2429  loss_mask: 0.1134  loss_rpn_cls: 0.00869  loss_rpn_loc: 0.05449  validation_loss: 0.9771  time: 0.2159  last_time: 0.2237  data_time: 0.0028  last_data_time: 0.0028   lr: 0.00020038  max_mem: 3820M
# [02/25 22:19:56 d2.utils.events]:  eta: 0:24:33  iter: 379  total_loss: 0.5741  loss_cls: 0.1685  loss_box_reg: 0.2028  loss_mask: 0.1114  loss_rpn_cls: 0.01811  loss_rpn_loc: 0.06987  validation_loss: 0.9771  time: 0.2150  last_time: 0.2403  data_time: 0.0039  last_data_time: 0.0164   lr: 0.00021153  max_mem: 3820M
# [02/25 22:20:01 d2.utils.events]:  eta: 0:24:30  iter: 399  total_loss: 0.5921  loss_cls: 0.1694  loss_box_reg: 0.1954  loss_mask: 0.1061  loss_rpn_cls: 0.007507  loss_rpn_loc: 0.08716  validation_loss: 0.9771  time: 0.2148  last_time: 0.2248  data_time: 0.0042  last_data_time: 0.0026   lr: 0.00022268  max_mem: 3820M
# [02/25 22:20:05 d2.utils.events]:  eta: 0:24:23  iter: 419  total_loss: 0.6099  loss_cls: 0.1708  loss_box_reg: 0.1851  loss_mask: 0.1216  loss_rpn_cls: 0.01073  loss_rpn_loc: 0.07672  validation_loss: 0.9771  time: 0.2144  last_time: 0.1725  data_time: 0.0032  last_data_time: 0.0037   lr: 0.00023383  max_mem: 3820M
# [02/25 22:20:09 d2.utils.events]:  eta: 0:24:18  iter: 439  total_loss: 0.544  loss_cls: 0.1556  loss_box_reg: 0.1641  loss_mask: 0.09441  loss_rpn_cls: 0.01054  loss_rpn_loc: 0.05654  validation_loss: 0.9771  time: 0.2140  last_time: 0.2375  data_time: 0.0039  last_data_time: 0.0027   lr: 0.00024498  max_mem: 3820M
# [02/25 22:20:13 d2.utils.events]:  eta: 0:24:14  iter: 459  total_loss: 0.4987  loss_cls: 0.1485  loss_box_reg: 0.185  loss_mask: 0.1026  loss_rpn_cls: 0.005646  loss_rpn_loc: 0.05869  validation_loss: 0.9771  time: 0.2141  last_time: 0.2351  data_time: 0.0061  last_data_time: 0.0025   lr: 0.00025  max_mem: 3820M
# [02/25 22:20:18 d2.utils.events]:  eta: 0:24:09  iter: 479  total_loss: 0.5886  loss_cls: 0.1267  loss_box_reg: 0.1927  loss_mask: 0.1102  loss_rpn_cls: 0.01345  loss_rpn_loc: 0.07267  validation_loss: 0.9771  time: 0.2141  last_time: 0.2230  data_time: 0.0037  last_data_time: 0.0038   lr: 0.00025  max_mem: 3820M
# [02/25 22:20:22 d2.utils.events]:  eta: 0:24:08  iter: 499  total_loss: 0.5101  loss_cls: 0.1081  loss_box_reg: 0.1343  loss_mask: 0.07977  loss_rpn_cls: 0.009821  loss_rpn_loc: 0.06764  validation_loss: 0.9771  time: 0.2148  last_time: 0.2390  data_time: 0.0026  last_data_time: 0.0033   lr: 0.00025  max_mem: 3820M
# [02/25 22:20:27 d2.utils.events]:  eta: 0:24:02  iter: 519  total_loss: 0.4622  loss_cls: 0.1101  loss_box_reg: 0.1523  loss_mask: 0.09039  loss_rpn_cls: 0.01942  loss_rpn_loc: 0.06306  validation_loss: 0.9771  time: 0.2148  last_time: 0.2021  data_time: 0.0036  last_data_time: 0.0036   lr: 0.00025  max_mem: 3820M
# [02/25 22:20:32 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in training: [ResizeShortestEdge(short_edge_length=(1024, 1024), max_size=1024)]
# [02/25 22:20:32 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [02/25 22:20:32 d2.data.common]: Serializing 22 elements to byte tensors and concatenating them all ...
# [02/25 22:20:33 d2.data.common]: Serialized dataset takes 7.37 MiB
# [02/25 22:20:34 detectron2]: Loss on Validation  done 11/22. 0.0000 s / img. ETA=0:00:00
# [02/25 22:20:39 detectron2]: VALIDATION_LOSS: 0.61304
# [02/25 22:20:39 d2.engine.hooks]: Saved best model as latest eval score for validation_loss is 0.61304, better than last best score 0.97710 @ iteration 267.
# [02/25 22:20:40 d2.utils.events]:  eta: 0:23:56  iter: 539  total_loss: 0.4747  loss_cls: 0.1319  loss_box_reg: 0.1611  loss_mask: 0.1078  loss_rpn_cls: 0.01165  loss_rpn_loc: 0.06502  validation_loss: 0.613  time: 0.2151  last_time: 0.2411  data_time: 0.0025  last_data_time: 0.0033   lr: 0.00025  max_mem: 3820M
# [02/25 22:20:44 d2.utils.events]:  eta: 0:23:51  iter: 559  total_loss: 0.5684  loss_cls: 0.127  loss_box_reg: 0.1685  loss_mask: 0.1344  loss_rpn_cls: 0.01367  loss_rpn_loc: 0.08445  validation_loss: 0.613  time: 0.2146  last_time: 0.2112  data_time: 0.0038  last_data_time: 0.0035   lr: 0.00025  max_mem: 3820M
# [02/25 22:20:49 d2.utils.events]:  eta: 0:23:47  iter: 579  total_loss: 0.405  loss_cls: 0.09841  loss_box_reg: 0.146  loss_mask: 0.08023  loss_rpn_cls: 0.01048  loss_rpn_loc: 0.05596  validation_loss: 0.613  time: 0.2145  last_time: 0.2097  data_time: 0.0038  last_data_time: 0.0025   lr: 0.00025  max_mem: 3820M
# [02/25 22:20:53 d2.utils.events]:  eta: 0:23:44  iter: 599  total_loss: 0.4649  loss_cls: 0.1219  loss_box_reg: 0.147  loss_mask: 0.09892  loss_rpn_cls: 0.006331  loss_rpn_loc: 0.04589  validation_loss: 0.613  time: 0.2148  last_time: 0.2435  data_time: 0.0036  last_data_time: 0.0015   lr: 0.00025  max_mem: 3820M
# [02/25 22:20:58 d2.utils.events]:  eta: 0:23:41  iter: 619  total_loss: 0.4954  loss_cls: 0.1059  loss_box_reg: 0.1715  loss_mask: 0.1037  loss_rpn_cls: 0.006825  loss_rpn_loc: 0.09533  validation_loss: 0.613  time: 0.2152  last_time: 0.2296  data_time: 0.0073  last_data_time: 0.0017   lr: 0.00025  max_mem: 3820M
# [02/25 22:21:02 d2.utils.events]:  eta: 0:23:36  iter: 639  total_loss: 0.3842  loss_cls: 0.1057  loss_box_reg: 0.1361  loss_mask: 0.07862  loss_rpn_cls: 0.008075  loss_rpn_loc: 0.04354  validation_loss: 0.613  time: 0.2150  last_time: 0.2373  data_time: 0.0026  last_data_time: 0.0008   lr: 0.00025  max_mem: 3820M
# [02/25 22:21:06 d2.utils.events]:  eta: 0:23:34  iter: 659  total_loss: 0.3895  loss_cls: 0.1157  loss_box_reg: 0.1275  loss_mask: 0.08291  loss_rpn_cls: 0.006654  loss_rpn_loc: 0.04868  validation_loss: 0.613  time: 0.2153  last_time: 0.1476  data_time: 0.0026  last_data_time: 0.0021   lr: 0.00025  max_mem: 3820M
# [02/25 22:21:11 d2.utils.events]:  eta: 0:23:30  iter: 679  total_loss: 0.4967  loss_cls: 0.09472  loss_box_reg: 0.1493  loss_mask: 0.118  loss_rpn_cls: 0.01325  loss_rpn_loc: 0.07122  validation_loss: 0.613  time: 0.2156  last_time: 0.1654  data_time: 0.0051  last_data_time: 0.0025   lr: 0.00025  max_mem: 3820M
# [02/25 22:21:15 d2.utils.events]:  eta: 0:23:25  iter: 699  total_loss: 0.4911  loss_cls: 0.107  loss_box_reg: 0.156  loss_mask: 0.1152  loss_rpn_cls: 0.00654  loss_rpn_loc: 0.05842  validation_loss: 0.613  time: 0.2157  last_time: 0.2419  data_time: 0.0027  last_data_time: 0.0027   lr: 0.00025  max_mem: 3820M
# [02/25 22:21:20 d2.utils.events]:  eta: 0:23:19  iter: 719  total_loss: 0.4219  loss_cls: 0.0965  loss_box_reg: 0.1384  loss_mask: 0.09231  loss_rpn_cls: 0.007481  loss_rpn_loc: 0.03959  validation_loss: 0.613  time: 0.2160  last_time: 0.2511  data_time: 0.0037  last_data_time: 0.0080   lr: 0.00025  max_mem: 3820M
# [02/25 22:21:24 d2.utils.events]:  eta: 0:23:15  iter: 739  total_loss: 0.3561  loss_cls: 0.09351  loss_box_reg: 0.1288  loss_mask: 0.07992  loss_rpn_cls: 0.005921  loss_rpn_loc: 0.05261  validation_loss: 0.613  time: 0.2159  last_time: 0.2393  data_time: 0.0028  last_data_time: 0.0034   lr: 0.00025  max_mem: 3820M
# [02/25 22:21:28 d2.utils.events]:  eta: 0:23:10  iter: 759  total_loss: 0.3732  loss_cls: 0.06846  loss_box_reg: 0.1193  loss_mask: 0.07242  loss_rpn_cls: 0.009581  loss_rpn_loc: 0.05307  validation_loss: 0.613  time: 0.2159  last_time: 0.2439  data_time: 0.0033  last_data_time: 0.0021   lr: 0.00025  max_mem: 3820M
# [02/25 22:21:33 d2.utils.events]:  eta: 0:23:04  iter: 779  total_loss: 0.4906  loss_cls: 0.1097  loss_box_reg: 0.1691  loss_mask: 0.1074  loss_rpn_cls: 0.01021  loss_rpn_loc: 0.08508  validation_loss: 0.613  time: 0.2159  last_time: 0.2419  data_time: 0.0046  last_data_time: 0.0046   lr: 0.00025  max_mem: 3820M
# [02/25 22:21:37 d2.utils.events]:  eta: 0:22:59  iter: 799  total_loss: 0.3998  loss_cls: 0.1001  loss_box_reg: 0.1549  loss_mask: 0.08333  loss_rpn_cls: 0.008084  loss_rpn_loc: 0.05949  validation_loss: 0.613  time: 0.2160  last_time: 0.1835  data_time: 0.0027  last_data_time: 0.0032   lr: 0.00025  max_mem: 3820M
# [02/25 22:21:40 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in training: [ResizeShortestEdge(short_edge_length=(1024, 1024), max_size=1024)]
# [02/25 22:21:40 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [02/25 22:21:40 d2.data.common]: Serializing 22 elements to byte tensors and concatenating them all ...
# [02/25 22:21:41 d2.data.common]: Serialized dataset takes 7.37 MiB
# [02/25 22:21:42 detectron2]: Loss on Validation  done 11/22. 0.0000 s / img. ETA=0:00:00
# [02/25 22:21:47 detectron2]: VALIDATION_LOSS: 0.57622
# [02/25 22:21:47 d2.engine.hooks]: Saved best model as latest eval score for validation_loss is 0.57622, better than last best score 0.61304 @ iteration 535.
# [02/25 22:21:51 d2.utils.events]:  eta: 0:22:54  iter: 819  total_loss: 0.3642  loss_cls: 0.09296  loss_box_reg: 0.1347  loss_mask: 0.08063  loss_rpn_cls: 0.01198  loss_rpn_loc: 0.04728  validation_loss: 0.5762  time: 0.2162  last_time: 0.1586  data_time: 0.0060  last_data_time: 0.0026   lr: 0.00025  max_mem: 3820M
# [02/25 22:21:55 d2.utils.events]:  eta: 0:22:49  iter: 839  total_loss: 0.3731  loss_cls: 0.08125  loss_box_reg: 0.1374  loss_mask: 0.08624  loss_rpn_cls: 0.008311  loss_rpn_loc: 0.07729  validation_loss: 0.5762  time: 0.2162  last_time: 0.1339  data_time: 0.0031  last_data_time: 0.0020   lr: 0.00025  max_mem: 3820M
# [02/25 22:21:59 d2.utils.events]:  eta: 0:22:45  iter: 859  total_loss: 0.3939  loss_cls: 0.09219  loss_box_reg: 0.1227  loss_mask: 0.08007  loss_rpn_cls: 0.01086  loss_rpn_loc: 0.1025  validation_loss: 0.5762  time: 0.2162  last_time: 0.2119  data_time: 0.0032  last_data_time: 0.0021   lr: 0.00025  max_mem: 3820M
# [02/25 22:22:04 d2.utils.events]:  eta: 0:22:40  iter: 879  total_loss: 0.4042  loss_cls: 0.08609  loss_box_reg: 0.1366  loss_mask: 0.1031  loss_rpn_cls: 0.009999  loss_rpn_loc: 0.05114  validation_loss: 0.5762  time: 0.2162  last_time: 0.1385  data_time: 0.0041  last_data_time: 0.0015   lr: 0.00025  max_mem: 3820M
# [02/25 22:22:08 d2.utils.events]:  eta: 0:22:35  iter: 899  total_loss: 0.5583  loss_cls: 0.09627  loss_box_reg: 0.1536  loss_mask: 0.1038  loss_rpn_cls: 0.01387  loss_rpn_loc: 0.09537  validation_loss: 0.5762  time: 0.2158  last_time: 0.0945  data_time: 0.0029  last_data_time: 0.0028   lr: 0.00025  max_mem: 3820M
# [02/25 22:22:12 d2.utils.events]:  eta: 0:22:29  iter: 919  total_loss: 0.5058  loss_cls: 0.09911  loss_box_reg: 0.1679  loss_mask: 0.1181  loss_rpn_cls: 0.009397  loss_rpn_loc: 0.05941  validation_loss: 0.5762  time: 0.2159  last_time: 0.2254  data_time: 0.0046  last_data_time: 0.0032   lr: 0.00025  max_mem: 3820M
# [02/25 22:22:16 d2.utils.events]:  eta: 0:22:23  iter: 939  total_loss: 0.5076  loss_cls: 0.1051  loss_box_reg: 0.1977  loss_mask: 0.119  loss_rpn_cls: 0.01323  loss_rpn_loc: 0.09362  validation_loss: 0.5762  time: 0.2154  last_time: 0.1974  data_time: 0.0027  last_data_time: 0.0059   lr: 0.00025  max_mem: 3820M
# [02/25 22:22:20 d2.utils.events]:  eta: 0:22:18  iter: 959  total_loss: 0.3796  loss_cls: 0.07905  loss_box_reg: 0.1278  loss_mask: 0.07689  loss_rpn_cls: 0.01574  loss_rpn_loc: 0.08732  validation_loss: 0.5762  time: 0.2152  last_time: 0.2435  data_time: 0.0065  last_data_time: 0.0029   lr: 0.00025  max_mem: 3820M
# [02/25 22:22:24 d2.utils.events]:  eta: 0:22:12  iter: 979  total_loss: 0.5543  loss_cls: 0.09905  loss_box_reg: 0.1865  loss_mask: 0.1097  loss_rpn_cls: 0.005781  loss_rpn_loc: 0.06432  validation_loss: 0.5762  time: 0.2148  last_time: 0.1386  data_time: 0.0051  last_data_time: 0.0019   lr: 0.00025  max_mem: 3820M
# [02/25 22:22:29 d2.utils.events]:  eta: 0:22:08  iter: 999  total_loss: 0.3699  loss_cls: 0.08201  loss_box_reg: 0.1344  loss_mask: 0.07801  loss_rpn_cls: 0.008246  loss_rpn_loc: 0.05598  validation_loss: 0.5762  time: 0.2148  last_time: 0.1566  data_time: 0.0033  last_data_time: 0.0020   lr: 0.00025  max_mem: 3820M
# [02/25 22:22:33 d2.utils.events]:  eta: 0:22:03  iter: 1019  total_loss: 0.4598  loss_cls: 0.1035  loss_box_reg: 0.153  loss_mask: 0.09789  loss_rpn_cls: 0.0087  loss_rpn_loc: 0.09092  validation_loss: 0.5762  time: 0.2145  last_time: 0.2302  data_time: 0.0038  last_data_time: 0.0038   lr: 0.00025  max_mem: 3820M
# [02/25 22:22:37 d2.utils.events]:  eta: 0:21:58  iter: 1039  total_loss: 0.379  loss_cls: 0.07589  loss_box_reg: 0.1299  loss_mask: 0.08126  loss_rpn_cls: 0.01084  loss_rpn_loc: 0.07565  validation_loss: 0.5762  time: 0.2144  last_time: 0.2460  data_time: 0.0030  last_data_time: 0.0046   lr: 0.00025  max_mem: 3820M
# [02/25 22:22:41 d2.utils.events]:  eta: 0:21:52  iter: 1059  total_loss: 0.335  loss_cls: 0.07184  loss_box_reg: 0.126  loss_mask: 0.07722  loss_rpn_cls: 0.00558  loss_rpn_loc: 0.05661  validation_loss: 0.5762  time: 0.2144  last_time: 0.1513  data_time: 0.0034  last_data_time: 0.0032   lr: 0.00025  max_mem: 3820M
# [02/25 22:22:46 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in training: [ResizeShortestEdge(short_edge_length=(1024, 1024), max_size=1024)]
# [02/25 22:22:46 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [02/25 22:22:46 d2.data.common]: Serializing 22 elements to byte tensors and concatenating them all ...
# [02/25 22:22:46 d2.data.common]: Serialized dataset takes 7.37 MiB
# [02/25 22:22:48 detectron2]: Loss on Validation  done 11/22. 0.0000 s / img. ETA=0:00:00
# [02/25 22:22:52 detectron2]: VALIDATION_LOSS: 0.53712
# [02/25 22:22:53 d2.engine.hooks]: Saved best model as latest eval score for validation_loss is 0.53712, better than last best score 0.57622 @ iteration 803.
# [02/25 22:22:55 d2.utils.events]:  eta: 0:21:47  iter: 1079  total_loss: 0.4025  loss_cls: 0.09649  loss_box_reg: 0.1552  loss_mask: 0.09997  loss_rpn_cls: 0.003209  loss_rpn_loc: 0.04216  validation_loss: 0.5371  time: 0.2145  last_time: 0.2362  data_time: 0.0048  last_data_time: 0.0022   lr: 0.00025  max_mem: 3820M
# [02/25 22:22:59 d2.utils.events]:  eta: 0:21:41  iter: 1099  total_loss: 0.3437  loss_cls: 0.08143  loss_box_reg: 0.1195  loss_mask: 0.06914  loss_rpn_cls: 0.008825  loss_rpn_loc: 0.05699  validation_loss: 0.5371  time: 0.2147  last_time: 0.2405  data_time: 0.0033  last_data_time: 0.0035   lr: 0.00025  max_mem: 3820M
# [02/25 22:23:04 d2.utils.events]:  eta: 0:21:40  iter: 1119  total_loss: 0.3029  loss_cls: 0.06267  loss_box_reg: 0.1141  loss_mask: 0.0691  loss_rpn_cls: 0.01071  loss_rpn_loc: 0.05163  validation_loss: 0.5371  time: 0.2148  last_time: 0.1048  data_time: 0.0034  last_data_time: 0.0018   lr: 0.00025  max_mem: 3820M
# [02/25 22:23:08 d2.utils.events]:  eta: 0:21:34  iter: 1139  total_loss: 0.2856  loss_cls: 0.07911  loss_box_reg: 0.09972  loss_mask: 0.06634  loss_rpn_cls: 0.006789  loss_rpn_loc: 0.04071  validation_loss: 0.5371  time: 0.2146  last_time: 0.2413  data_time: 0.0036  last_data_time: 0.0022   lr: 0.00025  max_mem: 3820M
# [02/25 22:23:12 d2.utils.events]:  eta: 0:21:27  iter: 1159  total_loss: 0.4527  loss_cls: 0.07681  loss_box_reg: 0.1397  loss_mask: 0.09526  loss_rpn_cls: 0.01204  loss_rpn_loc: 0.05438  validation_loss: 0.5371  time: 0.2146  last_time: 0.2348  data_time: 0.0034  last_data_time: 0.0022   lr: 0.00025  max_mem: 3820M
# [02/25 22:23:17 d2.utils.events]:  eta: 0:21:25  iter: 1179  total_loss: 0.2806  loss_cls: 0.06749  loss_box_reg: 0.1094  loss_mask: 0.07068  loss_rpn_cls: 0.009063  loss_rpn_loc: 0.03817  validation_loss: 0.5371  time: 0.2149  last_time: 0.2445  data_time: 0.0042  last_data_time: 0.0041   lr: 0.00025  max_mem: 3820M
# [02/25 22:23:21 d2.utils.events]:  eta: 0:21:20  iter: 1199  total_loss: 0.3504  loss_cls: 0.06064  loss_box_reg: 0.1352  loss_mask: 0.0792  loss_rpn_cls: 0.01077  loss_rpn_loc: 0.05951  validation_loss: 0.5371  time: 0.2149  last_time: 0.2307  data_time: 0.0044  last_data_time: 0.0144   lr: 0.00025  max_mem: 3820M
# ...
# [02/25 22:43:00 d2.data.common]: Serializing 22 elements to byte tensors and concatenating them all ...
# [02/25 22:43:00 d2.data.common]: Serialized dataset takes 7.37 MiB
# [02/25 22:43:02 detectron2]: Loss on Validation  done 11/22. 0.0000 s / img. ETA=0:00:00
# [02/25 22:43:06 detectron2]: VALIDATION_LOSS: 0.46474
# [02/25 22:43:06 d2.engine.hooks]: Not saving as latest eval score for validation_loss is 0.46474, not better than best score 0.45458 @ iteration 4019.
# [02/25 22:43:07 d2.utils.events]:  eta: 0:03:08  iter: 5899  total_loss: 0.3378  loss_cls: 0.05287  loss_box_reg: 0.122  loss_mask: 0.08708  loss_rpn_cls: 0.002778  loss_rpn_loc: 0.05019  validation_loss: 0.4647  time: 0.2171  last_time: 0.2467  data_time: 0.0044  last_data_time: 0.0037   lr: 2.5e-06  max_mem: 3820M
# [02/25 22:43:12 d2.utils.events]:  eta: 0:03:03  iter: 5919  total_loss: 0.2139  loss_cls: 0.03965  loss_box_reg: 0.08296  loss_mask: 0.05619  loss_rpn_cls: 0.001581  loss_rpn_loc: 0.02193  validation_loss: 0.4647  time: 0.2171  last_time: 0.2417  data_time: 0.0030  last_data_time: 0.0005   lr: 2.5e-06  max_mem: 3820M
# [02/25 22:43:16 d2.utils.events]:  eta: 0:02:58  iter: 5939  total_loss: 0.1603  loss_cls: 0.02717  loss_box_reg: 0.06642  loss_mask: 0.04538  loss_rpn_cls: 0.001043  loss_rpn_loc: 0.02131  validation_loss: 0.4647  time: 0.2171  last_time: 0.2542  data_time: 0.0027  last_data_time: 0.0041   lr: 2.5e-06  max_mem: 3820M
# [02/25 22:43:20 d2.utils.events]:  eta: 0:02:54  iter: 5959  total_loss: 0.3405  loss_cls: 0.05745  loss_box_reg: 0.1352  loss_mask: 0.1021  loss_rpn_cls: 0.003446  loss_rpn_loc: 0.0425  validation_loss: 0.4647  time: 0.2170  last_time: 0.2130  data_time: 0.0026  last_data_time: 0.0020   lr: 2.5e-06  max_mem: 3820M
# [02/25 22:43:24 d2.utils.events]:  eta: 0:02:49  iter: 5979  total_loss: 0.3093  loss_cls: 0.06697  loss_box_reg: 0.1229  loss_mask: 0.07825  loss_rpn_cls: 0.00727  loss_rpn_loc: 0.04053  validation_loss: 0.4647  time: 0.2170  last_time: 0.2362  data_time: 0.0025  last_data_time: 0.0017   lr: 2.5e-06  max_mem: 3820M
# [02/25 22:43:29 d2.utils.events]:  eta: 0:02:44  iter: 5999  total_loss: 0.223  loss_cls: 0.0338  loss_box_reg: 0.09785  loss_mask: 0.06486  loss_rpn_cls: 0.002065  loss_rpn_loc: 0.03121  validation_loss: 0.4647  time: 0.2170  last_time: 0.2489  data_time: 0.0058  last_data_time: 0.0008   lr: 2.5e-06  max_mem: 3820M
# [02/25 22:43:33 d2.utils.events]:  eta: 0:02:40  iter: 6019  total_loss: 0.2699  loss_cls: 0.04438  loss_box_reg: 0.1107  loss_mask: 0.07244  loss_rpn_cls: 0.004091  loss_rpn_loc: 0.04174  validation_loss: 0.4647  time: 0.2170  last_time: 0.2406  data_time: 0.0025  last_data_time: 0.0027   lr: 2.5e-06  max_mem: 3820M
# [02/25 22:43:37 d2.utils.events]:  eta: 0:02:35  iter: 6039  total_loss: 0.2099  loss_cls: 0.03259  loss_box_reg: 0.08214  loss_mask: 0.05664  loss_rpn_cls: 0.003289  loss_rpn_loc: 0.03605  validation_loss: 0.4647  time: 0.2170  last_time: 0.2235  data_time: 0.0027  last_data_time: 0.0034   lr: 2.5e-06  max_mem: 3820M
# [02/25 22:43:42 d2.utils.events]:  eta: 0:02:30  iter: 6059  total_loss: 0.233  loss_cls: 0.036  loss_box_reg: 0.09137  loss_mask: 0.06381  loss_rpn_cls: 0.003509  loss_rpn_loc: 0.03725  validation_loss: 0.4647  time: 0.2170  last_time: 0.1688  data_time: 0.0036  last_data_time: 0.0021   lr: 2.5e-06  max_mem: 3820M
# [02/25 22:43:46 d2.utils.events]:  eta: 0:02:26  iter: 6079  total_loss: 0.1794  loss_cls: 0.03206  loss_box_reg: 0.07239  loss_mask: 0.05046  loss_rpn_cls: 0.001266  loss_rpn_loc: 0.02473  validation_loss: 0.4647  time: 0.2170  last_time: 0.2328  data_time: 0.0026  last_data_time: 0.0027   lr: 2.5e-06  max_mem: 3820M
# [02/25 22:43:50 d2.utils.events]:  eta: 0:02:21  iter: 6099  total_loss: 0.3093  loss_cls: 0.0481  loss_box_reg: 0.1233  loss_mask: 0.08153  loss_rpn_cls: 0.004985  loss_rpn_loc: 0.0618  validation_loss: 0.4647  time: 0.2170  last_time: 0.2363  data_time: 0.0026  last_data_time: 0.0023   lr: 2.5e-06  max_mem: 3820M
# [02/25 22:43:54 d2.utils.events]:  eta: 0:02:16  iter: 6119  total_loss: 0.2741  loss_cls: 0.04298  loss_box_reg: 0.1082  loss_mask: 0.07579  loss_rpn_cls: 0.005343  loss_rpn_loc: 0.03253  validation_loss: 0.4647  time: 0.2169  last_time: 0.2580  data_time: 0.0064  last_data_time: 0.0384   lr: 2.5e-06  max_mem: 3820M
# [02/25 22:43:59 d2.utils.events]:  eta: 0:02:11  iter: 6139  total_loss: 0.218  loss_cls: 0.03602  loss_box_reg: 0.08933  loss_mask: 0.06121  loss_rpn_cls: 0.001881  loss_rpn_loc: 0.02468  validation_loss: 0.4647  time: 0.2169  last_time: 0.2411  data_time: 0.0027  last_data_time: 0.0035   lr: 2.5e-06  max_mem: 3820M
# [02/25 22:44:03 d2.utils.events]:  eta: 0:02:06  iter: 6159  total_loss: 0.2839  loss_cls: 0.05315  loss_box_reg: 0.1032  loss_mask: 0.1003  loss_rpn_cls: 0.003512  loss_rpn_loc: 0.03712  validation_loss: 0.4647  time: 0.2169  last_time: 0.2388  data_time: 0.0031  last_data_time: 0.0007   lr: 2.5e-06  max_mem: 3820M
# [02/25 22:44:06 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in training: [ResizeShortestEdge(short_edge_length=(1024, 1024), max_size=1024)]
# [02/25 22:44:06 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [02/25 22:44:06 d2.data.common]: Serializing 22 elements to byte tensors and concatenating them all ...
# [02/25 22:44:07 d2.data.common]: Serialized dataset takes 7.37 MiB
# [02/25 22:44:08 detectron2]: Loss on Validation  done 11/22. 0.0000 s / img. ETA=0:00:00
# [02/25 22:44:13 detectron2]: VALIDATION_LOSS: 0.46154
# [02/25 22:44:13 d2.engine.hooks]: Not saving as latest eval score for validation_loss is 0.46154, not better than best score 0.45458 @ iteration 4019.
# [02/25 22:44:16 d2.utils.events]:  eta: 0:02:02  iter: 6179  total_loss: 0.1625  loss_cls: 0.03551  loss_box_reg: 0.07252  loss_mask: 0.05173  loss_rpn_cls: 0.002283  loss_rpn_loc: 0.02216  validation_loss: 0.4615  time: 0.2169  last_time: 0.2396  data_time: 0.0047  last_data_time: 0.0035   lr: 2.5e-06  max_mem: 3820M
# [02/25 22:44:20 d2.utils.events]:  eta: 0:01:57  iter: 6199  total_loss: 0.2715  loss_cls: 0.03743  loss_box_reg: 0.09676  loss_mask: 0.07448  loss_rpn_cls: 0.004737  loss_rpn_loc: 0.03485  validation_loss: 0.4615  time: 0.2169  last_time: 0.2247  data_time: 0.0035  last_data_time: 0.0018   lr: 2.5e-06  max_mem: 3820M
# [02/25 22:44:25 d2.utils.events]:  eta: 0:01:52  iter: 6219  total_loss: 0.208  loss_cls: 0.03183  loss_box_reg: 0.07474  loss_mask: 0.05054  loss_rpn_cls: 0.002537  loss_rpn_loc: 0.02349  validation_loss: 0.4615  time: 0.2170  last_time: 0.2336  data_time: 0.0047  last_data_time: 0.0028   lr: 2.5e-06  max_mem: 3820M
# [02/25 22:44:29 d2.utils.events]:  eta: 0:01:47  iter: 6239  total_loss: 0.2971  loss_cls: 0.04013  loss_box_reg: 0.1047  loss_mask: 0.07026  loss_rpn_cls: 0.007957  loss_rpn_loc: 0.05831  validation_loss: 0.4615  time: 0.2169  last_time: 0.2264  data_time: 0.0045  last_data_time: 0.0016   lr: 2.5e-06  max_mem: 3820M
# [02/25 22:44:34 d2.utils.events]:  eta: 0:01:43  iter: 6259  total_loss: 0.2005  loss_cls: 0.03037  loss_box_reg: 0.08192  loss_mask: 0.0537  loss_rpn_cls: 0.00176  loss_rpn_loc: 0.02446  validation_loss: 0.4615  time: 0.2170  last_time: 0.1688  data_time: 0.0031  last_data_time: 0.0024   lr: 2.5e-06  max_mem: 3820M
# [02/25 22:44:38 d2.utils.events]:  eta: 0:01:38  iter: 6279  total_loss: 0.2978  loss_cls: 0.04864  loss_box_reg: 0.1159  loss_mask: 0.08135  loss_rpn_cls: 0.005333  loss_rpn_loc: 0.04002  validation_loss: 0.4615  time: 0.2170  last_time: 0.2459  data_time: 0.0044  last_data_time: 0.0023   lr: 2.5e-06  max_mem: 3820M
# [02/25 22:44:43 d2.utils.events]:  eta: 0:01:33  iter: 6299  total_loss: 0.2948  loss_cls: 0.04911  loss_box_reg: 0.1103  loss_mask: 0.07485  loss_rpn_cls: 0.00614  loss_rpn_loc: 0.05357  validation_loss: 0.4615  time: 0.2170  last_time: 0.2300  data_time: 0.0026  last_data_time: 0.0029   lr: 2.5e-06  max_mem: 3820M
# [02/25 22:44:47 d2.utils.events]:  eta: 0:01:29  iter: 6319  total_loss: 0.2196  loss_cls: 0.04285  loss_box_reg: 0.08582  loss_mask: 0.06066  loss_rpn_cls: 0.003198  loss_rpn_loc: 0.03404  validation_loss: 0.4615  time: 0.2170  last_time: 0.2424  data_time: 0.0032  last_data_time: 0.0026   lr: 2.5e-06  max_mem: 3820M
# [02/25 22:44:51 d2.utils.events]:  eta: 0:01:24  iter: 6339  total_loss: 0.2445  loss_cls: 0.03517  loss_box_reg: 0.09777  loss_mask: 0.07521  loss_rpn_cls: 0.004063  loss_rpn_loc: 0.03752  validation_loss: 0.4615  time: 0.2170  last_time: 0.2415  data_time: 0.0026  last_data_time: 0.0020   lr: 2.5e-06  max_mem: 3820M
# [02/25 22:44:56 d2.utils.events]:  eta: 0:01:19  iter: 6359  total_loss: 0.2221  loss_cls: 0.04232  loss_box_reg: 0.09197  loss_mask: 0.06417  loss_rpn_cls: 0.002466  loss_rpn_loc: 0.03109  validation_loss: 0.4615  time: 0.2170  last_time: 0.2423  data_time: 0.0066  last_data_time: 0.0008   lr: 2.5e-06  max_mem: 3820M
# [02/25 22:45:01 d2.utils.events]:  eta: 0:01:15  iter: 6379  total_loss: 0.2461  loss_cls: 0.04053  loss_box_reg: 0.09064  loss_mask: 0.06609  loss_rpn_cls: 0.003098  loss_rpn_loc: 0.04114  validation_loss: 0.4615  time: 0.2171  last_time: 0.2809  data_time: 0.0049  last_data_time: 0.0411   lr: 2.5e-06  max_mem: 3820M
# [02/25 22:45:05 d2.utils.events]:  eta: 0:01:10  iter: 6399  total_loss: 0.2213  loss_cls: 0.0355  loss_box_reg: 0.09661  loss_mask: 0.06031  loss_rpn_cls: 0.002883  loss_rpn_loc: 0.0319  validation_loss: 0.4615  time: 0.2170  last_time: 0.2378  data_time: 0.0029  last_data_time: 0.0023   lr: 2.5e-06  max_mem: 3820M
# [02/25 22:45:09 d2.utils.events]:  eta: 0:01:05  iter: 6419  total_loss: 0.2633  loss_cls: 0.03624  loss_box_reg: 0.1106  loss_mask: 0.07161  loss_rpn_cls: 0.003806  loss_rpn_loc: 0.03715  validation_loss: 0.4615  time: 0.2170  last_time: 0.1680  data_time: 0.0043  last_data_time: 0.0012   lr: 2.5e-06  max_mem: 3820M
# [02/25 22:45:14 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in training: [ResizeShortestEdge(short_edge_length=(1024, 1024), max_size=1024)]
# [02/25 22:45:14 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [02/25 22:45:14 d2.data.common]: Serializing 22 elements to byte tensors and concatenating them all ...
# [02/25 22:45:14 d2.data.common]: Serialized dataset takes 7.37 MiB
# [02/25 22:45:16 detectron2]: Loss on Validation  done 11/22. 0.0000 s / img. ETA=0:00:00
# [02/25 22:45:20 detectron2]: VALIDATION_LOSS: 0.45896
# [02/25 22:45:20 d2.engine.hooks]: Not saving as latest eval score for validation_loss is 0.45896, not better than best score 0.45458 @ iteration 4019.
# [02/25 22:45:22 d2.utils.events]:  eta: 0:01:01  iter: 6439  total_loss: 0.2213  loss_cls: 0.03795  loss_box_reg: 0.09067  loss_mask: 0.06062  loss_rpn_cls: 0.00193  loss_rpn_loc: 0.02956  validation_loss: 0.459  time: 0.2170  last_time: 0.2406  data_time: 0.0056  last_data_time: 0.0032   lr: 2.5e-06  max_mem: 3820M
# [02/25 22:45:27 d2.utils.events]:  eta: 0:00:56  iter: 6459  total_loss: 0.1939  loss_cls: 0.0353  loss_box_reg: 0.07827  loss_mask: 0.04973  loss_rpn_cls: 0.002047  loss_rpn_loc: 0.02519  validation_loss: 0.459  time: 0.2171  last_time: 0.2206  data_time: 0.0025  last_data_time: 0.0034   lr: 2.5e-06  max_mem: 3820M
# [02/25 22:45:31 d2.utils.events]:  eta: 0:00:51  iter: 6479  total_loss: 0.2137  loss_cls: 0.03222  loss_box_reg: 0.09138  loss_mask: 0.06426  loss_rpn_cls: 0.001635  loss_rpn_loc: 0.02759  validation_loss: 0.459  time: 0.2171  last_time: 0.1694  data_time: 0.0032  last_data_time: 0.0025   lr: 2.5e-06  max_mem: 3820M
# [02/25 22:45:36 d2.utils.events]:  eta: 0:00:47  iter: 6499  total_loss: 0.2573  loss_cls: 0.04845  loss_box_reg: 0.1004  loss_mask: 0.07152  loss_rpn_cls: 0.001609  loss_rpn_loc: 0.03277  validation_loss: 0.459  time: 0.2171  last_time: 0.1966  data_time: 0.0026  last_data_time: 0.0019   lr: 2.5e-06  max_mem: 3820M
# [02/25 22:45:40 d2.utils.events]:  eta: 0:00:42  iter: 6519  total_loss: 0.2378  loss_cls: 0.03927  loss_box_reg: 0.08055  loss_mask: 0.05576  loss_rpn_cls: 0.002908  loss_rpn_loc: 0.03823  validation_loss: 0.459  time: 0.2171  last_time: 0.2355  data_time: 0.0026  last_data_time: 0.0027   lr: 2.5e-06  max_mem: 3820M
# [02/25 22:45:44 d2.utils.events]:  eta: 0:00:37  iter: 6539  total_loss: 0.2555  loss_cls: 0.03982  loss_box_reg: 0.1026  loss_mask: 0.07157  loss_rpn_cls: 0.006192  loss_rpn_loc: 0.03605  validation_loss: 0.459  time: 0.2171  last_time: 0.2632  data_time: 0.0036  last_data_time: 0.0223   lr: 2.5e-06  max_mem: 3820M
# [02/25 22:45:49 d2.utils.events]:  eta: 0:00:32  iter: 6559  total_loss: 0.2227  loss_cls: 0.03755  loss_box_reg: 0.09478  loss_mask: 0.06789  loss_rpn_cls: 0.00234  loss_rpn_loc: 0.03306  validation_loss: 0.459  time: 0.2171  last_time: 0.2280  data_time: 0.0028  last_data_time: 0.0031   lr: 2.5e-06  max_mem: 3820M
# [02/25 22:45:53 d2.utils.events]:  eta: 0:00:28  iter: 6579  total_loss: 0.271  loss_cls: 0.04136  loss_box_reg: 0.1045  loss_mask: 0.07247  loss_rpn_cls: 0.005893  loss_rpn_loc: 0.05546  validation_loss: 0.459  time: 0.2170  last_time: 0.2232  data_time: 0.0028  last_data_time: 0.0019   lr: 2.5e-06  max_mem: 3820M
# [02/25 22:45:57 d2.utils.events]:  eta: 0:00:23  iter: 6599  total_loss: 0.2963  loss_cls: 0.03979  loss_box_reg: 0.08908  loss_mask: 0.06231  loss_rpn_cls: 0.002424  loss_rpn_loc: 0.04857  validation_loss: 0.459  time: 0.2170  last_time: 0.1483  data_time: 0.0049  last_data_time: 0.0035   lr: 2.5e-06  max_mem: 3820M
# [02/25 22:46:02 d2.utils.events]:  eta: 0:00:18  iter: 6619  total_loss: 0.3622  loss_cls: 0.06503  loss_box_reg: 0.1426  loss_mask: 0.08018  loss_rpn_cls: 0.003044  loss_rpn_loc: 0.04232  validation_loss: 0.459  time: 0.2170  last_time: 0.2356  data_time: 0.0033  last_data_time: 0.0043   lr: 2.5e-06  max_mem: 3820M
# [02/25 22:46:06 d2.utils.events]:  eta: 0:00:14  iter: 6639  total_loss: 0.2474  loss_cls: 0.0313  loss_box_reg: 0.1043  loss_mask: 0.06703  loss_rpn_cls: 0.004447  loss_rpn_loc: 0.03291  validation_loss: 0.459  time: 0.2171  last_time: 0.2425  data_time: 0.0061  last_data_time: 0.0010   lr: 2.5e-06  max_mem: 3820M
# [02/25 22:46:11 d2.utils.events]:  eta: 0:00:09  iter: 6659  total_loss: 0.2841  loss_cls: 0.03985  loss_box_reg: 0.1081  loss_mask: 0.06986  loss_rpn_cls: 0.003234  loss_rpn_loc: 0.04705  validation_loss: 0.459  time: 0.2171  last_time: 0.1969  data_time: 0.0026  last_data_time: 0.0031   lr: 2.5e-06  max_mem: 3820M
# [02/25 22:46:15 d2.utils.events]:  eta: 0:00:04  iter: 6679  total_loss: 0.2155  loss_cls: 0.03559  loss_box_reg: 0.07417  loss_mask: 0.05512  loss_rpn_cls: 0.002089  loss_rpn_loc: 0.02461  validation_loss: 0.459  time: 0.2171  last_time: 0.2293  data_time: 0.0029  last_data_time: 0.0034   lr: 2.5e-06  max_mem: 3820M
# [02/25 22:46:19 d2.utils.events]:  eta: 0:00:00  iter: 6699  total_loss: 0.1917  loss_cls: 0.0252  loss_box_reg: 0.0799  loss_mask: 0.05917  loss_rpn_cls: 0.003902  loss_rpn_loc: 0.03063  validation_loss: 0.459  time: 0.2171  last_time: 0.2325  data_time: 0.0036  last_data_time: 0.0021   lr: 2.5e-06  max_mem: 3820M
# [02/25 22:46:19 d2.engine.hooks]: Overall training speed: 6698 iterations in 0:24:13 (0.2171 s / it)
# [02/25 22:46:19 d2.engine.hooks]: Total training time: 0:27:53 (0:03:39 on hooks)
# [02/25 22:46:21 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in training: [ResizeShortestEdge(short_edge_length=(1024, 1024), max_size=1024)]
# [02/25 22:46:21 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [02/25 22:46:21 d2.data.common]: Serializing 22 elements to byte tensors and concatenating them all ...
# [02/25 22:46:22 d2.data.common]: Serialized dataset takes 7.37 MiB
# [02/25 22:46:23 detectron2]: Loss on Validation  done 11/22. 0.0000 s / img. ETA=0:00:00
# [02/25 22:46:28 detectron2]: VALIDATION_LOSS: 0.46237
# [02/25 22:46:28 d2.engine.hooks]: Not saving as latest eval score for validation_loss is 0.46237, not better than best score 0.45458 @ iteration 4019.

# %% [markdown]
# ### Plot Training and Validation Curves

# %%
def load_json_arr(json_path):
    train, val = [], []
    with open(json_path, "r") as f:
        for line in f:
            line = json.loads(line)
            if "validation_loss" in line:
                val.append(line)
            elif "total_loss" in line:
                train.append(line)
    return train, val

# %%
train_metrics, val_metrics = load_json_arr(os.path.join(cfg.OUTPUT_DIR, "metrics.json"))
train_metrics = train_metrics[2:]

# %%
train_iters = [x["iteration"] for x in train_metrics]
train_loss = [x["total_loss"] for x in train_metrics]

val_iters = [x["iteration"] for x in val_metrics]
val_loss = [x["validation_loss"] for x in val_metrics]

# %%
plt.plot(train_iters, train_loss)
plt.plot(val_iters, val_loss)
plt.xlabel("iters")
plt.ylabel("loss")
plt.title("train/val loss")
plt.legend(["training loss", "validation loss"], loc="upper right")
plt.show()

# %% [markdown]
# ### Evalatuate Model on Mixed Testset
#
# Using Default Predictor with Threshold of 0.7

# %%
cfg.MODEL.WEIGHTS = os.path.join(cfg.OUTPUT_DIR, "model_best.pth")
cfg.MODEL.ROI_HEADS.SCORE_THRESH_TEST = 0.7
predictor = DefaultPredictor(cfg)
# Out:
# [02/26 00:06:10 d2.checkpoint.detection_checkpoint]: [DetectionCheckpointer] Loading from ./models/combined_segmentation/model_best.pth ...

# %%
evaluator = COCOEvaluator(
    dataset_name="mixed_test",
    output_dir=os.path.join(cfg.OUTPUT_DIR, "inference", "mixed"),
    allow_cached_coco=False,
    max_dets_per_image=1000,
    use_fast_impl=False,
)
testloader = build_detection_test_loader(cfg, "mixed_test")
print(inference_on_dataset(predictor.model, testloader, evaluator))
# Out:
# [02/26 00:06:26 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in inference: [ResizeShortestEdge(short_edge_length=(800, 800), max_size=1333, sample_style='choice')]
# [02/26 00:06:26 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [02/26 00:06:26 d2.data.common]: Serializing 23 elements to byte tensors and concatenating them all ...
# [02/26 00:06:26 d2.data.common]: Serialized dataset takes 3.90 MiB
# [02/26 00:06:26 d2.evaluation.evaluator]: Start inference on 23 batches
# [02/26 00:06:27 d2.evaluation.evaluator]: Inference done 11/23. Dataloading: 0.0004 s/iter. Inference: 0.0388 s/iter. Eval: 0.0320 s/iter. Total: 0.0713 s/iter. ETA=0:00:00
# [02/26 00:06:31 d2.evaluation.evaluator]: Total inference time: 0:00:04.750771 (0.263932 s / iter per device, on 1 devices)
# [02/26 00:06:31 d2.evaluation.evaluator]: Total inference pure compute time: 0:00:00 (0.043871 s / iter per device, on 1 devices)
# [02/26 00:06:31 d2.evaluation.coco_evaluation]: Preparing results for COCO format ...
# [02/26 00:06:31 d2.evaluation.coco_evaluation]: Saving results to ./models/combined_segmentation/inference/mixed/coco_instances_results.json
# [02/26 00:06:31 d2.evaluation.coco_evaluation]: Evaluating predictions with official COCO API...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.17s).
# Accumulating evaluation results...
# DONE (t=0.01s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.780
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.956
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.899
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.740
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.783
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.799
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.045
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.424
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.826
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.754
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.826
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.847
# [02/26 00:06:31 d2.evaluation.coco_evaluation]: Evaluation results for bbox:
# |   AP   |  AP50  |  AP75  |  APs   |  APm   |  APl   |
# |:------:|:------:|:------:|:------:|:------:|:------:|
# | 78.040 | 95.629 | 89.927 | 73.968 | 78.276 | 79.887 |
# [02/26 00:06:31 d2.evaluation.coco_evaluation]: Per-category bbox AP:
# | category   | AP     | category   | AP     |
# |:-----------|:-------|:-----------|:-------|
# | label      | 77.339 | button     | 78.741 |
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *segm*
# DONE (t=0.20s).
# Accumulating evaluation results...
# DONE (t=0.01s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.782
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.951
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.906
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.685
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.786
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.812
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.045
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.427
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.830
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.723
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.829
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.857
# [02/26 00:06:32 d2.evaluation.coco_evaluation]: Evaluation results for segm:
# |   AP   |  AP50  |  AP75  |  APs   |  APm   |  APl   |
# |:------:|:------:|:------:|:------:|:------:|:------:|
# | 78.247 | 95.094 | 90.634 | 68.528 | 78.563 | 81.231 |
# [02/26 00:06:32 d2.evaluation.coco_evaluation]: Per-category segm AP:
# | category   | AP     | category   | AP     |
# |:-----------|:-------|:-----------|:-------|
# | label      | 77.826 | button     | 78.668 |
# OrderedDict([('bbox', {'AP': 78.03998227230086, 'AP50': 95.62926932070145, 'AP75': 89.92710487640025, 'APs': 73.9675784886181, 'APm': 78.27564555763533, 'APl': 79.88668905004481, 'AP-label': 77.33935706883184, 'AP-button': 78.74060747576985}), ('segm', {'AP': 78.24689805402183, 'AP50': 95.0937820460089, 'AP75': 90.63411166366522, 'APs': 68.52761151055383, 'APm': 78.5634818540715, 'APl': 81.23107907251396, 'AP-label': 77.82624462308196, 'AP-button': 78.66755148496168})])

# %% [markdown]
# ### Visualize Inference on Mixed Testset

# %%
def visualize_inference(dataset_name: str, k: int):
    testset = get_detection_dataset_dicts(dataset_name, filter_empty=False)
    for d in random.sample(testset, k):
        img = cv2.imread(d["file_name"])
        outputs = predictor(img)
        v = Visualizer(
            img[:, :, ::-1],
            metadata=MetadataCatalog.get(dataset_name),
            scale=1.0,
            instance_mode=ColorMode.SEGMENTATION,
        )
        out = v.draw_instance_predictions(outputs["instances"].to("cpu"))
        plt.imshow(out.get_image())
        plt.axis("off")
        plt.show()

# %%
visualize_inference("mixed_test", 5)

# %% [markdown]
# ### Evaluate Model on UT-West-Campus Testset

# %%
evaluator = COCOEvaluator(
    dataset_name="ut_west_campus_test",
    output_dir=os.path.join(cfg.OUTPUT_DIR, "inference", "ut_west_campus"),
    allow_cached_coco=False,
    use_fast_impl=False,
)
testloader = build_detection_test_loader(cfg, "ut_west_campus_test")
print(inference_on_dataset(predictor.model, testloader, evaluator))
# Out:
# [02/25 22:46:40 d2.evaluation.coco_evaluation]: Trying to convert 'ut_west_campus_test' to COCO format ...
# [02/25 22:46:40 d2.data.datasets.coco]: Converting annotations of dataset 'ut_west_campus_test' to COCO format ...)
# [02/25 22:46:52 d2.data.datasets.coco]: Converting dataset dicts into COCO format
# [02/25 22:46:52 d2.data.datasets.coco]: Conversion finished, #images: 88, #annotations: 1964
# [02/25 22:46:52 d2.data.datasets.coco]: Caching COCO format annotations at './models/combined_segmentation/inference/ut_west_campus/ut_west_campus_test_coco_format.json' ...
# [02/25 22:47:05 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in inference: [ResizeShortestEdge(short_edge_length=(800, 800), max_size=1333, sample_style='choice')]
# [02/25 22:47:05 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [02/25 22:47:05 d2.data.common]: Serializing 88 elements to byte tensors and concatenating them all ...
# [02/25 22:47:06 d2.data.common]: Serialized dataset takes 31.87 MiB
# [02/25 22:47:06 d2.evaluation.evaluator]: Start inference on 88 batches
# [02/25 22:47:16 d2.evaluation.evaluator]: Inference done 11/88. Dataloading: 0.0006 s/iter. Inference: 0.0595 s/iter. Eval: 0.8244 s/iter. Total: 0.8844 s/iter. ETA=0:01:08
# [02/25 22:47:22 d2.evaluation.evaluator]: Inference done 17/88. Dataloading: 0.0007 s/iter. Inference: 0.0593 s/iter. Eval: 0.8264 s/iter. Total: 0.8865 s/iter. ETA=0:01:02
# [02/25 22:47:27 d2.evaluation.evaluator]: Inference done 21/88. Dataloading: 0.0007 s/iter. Inference: 0.0684 s/iter. Eval: 0.9097 s/iter. Total: 0.9789 s/iter. ETA=0:01:05
# [02/25 22:47:32 d2.evaluation.evaluator]: Inference done 25/88. Dataloading: 0.0007 s/iter. Inference: 0.0689 s/iter. Eval: 0.9748 s/iter. Total: 1.0445 s/iter. ETA=0:01:05
# [02/25 22:47:38 d2.evaluation.evaluator]: Inference done 31/88. Dataloading: 0.0007 s/iter. Inference: 0.0670 s/iter. Eval: 0.9490 s/iter. Total: 1.0168 s/iter. ETA=0:00:57
# [02/25 22:47:43 d2.evaluation.evaluator]: Inference done 40/88. Dataloading: 0.0007 s/iter. Inference: 0.0629 s/iter. Eval: 0.8348 s/iter. Total: 0.8985 s/iter. ETA=0:00:43
# [02/25 22:47:48 d2.evaluation.evaluator]: Inference done 49/88. Dataloading: 0.0007 s/iter. Inference: 0.0610 s/iter. Eval: 0.7810 s/iter. Total: 0.8429 s/iter. ETA=0:00:32
# [02/25 22:47:53 d2.evaluation.evaluator]: Inference done 56/88. Dataloading: 0.0007 s/iter. Inference: 0.0603 s/iter. Eval: 0.7691 s/iter. Total: 0.8303 s/iter. ETA=0:00:26
# [02/25 22:47:59 d2.evaluation.evaluator]: Inference done 63/88. Dataloading: 0.0007 s/iter. Inference: 0.0598 s/iter. Eval: 0.7620 s/iter. Total: 0.8226 s/iter. ETA=0:00:20
# [02/25 22:48:04 d2.evaluation.evaluator]: Inference done 72/88. Dataloading: 0.0007 s/iter. Inference: 0.0588 s/iter. Eval: 0.7359 s/iter. Total: 0.7956 s/iter. ETA=0:00:12
# [02/25 22:48:10 d2.evaluation.evaluator]: Inference done 78/88. Dataloading: 0.0008 s/iter. Inference: 0.0589 s/iter. Eval: 0.7467 s/iter. Total: 0.8065 s/iter. ETA=0:00:08
# [02/25 22:48:15 d2.evaluation.evaluator]: Inference done 87/88. Dataloading: 0.0008 s/iter. Inference: 0.0581 s/iter. Eval: 0.7201 s/iter. Total: 0.7791 s/iter. ETA=0:00:00
# [02/25 22:48:16 d2.evaluation.evaluator]: Total inference time: 0:01:04.501649 (0.777128 s / iter per device, on 1 devices)
# [02/25 22:48:16 d2.evaluation.evaluator]: Total inference pure compute time: 0:00:04 (0.057973 s / iter per device, on 1 devices)
# [02/25 22:48:16 d2.evaluation.coco_evaluation]: Preparing results for COCO format ...
# [02/25 22:48:16 d2.evaluation.coco_evaluation]: Saving results to ./models/combined_segmentation/inference/ut_west_campus/coco_instances_results.json
# [02/25 22:48:16 d2.evaluation.coco_evaluation]: Evaluating predictions with official COCO API...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.24s).
# Accumulating evaluation results...
# DONE (t=0.02s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.923
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.989
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.989
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.840
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.926
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.086
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.791
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.951
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.851
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.952
# [02/25 22:48:16 d2.evaluation.coco_evaluation]: Evaluation results for bbox:
# |   AP   |  AP50  |  AP75  |  APs  |  APm   |  APl   |
# |:------:|:------:|:------:|:-----:|:------:|:------:|
# | 92.262 | 98.883 | 98.883 |  nan  | 84.022 | 92.646 |
# [02/25 22:48:16 d2.evaluation.coco_evaluation]: Some metrics cannot be computed and is shown as NaN.
# [02/25 22:48:16 d2.evaluation.coco_evaluation]: Per-category bbox AP:
# | category   | AP     | category   | AP     |
# |:-----------|:-------|:-----------|:-------|
# | label      | 92.587 | button     | 91.937 |
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *segm*
# DONE (t=0.35s).
# Accumulating evaluation results...
# DONE (t=0.02s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.926
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.989
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.989
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.874
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.930
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.086
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.792
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.951
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.887
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.952
# [02/25 22:48:16 d2.evaluation.coco_evaluation]: Evaluation results for segm:
# |   AP   |  AP50  |  AP75  |  APs  |  APm   |  APl   |
# |:------:|:------:|:------:|:-----:|:------:|:------:|
# | 92.582 | 98.883 | 98.883 |  nan  | 87.358 | 92.994 |
# [02/25 22:48:16 d2.evaluation.coco_evaluation]: Some metrics cannot be computed and is shown as NaN.
# [02/25 22:48:16 d2.evaluation.coco_evaluation]: Per-category segm AP:
# | category   | AP     | category   | AP     |
# |:-----------|:-------|:-----------|:-------|
# | label      | 92.925 | button     | 92.240 |
# OrderedDict([('bbox', {'AP': 92.26177463434365, 'AP50': 98.88312930165067, 'AP75': 98.88312930165067, 'APs': nan, 'APm': 84.02172622900132, 'APl': 92.64644390106166, 'AP-label': 92.5867996307182, 'AP-button': 91.9367496379691}), ('segm', {'AP': 92.58242269132563, 'AP50': 98.88312930165067, 'AP75': 98.88312930165067, 'APs': nan, 'APm': 87.35846219865425, 'APl': 92.99359759551525, 'AP-label': 92.92497798793043, 'AP-button': 92.2398673947208})])

# %% [markdown]
# ### Visualize Inference on UT-West-Campus Testset

# %%
visualize_inference("ut_west_campus_test", 5)
