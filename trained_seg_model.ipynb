# %% [markdown]
# # Training Notebook
#
# Train Cascade Mask-RCNN
#
# Add a couple additional things:
# - Validation Loop using loss
# - Checkpoint based off of best validation metrics
# - Custom COCO Style Dataloaders

# %%
# Setup detectron2 logger
import detectron2
from detectron2.utils.logger import setup_logger

setup_logger()

# python libraries
import numpy as np
import os, json, random, math, time, datetime, logging
import torch, cv2
import matplotlib.pyplot as plt

# %matplotlib inline

# d2 libraries
from detectron2 import model_zoo
from detectron2.engine import DefaultTrainer, DefaultPredictor
from detectron2.evaluation import COCOEvaluator, inference_on_dataset
from detectron2.config import get_cfg
from detectron2.utils import comm
from detectron2.utils.logger import log_every_n_seconds
from detectron2.utils.visualizer import Visualizer, ColorMode
from detectron2.engine.hooks import EvalHook, BestCheckpointer
from detectron2.data import (
    MetadataCatalog,
    DatasetCatalog,
    build_detection_train_loader,
    build_detection_test_loader,
    get_detection_dataset_dicts,
    DatasetMapper,
)
import detectron2.data.transforms as T

# my stuff
from data_utils import read_split_file, random_split_mixed_set, register_dataset
import elevator_datasets

# %% [markdown]
# ### Randomly Split Data
#
# For reproducibility we seed the shuffler with the value 10

# %%
random_split_mixed_set(
    img_dir=elevator_datasets.MIXED_SRC,
    split_ratio=elevator_datasets.MIXED_SPLIT_RATIO,
    seed=10,
)
datasets = read_split_file(elevator_datasets.MIXED_SPLIT_FILE_PATH)

# %% [markdown]
# ### Register data splits with metadata

# %%
for name, im_paths in zip(["train", "val", "test"], datasets):
    DatasetCatalog.register(
        name=name, func=lambda im_paths=im_paths: register_dataset(im_paths=im_paths)
    )
    MetadataCatalog.get(name=name).thing_classes = ["label", "button"]
    MetadataCatalog.get(name=name).thing_colors = [(0, 255, 0), (0, 0, 255)]

# %%
trainset = DatasetCatalog.get("train")
print("trainset length: ", len(trainset))
# Out:
# trainset length:  70

# %% [markdown]
# ### View Training Data Samples
#
# Ensure that data is annotated correctly

# %%
for d in random.sample(trainset, 5):
    img = cv2.imread(d["file_name"])
    visualizer = Visualizer(
        img[:, :, ::-1],
        metadata=MetadataCatalog.get("train"),
        scale=1,
        instance_mode=ColorMode.SEGMENTATION,
    )
    out = visualizer.draw_dataset_dict(d)
    plt.imshow(out.get_image())
    plt.axis("off")
    plt.show()

# %% [markdown]
# ### Validation Loop using Validation Loss

# %%
def validation_loop(model: torch.nn, dataloader: torch.utils.data.DataLoader) -> dict:
    """
    Validate model on the given dataloader. Put model in training mode to output loss
    dict but do not backpropogate gradients. Largely adapted from train_loop.py and
    inference_on_dataset

    Args:
        model (torch.nn): model to validate
        dataloader (torch.utils.data.DataLoader): validation dataloader set to training
            mode

    Returns:
        dict: {"validation_loss": val_loss}
    """
    model.train()
    num_batches = len(dataloader)
    num_warmup = min(5, num_batches - 1)
    start_time = time.perf_counter()
    total_compute_time = 0
    losses = []
    for idx, data in enumerate(dataloader):
        if idx == num_warmup:
            start_time = time.perf_counter()
            total_compute_time = 0
        start_compute_time = time.perf_counter()
        if torch.cuda.is_available():
            torch.cuda.synchronize()
        total_compute_time += time.perf_counter() - start_compute_time
        iters_after_start = idx + 1 - num_warmup * int(idx >= num_warmup)
        seconds_per_img = total_compute_time / iters_after_start
        if idx >= num_warmup * 2 or seconds_per_img > 5:
            total_seconds_per_img = (
                time.perf_counter() - start_time
            ) / iters_after_start
            eta = datetime.timedelta(
                seconds=int(total_seconds_per_img) * (num_batches - idx - 1)
            )
            log_every_n_seconds(
                logging.INFO,
                "Loss on Validation  done {}/{}. {:.4f} s / img. ETA={}".format(
                    idx + 1, num_batches, seconds_per_img, str(eta)
                ),
                n=5,
            )

        batch_loss_dict = model(data)
        batch_loss_dict = {
            k: v.detach().cpu().item() if isinstance(v, torch.Tensor) else float(v)
            for k, v in batch_loss_dict.items()
        }
        total_batch_loss = sum(loss for loss in batch_loss_dict.values())
        losses.append(total_batch_loss)
    val_loss = np.mean(losses)
    comm.synchronize()
    log_every_n_seconds(logging.INFO, f"VALIDATION_LOSS: {val_loss:.5f}")
    return {"validation_loss": val_loss}

# %% [markdown]
# ### Define a Custom Trainer
#
# Add custom hooks and dataloader

# %%
class Trainer(DefaultTrainer):
    @classmethod
    def build_train_loader(cls, cfg):
        return build_detection_train_loader(
            dataset=get_detection_dataset_dicts(
                cfg.DATASETS.TRAIN[0], filter_empty=False
            ),
            mapper=DatasetMapper(
                is_train=True,
                augmentations=[
                    T.ResizeScale(
                        min_scale=0.1,
                        max_scale=2.0,
                        target_height=1024,
                        target_width=1024,
                    ),
                    T.FixedSizeCrop(crop_size=(1024, 1024), pad=False),
                ],
                image_format="RGB",
                use_instance_mask=True,
                recompute_boxes=True,
            ),
            total_batch_size=cfg.SOLVER.IMS_PER_BATCH,
            num_workers=cfg.DATALOADER.NUM_WORKERS,
        )

    @classmethod
    def build_validation_loader(cls, cfg):
        return build_detection_test_loader(
            dataset=get_detection_dataset_dicts(
                cfg.DATASETS.VAL[0], filter_empty=False
            ),
            mapper=DatasetMapper(
                is_train=True,
                augmentations=[
                    T.ResizeShortestEdge(short_edge_length=1024, max_size=1024)
                ],
                image_format="BGR",
                use_instance_mask=True,
            ),
        )

    def build_hooks(self) -> list:
        """
        Overwrite the evaluation loop and checkpoint using best validation loss

        Returns:
            list: list of hooks
        """
        hooks = super().build_hooks()
        # remove existing EvalHook
        if comm.is_main_process():
            del hooks[-2]
            del hooks[-2]
        else:
            del hooks[-1]
        hooks.extend(
            [
                EvalHook(
                    eval_period=self.cfg.TEST.EVAL_PERIOD,
                    eval_function=lambda: validation_loop(
                        self.model,
                        self.build_validation_loader(self.cfg),
                    ),
                    eval_after_train=True,
                ),
                BestCheckpointer(
                    eval_period=self.cfg.TEST.EVAL_PERIOD,
                    checkpointer=self.checkpointer,
                    val_metric="validation_loss",
                    mode="min",
                ),
            ]
        )
        return hooks

# %% [markdown]
# ### Define Config for Building Model

# %%
cfg = get_cfg()
cfg.merge_from_file(
    model_zoo.get_config_file("Misc/cascade_mask_rcnn_R_50_FPN_3x.yaml")
)

# start from pretrained weights
cfg.MODEL.WEIGHTS = model_zoo.get_checkpoint_url(
    "Misc/cascade_mask_rcnn_R_50_FPN_3x.yaml"
)

# assign datasets and adjust ROI HEADS to match num classes
cfg.DATASETS.TRAIN = ("train",)
cfg.DATASETS.VAL = ("val",)
cfg.DATASETS.TEST = ("test",)
cfg.DATALOADER.FILTER_EMPTY_ANNOTATIONS = False
cfg.INPUT.RANDOM_FLIP = "none"
cfg.MODEL.ROI_HEADS.NUM_CLASSES = 2

# Calculate training logic
epochs = 100
batch_size = 2
eval_period = 2
iters_per_epoch = math.ceil(len(trainset) / batch_size)

cfg.SOLVER.IMS_PER_BATCH = 2
cfg.SOLVER.MAX_ITER = iters_per_epoch * epochs
cfg.TEST.EVAL_PERIOD = iters_per_epoch * eval_period
cfg.SOLVER.BASE_LR = 0.00025
cfg.SOLVER.STEPS = [int(0.7 * cfg.SOLVER.MAX_ITER), int(0.8 * cfg.SOLVER.MAX_ITER)]
cfg.SOLVER.WARMUP_ITERS = int(0.067 * cfg.SOLVER.MAX_ITER)

# SAVE DIR
cfg.OUTPUT_DIR = "./output"

# %% [markdown]
# ### Train Configured Model
#
# Use modified DefaultTrainer

# %%
os.makedirs(cfg.OUTPUT_DIR, exist_ok=True)
trainer = Trainer(cfg)
trainer.resume_or_load(resume=False)
trainer.train()
# Out:
# [02/19 14:33:20 d2.engine.defaults]: Model:
# GeneralizedRCNN(
#   (backbone): FPN(
#     (fpn_lateral2): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral3): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral4): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output4): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral5): Conv2d(2048, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output5): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (top_block): LastLevelMaxPool()
#     (bottom_up): ResNet(
#       (stem): BasicStem(
#         (conv1): Conv2d(
#           3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False
#           (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#         )
#       )
#       (res2): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#         )
#       )
#       (res3): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             256, 128, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#         (3): BottleneckBlock(
#           (conv1): Conv2d(
#             512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#       )
#       (res4): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             512, 256, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (3): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (4): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (5): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#       )
#       (res5): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             1024, 512, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#         )
#       )
#     )
#   )
#   (proposal_generator): RPN(
#     (rpn_head): StandardRPNHead(
#       (conv): Conv2d(
#         256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)
#         (activation): ReLU()
#       )
#       (objectness_logits): Conv2d(256, 3, kernel_size=(1, 1), stride=(1, 1))
#       (anchor_deltas): Conv2d(256, 12, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (anchor_generator): DefaultAnchorGenerator(
#       (cell_anchors): BufferList()
#     )
#   )
#   (roi_heads): CascadeROIHeads(
#     (box_pooler): ROIPooler(
#       (level_poolers): ModuleList(
#         (0): ROIAlign(output_size=(7, 7), spatial_scale=0.25, sampling_ratio=0, aligned=True)
#         (1): ROIAlign(output_size=(7, 7), spatial_scale=0.125, sampling_ratio=0, aligned=True)
#         (2): ROIAlign(output_size=(7, 7), spatial_scale=0.0625, sampling_ratio=0, aligned=True)
#         (3): ROIAlign(output_size=(7, 7), spatial_scale=0.03125, sampling_ratio=0, aligned=True)
#       )
#     )
#     (box_head): ModuleList(
#       (0): FastRCNNConvFCHead(
#         (flatten): Flatten(start_dim=1, end_dim=-1)
#         (fc1): Linear(in_features=12544, out_features=1024, bias=True)
#         (fc_relu1): ReLU()
#         (fc2): Linear(in_features=1024, out_features=1024, bias=True)
#         (fc_relu2): ReLU()
#       )
#       (1): FastRCNNConvFCHead(
#         (flatten): Flatten(start_dim=1, end_dim=-1)
#         (fc1): Linear(in_features=12544, out_features=1024, bias=True)
#         (fc_relu1): ReLU()
#         (fc2): Linear(in_features=1024, out_features=1024, bias=True)
#         (fc_relu2): ReLU()
#       )
#       (2): FastRCNNConvFCHead(
#         (flatten): Flatten(start_dim=1, end_dim=-1)
#         (fc1): Linear(in_features=12544, out_features=1024, bias=True)
#         (fc_relu1): ReLU()
#         (fc2): Linear(in_features=1024, out_features=1024, bias=True)
#         (fc_relu2): ReLU()
#       )
#     )
#     (box_predictor): ModuleList(
#       (0): FastRCNNOutputLayers(
#         (cls_score): Linear(in_features=1024, out_features=3, bias=True)
#         (bbox_pred): Linear(in_features=1024, out_features=4, bias=True)
#       )
#       (1): FastRCNNOutputLayers(
#         (cls_score): Linear(in_features=1024, out_features=3, bias=True)
#         (bbox_pred): Linear(in_features=1024, out_features=4, bias=True)
#       )
#       (2): FastRCNNOutputLayers(
#         (cls_score): Linear(in_features=1024, out_features=3, bias=True)
#         (bbox_pred): Linear(in_features=1024, out_features=4, bias=True)
#       )
#     )
#     (mask_pooler): ROIPooler(
#       (level_poolers): ModuleList(
#         (0): ROIAlign(output_size=(14, 14), spatial_scale=0.25, sampling_ratio=0, aligned=True)
#         (1): ROIAlign(output_size=(14, 14), spatial_scale=0.125, sampling_ratio=0, aligned=True)
#         (2): ROIAlign(output_size=(14, 14), spatial_scale=0.0625, sampling_ratio=0, aligned=True)
#         (3): ROIAlign(output_size=(14, 14), spatial_scale=0.03125, sampling_ratio=0, aligned=True)
#       )
#     )
#     (mask_head): MaskRCNNConvUpsampleHead(
#       (mask_fcn1): Conv2d(
#         256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)
#         (activation): ReLU()
#       )
#       (mask_fcn2): Conv2d(
#         256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)
#         (activation): ReLU()
#       )
#       (mask_fcn3): Conv2d(
#         256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)
#         (activation): ReLU()
#       )
#       (mask_fcn4): Conv2d(
#         256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)
#         (activation): ReLU()
#       )
#       (deconv): ConvTranspose2d(256, 256, kernel_size=(2, 2), stride=(2, 2))
#       (deconv_relu): ReLU()
#       (predictor): Conv2d(256, 2, kernel_size=(1, 1), stride=(1, 1))
#     )
#   )
# )
# [02/19 14:33:22 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in training: [ResizeScale(min_scale=0.1, max_scale=2.0, target_height=1024, target_width=1024), FixedSizeCrop(crop_size=(1024, 1024), pad=False)]
# [02/19 14:33:22 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [02/19 14:33:22 d2.data.common]: Serializing 70 elements to byte tensors and concatenating them all ...
# [02/19 14:33:23 d2.data.common]: Serialized dataset takes 12.60 MiB
# [02/19 14:33:23 d2.checkpoint.detection_checkpoint]: [DetectionCheckpointer] Loading from https://dl.fbaipublicfiles.com/detectron2/Misc/cascade_mask_rcnn_R_50_FPN_3x/144998488/model_final_480dd8.pkl ...
# Skip loading parameter 'roi_heads.box_predictor.0.cls_score.weight' to the model due to incompatible shapes: (81, 1024) in the checkpoint but (3, 1024) in the model! You might want to double check if this is expected.
# Skip loading parameter 'roi_heads.box_predictor.0.cls_score.bias' to the model due to incompatible shapes: (81,) in the checkpoint but (3,) in the model! You might want to double check if this is expected.
# Skip loading parameter 'roi_heads.box_predictor.1.cls_score.weight' to the model due to incompatible shapes: (81, 1024) in the checkpoint but (3, 1024) in the model! You might want to double check if this is expected.
# Skip loading parameter 'roi_heads.box_predictor.1.cls_score.bias' to the model due to incompatible shapes: (81,) in the checkpoint but (3,) in the model! You might want to double check if this is expected.
# Skip loading parameter 'roi_heads.box_predictor.2.cls_score.weight' to the model due to incompatible shapes: (81, 1024) in the checkpoint but (3, 1024) in the model! You might want to double check if this is expected.
# Skip loading parameter 'roi_heads.box_predictor.2.cls_score.bias' to the model due to incompatible shapes: (81,) in the checkpoint but (3,) in the model! You might want to double check if this is expected.
# Skip loading parameter 'roi_heads.mask_head.predictor.weight' to the model due to incompatible shapes: (80, 256, 1, 1) in the checkpoint but (2, 256, 1, 1) in the model! You might want to double check if this is expected.
# Skip loading parameter 'roi_heads.mask_head.predictor.bias' to the model due to incompatible shapes: (80,) in the checkpoint but (2,) in the model! You might want to double check if this is expected.
# Some model parameters or buffers are not found in the checkpoint:
# roi_heads.box_predictor.0.cls_score.{bias, weight}
# roi_heads.box_predictor.1.cls_score.{bias, weight}
# roi_heads.box_predictor.2.cls_score.{bias, weight}
# roi_heads.mask_head.predictor.{bias, weight}
# [02/19 14:33:23 d2.engine.train_loop]: Starting training from iteration 0
# /home/abhinavchadaga/miniforge3/envs/d2/lib/python3.8/site-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at /opt/conda/conda-bld/pytorch_1670525541702/work/aten/src/ATen/native/TensorShape.cpp:3190.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# [02/19 14:33:28 d2.utils.events]:  eta: 0:12:37  iter: 19  total_loss: 7.077  loss_cls_stage0: 1.005  loss_box_reg_stage0: 0.2808  loss_cls_stage1: 1.129  loss_box_reg_stage1: 0.5376  loss_cls_stage2: 1.183  loss_box_reg_stage2: 0.6219  loss_mask: 0.6906  loss_rpn_cls: 1.119  loss_rpn_loc: 0.1244  time: 0.1932  last_time: 0.2217  data_time: 0.0132  last_data_time: 0.0006   lr: 2.0529e-05  max_mem: 3224M
# [02/19 14:33:32 d2.utils.events]:  eta: 0:12:27  iter: 39  total_loss: 5.626  loss_cls_stage0: 0.8846  loss_box_reg_stage0: 0.246  loss_cls_stage1: 0.9988  loss_box_reg_stage1: 0.4716  loss_cls_stage2: 1.012  loss_box_reg_stage2: 0.538  loss_mask: 0.6532  loss_rpn_cls: 0.319  loss_rpn_loc: 0.1065  time: 0.1994  last_time: 0.2218  data_time: 0.0022  last_data_time: 0.0005   lr: 4.1875e-05  max_mem: 3224M
# [02/19 14:33:36 d2.utils.events]:  eta: 0:12:16  iter: 59  total_loss: 4.622  loss_cls_stage0: 0.7562  loss_box_reg_stage0: 0.2233  loss_cls_stage1: 0.8494  loss_box_reg_stage1: 0.429  loss_cls_stage2: 0.8545  loss_box_reg_stage2: 0.5737  loss_mask: 0.5704  loss_rpn_cls: 0.06248  loss_rpn_loc: 0.08853  time: 0.2013  last_time: 0.2279  data_time: 0.0050  last_data_time: 0.0015   lr: 6.3221e-05  max_mem: 3224M
# [02/19 14:33:39 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in training: [ResizeShortestEdge(short_edge_length=(1024, 1024), max_size=1024)]
# [02/19 14:33:39 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [02/19 14:33:39 d2.data.common]: Serializing 10 elements to byte tensors and concatenating them all ...
# [02/19 14:33:39 d2.data.common]: Serialized dataset takes 2.11 MiB
# [02/19 14:33:40 detectron2]: VALIDATION_LOSS: 4.52221
# [02/19 14:33:40 d2.engine.hooks]: Saved first model at 4.52221 @ 69 steps
# [02/19 14:33:42 d2.utils.events]:  eta: 0:12:15  iter: 79  total_loss: 4.092  loss_cls_stage0: 0.6507  loss_box_reg_stage0: 0.2164  loss_cls_stage1: 0.7337  loss_box_reg_stage1: 0.4975  loss_cls_stage2: 0.7186  loss_box_reg_stage2: 0.7125  loss_mask: 0.4933  loss_rpn_cls: 0.03128  loss_rpn_loc: 0.06362  validation_loss: 4.522  time: 0.2010  last_time: 0.1221  data_time: 0.0034  last_data_time: 0.0005   lr: 8.4567e-05  max_mem: 3224M
# [02/19 14:33:46 d2.utils.events]:  eta: 0:12:07  iter: 99  total_loss: 3.878  loss_cls_stage0: 0.5902  loss_box_reg_stage0: 0.2547  loss_cls_stage1: 0.6508  loss_box_reg_stage1: 0.5525  loss_cls_stage2: 0.6393  loss_box_reg_stage2: 0.6878  loss_mask: 0.4008  loss_rpn_cls: 0.0423  loss_rpn_loc: 0.0804  validation_loss: 4.522  time: 0.2007  last_time: 0.2145  data_time: 0.0038  last_data_time: 0.0037   lr: 0.00010591  max_mem: 3224M
# [02/19 14:33:50 d2.utils.events]:  eta: 0:12:02  iter: 119  total_loss: 3.711  loss_cls_stage0: 0.5446  loss_box_reg_stage0: 0.254  loss_cls_stage1: 0.5926  loss_box_reg_stage1: 0.491  loss_cls_stage2: 0.5831  loss_box_reg_stage2: 0.6593  loss_mask: 0.3413  loss_rpn_cls: 0.03696  loss_rpn_loc: 0.1174  validation_loss: 4.522  time: 0.1990  last_time: 0.2159  data_time: 0.0030  last_data_time: 0.0021   lr: 0.00012726  max_mem: 3224M
# [02/19 14:33:54 d2.utils.events]:  eta: 0:11:55  iter: 139  total_loss: 3.271  loss_cls_stage0: 0.4818  loss_box_reg_stage0: 0.2075  loss_cls_stage1: 0.4997  loss_box_reg_stage1: 0.4356  loss_cls_stage2: 0.5352  loss_box_reg_stage2: 0.608  loss_mask: 0.3083  loss_rpn_cls: 0.01969  loss_rpn_loc: 0.09274  validation_loss: 4.522  time: 0.1985  last_time: 0.1944  data_time: 0.0023  last_data_time: 0.0013   lr: 0.00014861  max_mem: 3224M
# [02/19 14:33:54 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in training: [ResizeShortestEdge(short_edge_length=(1024, 1024), max_size=1024)]
# [02/19 14:33:54 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [02/19 14:33:54 d2.data.common]: Serializing 10 elements to byte tensors and concatenating them all ...
# [02/19 14:33:55 d2.data.common]: Serialized dataset takes 2.11 MiB
# [02/19 14:33:56 detectron2]: VALIDATION_LOSS: 3.35129
# [02/19 14:33:56 d2.engine.hooks]: Saved best model as latest eval score for validation_loss is 3.35129, better than last best score 4.52221 @ iteration 69.
# [02/19 14:34:00 d2.utils.events]:  eta: 0:11:49  iter: 159  total_loss: 3.433  loss_cls_stage0: 0.4566  loss_box_reg_stage0: 0.2515  loss_cls_stage1: 0.4776  loss_box_reg_stage1: 0.5259  loss_cls_stage2: 0.5071  loss_box_reg_stage2: 0.7415  loss_mask: 0.2448  loss_rpn_cls: 0.02269  loss_rpn_loc: 0.07049  validation_loss: 3.351  time: 0.1990  last_time: 0.1716  data_time: 0.0055  last_data_time: 0.0007   lr: 0.00016995  max_mem: 3224M
# [02/19 14:34:05 d2.utils.events]:  eta: 0:11:49  iter: 179  total_loss: 2.64  loss_cls_stage0: 0.387  loss_box_reg_stage0: 0.1647  loss_cls_stage1: 0.4074  loss_box_reg_stage1: 0.3673  loss_cls_stage2: 0.4291  loss_box_reg_stage2: 0.5199  loss_mask: 0.2097  loss_rpn_cls: 0.0224  loss_rpn_loc: 0.06353  validation_loss: 3.351  time: 0.2000  last_time: 0.1819  data_time: 0.0029  last_data_time: 0.0012   lr: 0.0001913  max_mem: 3224M
# [02/19 14:34:09 d2.utils.events]:  eta: 0:11:48  iter: 199  total_loss: 2.809  loss_cls_stage0: 0.3701  loss_box_reg_stage0: 0.2366  loss_cls_stage1: 0.3744  loss_box_reg_stage1: 0.4895  loss_cls_stage2: 0.3923  loss_box_reg_stage2: 0.6591  loss_mask: 0.22  loss_rpn_cls: 0.02708  loss_rpn_loc: 0.06656  validation_loss: 3.351  time: 0.2018  last_time: 0.2288  data_time: 0.0023  last_data_time: 0.0005   lr: 0.00021264  max_mem: 3224M
# [02/19 14:34:11 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in training: [ResizeShortestEdge(short_edge_length=(1024, 1024), max_size=1024)]
# [02/19 14:34:11 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [02/19 14:34:11 d2.data.common]: Serializing 10 elements to byte tensors and concatenating them all ...
# [02/19 14:34:12 d2.data.common]: Serialized dataset takes 2.11 MiB
# [02/19 14:34:13 detectron2]: VALIDATION_LOSS: 2.73337
# [02/19 14:34:13 d2.engine.hooks]: Saved best model as latest eval score for validation_loss is 2.73337, better than last best score 3.35129 @ iteration 139.
# [02/19 14:34:16 d2.utils.events]:  eta: 0:11:43  iter: 219  total_loss: 2.496  loss_cls_stage0: 0.3118  loss_box_reg_stage0: 0.1647  loss_cls_stage1: 0.31  loss_box_reg_stage1: 0.3523  loss_cls_stage2: 0.3497  loss_box_reg_stage2: 0.5326  loss_mask: 0.1647  loss_rpn_cls: 0.01729  loss_rpn_loc: 0.06229  validation_loss: 2.733  time: 0.2022  last_time: 0.2262  data_time: 0.0031  last_data_time: 0.0044   lr: 0.00023399  max_mem: 3224M
# [02/19 14:34:20 d2.utils.events]:  eta: 0:11:37  iter: 239  total_loss: 2.74  loss_cls_stage0: 0.2937  loss_box_reg_stage0: 0.2383  loss_cls_stage1: 0.2969  loss_box_reg_stage1: 0.5045  loss_cls_stage2: 0.3148  loss_box_reg_stage2: 0.645  loss_mask: 0.1981  loss_rpn_cls: 0.01688  loss_rpn_loc: 0.08917  validation_loss: 2.733  time: 0.2018  last_time: 0.2088  data_time: 0.0023  last_data_time: 0.0024   lr: 0.00025  max_mem: 3224M
# [02/19 14:34:24 d2.utils.events]:  eta: 0:11:30  iter: 259  total_loss: 1.967  loss_cls_stage0: 0.2427  loss_box_reg_stage0: 0.1729  loss_cls_stage1: 0.2311  loss_box_reg_stage1: 0.3621  loss_cls_stage2: 0.2419  loss_box_reg_stage2: 0.5282  loss_mask: 0.1396  loss_rpn_cls: 0.01839  loss_rpn_loc: 0.05308  validation_loss: 2.733  time: 0.2015  last_time: 0.2231  data_time: 0.0025  last_data_time: 0.0028   lr: 0.00025  max_mem: 3224M
# [02/19 14:34:28 d2.utils.events]:  eta: 0:11:26  iter: 279  total_loss: 2.227  loss_cls_stage0: 0.2363  loss_box_reg_stage0: 0.2017  loss_cls_stage1: 0.2238  loss_box_reg_stage1: 0.4261  loss_cls_stage2: 0.2341  loss_box_reg_stage2: 0.575  loss_mask: 0.1424  loss_rpn_cls: 0.01651  loss_rpn_loc: 0.05657  validation_loss: 2.733  time: 0.2013  last_time: 0.1636  data_time: 0.0023  last_data_time: 0.0012   lr: 0.00025  max_mem: 3224M
# [02/19 14:34:28 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in training: [ResizeShortestEdge(short_edge_length=(1024, 1024), max_size=1024)]
# [02/19 14:34:28 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [02/19 14:34:28 d2.data.common]: Serializing 10 elements to byte tensors and concatenating them all ...
# [02/19 14:34:28 d2.data.common]: Serialized dataset takes 2.11 MiB
# [02/19 14:34:29 detectron2]: VALIDATION_LOSS: 2.36814
# [02/19 14:34:30 d2.engine.hooks]: Saved best model as latest eval score for validation_loss is 2.36814, better than last best score 2.73337 @ iteration 209.
# [02/19 14:34:34 d2.utils.events]:  eta: 0:11:24  iter: 299  total_loss: 2.319  loss_cls_stage0: 0.2305  loss_box_reg_stage0: 0.1962  loss_cls_stage1: 0.216  loss_box_reg_stage1: 0.4264  loss_cls_stage2: 0.2157  loss_box_reg_stage2: 0.5535  loss_mask: 0.16  loss_rpn_cls: 0.04483  loss_rpn_loc: 0.0883  validation_loss: 2.368  time: 0.2018  last_time: 0.1868  data_time: 0.0023  last_data_time: 0.0006   lr: 0.00025  max_mem: 3224M
# [02/19 14:34:38 d2.utils.events]:  eta: 0:11:19  iter: 319  total_loss: 2.201  loss_cls_stage0: 0.2125  loss_box_reg_stage0: 0.1964  loss_cls_stage1: 0.1948  loss_box_reg_stage1: 0.4217  loss_cls_stage2: 0.1974  loss_box_reg_stage2: 0.616  loss_mask: 0.1452  loss_rpn_cls: 0.02348  loss_rpn_loc: 0.0881  validation_loss: 2.368  time: 0.2010  last_time: 0.2292  data_time: 0.0024  last_data_time: 0.0006   lr: 0.00025  max_mem: 3224M
# [02/19 14:34:42 d2.utils.events]:  eta: 0:11:14  iter: 339  total_loss: 2.13  loss_cls_stage0: 0.217  loss_box_reg_stage0: 0.2103  loss_cls_stage1: 0.2095  loss_box_reg_stage1: 0.4459  loss_cls_stage2: 0.2228  loss_box_reg_stage2: 0.5733  loss_mask: 0.1584  loss_rpn_cls: 0.02847  loss_rpn_loc: 0.07958  validation_loss: 2.368  time: 0.2008  last_time: 0.1317  data_time: 0.0027  last_data_time: 0.0016   lr: 0.00025  max_mem: 3224M
# [02/19 14:34:44 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in training: [ResizeShortestEdge(short_edge_length=(1024, 1024), max_size=1024)]
# [02/19 14:34:44 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [02/19 14:34:44 d2.data.common]: Serializing 10 elements to byte tensors and concatenating them all ...
# [02/19 14:34:44 d2.data.common]: Serialized dataset takes 2.11 MiB
# [02/19 14:34:46 detectron2]: VALIDATION_LOSS: 2.33786
# [02/19 14:34:46 d2.engine.hooks]: Saved best model as latest eval score for validation_loss is 2.33786, better than last best score 2.36814 @ iteration 279.
# [02/19 14:34:48 d2.utils.events]:  eta: 0:11:10  iter: 359  total_loss: 2.17  loss_cls_stage0: 0.1927  loss_box_reg_stage0: 0.2131  loss_cls_stage1: 0.1814  loss_box_reg_stage1: 0.4812  loss_cls_stage2: 0.1734  loss_box_reg_stage2: 0.6577  loss_mask: 0.1501  loss_rpn_cls: 0.01596  loss_rpn_loc: 0.07039  validation_loss: 2.338  time: 0.2007  last_time: 0.1553  data_time: 0.0040  last_data_time: 0.0027   lr: 0.00025  max_mem: 3224M
# [02/19 14:34:52 d2.utils.events]:  eta: 0:11:06  iter: 379  total_loss: 2.054  loss_cls_stage0: 0.1819  loss_box_reg_stage0: 0.2213  loss_cls_stage1: 0.1591  loss_box_reg_stage1: 0.4527  loss_cls_stage2: 0.1704  loss_box_reg_stage2: 0.6322  loss_mask: 0.1492  loss_rpn_cls: 0.01348  loss_rpn_loc: 0.08288  validation_loss: 2.338  time: 0.2005  last_time: 0.1289  data_time: 0.0025  last_data_time: 0.0018   lr: 0.00025  max_mem: 3224M
# [02/19 14:34:56 d2.utils.events]:  eta: 0:11:02  iter: 399  total_loss: 1.755  loss_cls_stage0: 0.1536  loss_box_reg_stage0: 0.1647  loss_cls_stage1: 0.1464  loss_box_reg_stage1: 0.3731  loss_cls_stage2: 0.1494  loss_box_reg_stage2: 0.5692  loss_mask: 0.1236  loss_rpn_cls: 0.008593  loss_rpn_loc: 0.0605  validation_loss: 2.338  time: 0.2010  last_time: 0.2095  data_time: 0.0027  last_data_time: 0.0006   lr: 0.00025  max_mem: 3224M
# [02/19 14:35:01 d2.utils.events]:  eta: 0:10:58  iter: 419  total_loss: 1.905  loss_cls_stage0: 0.1699  loss_box_reg_stage0: 0.1965  loss_cls_stage1: 0.1499  loss_box_reg_stage1: 0.4032  loss_cls_stage2: 0.1582  loss_box_reg_stage2: 0.5607  loss_mask: 0.1253  loss_rpn_cls: 0.01026  loss_rpn_loc: 0.06118  validation_loss: 2.338  time: 0.2014  last_time: 0.2261  data_time: 0.0030  last_data_time: 0.0014   lr: 0.00025  max_mem: 3224M
# [02/19 14:35:01 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in training: [ResizeShortestEdge(short_edge_length=(1024, 1024), max_size=1024)]
# [02/19 14:35:01 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [02/19 14:35:01 d2.data.common]: Serializing 10 elements to byte tensors and concatenating them all ...
# [02/19 14:35:01 d2.data.common]: Serialized dataset takes 2.11 MiB
# [02/19 14:35:02 detectron2]: VALIDATION_LOSS: 2.22397
# [02/19 14:35:03 d2.engine.hooks]: Saved best model as latest eval score for validation_loss is 2.22397, better than last best score 2.33786 @ iteration 349.
# [02/19 14:35:07 d2.utils.events]:  eta: 0:10:56  iter: 439  total_loss: 1.547  loss_cls_stage0: 0.1542  loss_box_reg_stage0: 0.1501  loss_cls_stage1: 0.1433  loss_box_reg_stage1: 0.297  loss_cls_stage2: 0.1577  loss_box_reg_stage2: 0.4231  loss_mask: 0.1146  loss_rpn_cls: 0.01193  loss_rpn_loc: 0.06186  validation_loss: 2.224  time: 0.2018  last_time: 0.1468  data_time: 0.0030  last_data_time: 0.0016   lr: 0.00025  max_mem: 3224M
# [02/19 14:35:11 d2.utils.events]:  eta: 0:10:52  iter: 459  total_loss: 1.942  loss_cls_stage0: 0.1571  loss_box_reg_stage0: 0.2022  loss_cls_stage1: 0.1486  loss_box_reg_stage1: 0.4255  loss_cls_stage2: 0.1497  loss_box_reg_stage2: 0.6713  loss_mask: 0.1331  loss_rpn_cls: 0.008203  loss_rpn_loc: 0.05854  validation_loss: 2.224  time: 0.2015  last_time: 0.1551  data_time: 0.0024  last_data_time: 0.0005   lr: 0.00025  max_mem: 3224M
# [02/19 14:35:15 d2.utils.events]:  eta: 0:10:48  iter: 479  total_loss: 2.154  loss_cls_stage0: 0.1599  loss_box_reg_stage0: 0.1956  loss_cls_stage1: 0.1448  loss_box_reg_stage1: 0.4251  loss_cls_stage2: 0.1493  loss_box_reg_stage2: 0.6286  loss_mask: 0.1402  loss_rpn_cls: 0.01756  loss_rpn_loc: 0.06854  validation_loss: 2.224  time: 0.2014  last_time: 0.2249  data_time: 0.0024  last_data_time: 0.0022   lr: 0.00025  max_mem: 3224M
# [02/19 14:35:18 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in training: [ResizeShortestEdge(short_edge_length=(1024, 1024), max_size=1024)]
# [02/19 14:35:18 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [02/19 14:35:18 d2.data.common]: Serializing 10 elements to byte tensors and concatenating them all ...
# [02/19 14:35:18 d2.data.common]: Serialized dataset takes 2.11 MiB
# [02/19 14:35:19 detectron2]: VALIDATION_LOSS: 2.13994
# [02/19 14:35:20 d2.engine.hooks]: Saved best model as latest eval score for validation_loss is 2.13994, better than last best score 2.22397 @ iteration 419.
# [02/19 14:35:22 d2.utils.events]:  eta: 0:10:45  iter: 499  total_loss: 1.523  loss_cls_stage0: 0.1304  loss_box_reg_stage0: 0.1587  loss_cls_stage1: 0.0996  loss_box_reg_stage1: 0.3446  loss_cls_stage2: 0.1105  loss_box_reg_stage2: 0.4942  loss_mask: 0.127  loss_rpn_cls: 0.01243  loss_rpn_loc: 0.04597  validation_loss: 2.14  time: 0.2020  last_time: 0.1961  data_time: 0.0041  last_data_time: 0.0006   lr: 0.00025  max_mem: 3224M
# [02/19 14:35:26 d2.utils.events]:  eta: 0:10:41  iter: 519  total_loss: 1.554  loss_cls_stage0: 0.129  loss_box_reg_stage0: 0.1674  loss_cls_stage1: 0.1023  loss_box_reg_stage1: 0.3538  loss_cls_stage2: 0.1027  loss_box_reg_stage2: 0.5311  loss_mask: 0.1345  loss_rpn_cls: 0.01236  loss_rpn_loc: 0.06334  validation_loss: 2.14  time: 0.2020  last_time: 0.2167  data_time: 0.0032  last_data_time: 0.0046   lr: 0.00025  max_mem: 3224M
# [02/19 14:35:30 d2.utils.events]:  eta: 0:10:37  iter: 539  total_loss: 1.721  loss_cls_stage0: 0.1309  loss_box_reg_stage0: 0.1825  loss_cls_stage1: 0.1109  loss_box_reg_stage1: 0.379  loss_cls_stage2: 0.103  loss_box_reg_stage2: 0.5811  loss_mask: 0.1197  loss_rpn_cls: 0.01438  loss_rpn_loc: 0.05937  validation_loss: 2.14  time: 0.2019  last_time: 0.2186  data_time: 0.0029  last_data_time: 0.0005   lr: 0.00025  max_mem: 3224M
# [02/19 14:35:34 d2.utils.events]:  eta: 0:10:34  iter: 559  total_loss: 1.544  loss_cls_stage0: 0.122  loss_box_reg_stage0: 0.1919  loss_cls_stage1: 0.09831  loss_box_reg_stage1: 0.3736  loss_cls_stage2: 0.1073  loss_box_reg_stage2: 0.5234  loss_mask: 0.1315  loss_rpn_cls: 0.009581  loss_rpn_loc: 0.05072  validation_loss: 2.14  time: 0.2024  last_time: 0.2244  data_time: 0.0037  last_data_time: 0.0025   lr: 0.00025  max_mem: 3224M
# [02/19 14:35:35 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in training: [ResizeShortestEdge(short_edge_length=(1024, 1024), max_size=1024)]
# [02/19 14:35:35 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [02/19 14:35:35 d2.data.common]: Serializing 10 elements to byte tensors and concatenating them all ...
# [02/19 14:35:35 d2.data.common]: Serialized dataset takes 2.11 MiB
# [02/19 14:35:36 detectron2]: VALIDATION_LOSS: 2.16039
# [02/19 14:35:36 d2.engine.hooks]: Not saving as latest eval score for validation_loss is 2.16039, not better than best score 2.13994 @ iteration 489.
# [02/19 14:35:40 d2.utils.events]:  eta: 0:10:30  iter: 579  total_loss: 1.808  loss_cls_stage0: 0.1295  loss_box_reg_stage0: 0.1803  loss_cls_stage1: 0.1184  loss_box_reg_stage1: 0.4049  loss_cls_stage2: 0.1175  loss_box_reg_stage2: 0.5861  loss_mask: 0.128  loss_rpn_cls: 0.01015  loss_rpn_loc: 0.06131  validation_loss: 2.16  time: 0.2028  last_time: 0.2226  data_time: 0.0026  last_data_time: 0.0030   lr: 0.00025  max_mem: 3224M
# [02/19 14:35:44 d2.utils.events]:  eta: 0:10:25  iter: 599  total_loss: 1.692  loss_cls_stage0: 0.1212  loss_box_reg_stage0: 0.1732  loss_cls_stage1: 0.1096  loss_box_reg_stage1: 0.3555  loss_cls_stage2: 0.1115  loss_box_reg_stage2: 0.5683  loss_mask: 0.1317  loss_rpn_cls: 0.01313  loss_rpn_loc: 0.06215  validation_loss: 2.16  time: 0.2024  last_time: 0.2250  data_time: 0.0029  last_data_time: 0.0029   lr: 0.00025  max_mem: 3224M
# [02/19 14:35:48 d2.utils.events]:  eta: 0:10:21  iter: 619  total_loss: 1.742  loss_cls_stage0: 0.1197  loss_box_reg_stage0: 0.18  loss_cls_stage1: 0.09299  loss_box_reg_stage1: 0.4039  loss_cls_stage2: 0.1001  loss_box_reg_stage2: 0.5529  loss_mask: 0.1367  loss_rpn_cls: 0.01323  loss_rpn_loc: 0.07294  validation_loss: 2.16  time: 0.2027  last_time: 0.2231  data_time: 0.0039  last_data_time: 0.0007   lr: 0.00025  max_mem: 3224M
# [02/19 14:35:51 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in training: [ResizeShortestEdge(short_edge_length=(1024, 1024), max_size=1024)]
# [02/19 14:35:51 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [02/19 14:35:51 d2.data.common]: Serializing 10 elements to byte tensors and concatenating them all ...
# [02/19 14:35:51 d2.data.common]: Serialized dataset takes 2.11 MiB
# [02/19 14:35:52 detectron2]: VALIDATION_LOSS: 2.07050
# [02/19 14:35:53 d2.engine.hooks]: Saved best model as latest eval score for validation_loss is 2.07050, better than last best score 2.13994 @ iteration 489.
# [02/19 14:35:55 d2.utils.events]:  eta: 0:10:17  iter: 639  total_loss: 1.7  loss_cls_stage0: 0.1216  loss_box_reg_stage0: 0.1556  loss_cls_stage1: 0.1051  loss_box_reg_stage1: 0.3623  loss_cls_stage2: 0.1213  loss_box_reg_stage2: 0.5459  loss_mask: 0.1214  loss_rpn_cls: 0.01003  loss_rpn_loc: 0.05463  validation_loss: 2.07  time: 0.2028  last_time: 0.2174  data_time: 0.0032  last_data_time: 0.0006   lr: 0.00025  max_mem: 3224M
# [02/19 14:35:59 d2.utils.events]:  eta: 0:10:13  iter: 659  total_loss: 1.643  loss_cls_stage0: 0.1124  loss_box_reg_stage0: 0.1701  loss_cls_stage1: 0.09819  loss_box_reg_stage1: 0.3602  loss_cls_stage2: 0.1098  loss_box_reg_stage2: 0.5352  loss_mask: 0.1258  loss_rpn_cls: 0.01311  loss_rpn_loc: 0.06335  validation_loss: 2.07  time: 0.2032  last_time: 0.2895  data_time: 0.0066  last_data_time: 0.0665   lr: 0.00025  max_mem: 3224M
# [02/19 14:36:03 d2.utils.events]:  eta: 0:10:09  iter: 679  total_loss: 1.564  loss_cls_stage0: 0.1037  loss_box_reg_stage0: 0.1757  loss_cls_stage1: 0.08727  loss_box_reg_stage1: 0.3625  loss_cls_stage2: 0.0928  loss_box_reg_stage2: 0.5472  loss_mask: 0.1268  loss_rpn_cls: 0.01414  loss_rpn_loc: 0.06703  validation_loss: 2.07  time: 0.2032  last_time: 0.1517  data_time: 0.0033  last_data_time: 0.0006   lr: 0.00025  max_mem: 3224M
# [02/19 14:36:08 d2.utils.events]:  eta: 0:10:05  iter: 699  total_loss: 1.681  loss_cls_stage0: 0.1181  loss_box_reg_stage0: 0.1761  loss_cls_stage1: 0.1052  loss_box_reg_stage1: 0.3926  loss_cls_stage2: 0.1103  loss_box_reg_stage2: 0.5217  loss_mask: 0.1281  loss_rpn_cls: 0.0118  loss_rpn_loc: 0.06413  validation_loss: 2.07  time: 0.2036  last_time: 0.2246  data_time: 0.0029  last_data_time: 0.0007   lr: 0.00025  max_mem: 3224M
# [02/19 14:36:08 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in training: [ResizeShortestEdge(short_edge_length=(1024, 1024), max_size=1024)]
# [02/19 14:36:08 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [02/19 14:36:08 d2.data.common]: Serializing 10 elements to byte tensors and concatenating them all ...
# [02/19 14:36:08 d2.data.common]: Serialized dataset takes 2.11 MiB
# [02/19 14:36:10 detectron2]: VALIDATION_LOSS: 2.15410
# [02/19 14:36:10 d2.engine.hooks]: Not saving as latest eval score for validation_loss is 2.15410, not better than best score 2.07050 @ iteration 629.
# [02/19 14:36:13 d2.utils.events]:  eta: 0:10:00  iter: 719  total_loss: 1.677  loss_cls_stage0: 0.1178  loss_box_reg_stage0: 0.1721  loss_cls_stage1: 0.09166  loss_box_reg_stage1: 0.3416  loss_cls_stage2: 0.09372  loss_box_reg_stage2: 0.5205  loss_mask: 0.1339  loss_rpn_cls: 0.01153  loss_rpn_loc: 0.06484  validation_loss: 2.154  time: 0.2034  last_time: 0.2317  data_time: 0.0060  last_data_time: 0.0056   lr: 0.00025  max_mem: 3224M
# [02/19 14:36:18 d2.utils.events]:  eta: 0:09:56  iter: 739  total_loss: 1.339  loss_cls_stage0: 0.1056  loss_box_reg_stage0: 0.1607  loss_cls_stage1: 0.09428  loss_box_reg_stage1: 0.3221  loss_cls_stage2: 0.08606  loss_box_reg_stage2: 0.4489  loss_mask: 0.1105  loss_rpn_cls: 0.01104  loss_rpn_loc: 0.04663  validation_loss: 2.154  time: 0.2034  last_time: 0.2379  data_time: 0.0037  last_data_time: 0.0036   lr: 0.00025  max_mem: 3224M
# [02/19 14:36:22 d2.utils.events]:  eta: 0:09:52  iter: 759  total_loss: 1.659  loss_cls_stage0: 0.1113  loss_box_reg_stage0: 0.1638  loss_cls_stage1: 0.1065  loss_box_reg_stage1: 0.3482  loss_cls_stage2: 0.1217  loss_box_reg_stage2: 0.5022  loss_mask: 0.1218  loss_rpn_cls: 0.01078  loss_rpn_loc: 0.06119  validation_loss: 2.154  time: 0.2033  last_time: 0.2229  data_time: 0.0035  last_data_time: 0.0025   lr: 0.00025  max_mem: 3224M
# [02/19 14:36:24 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in training: [ResizeShortestEdge(short_edge_length=(1024, 1024), max_size=1024)]
# [02/19 14:36:24 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [02/19 14:36:24 d2.data.common]: Serializing 10 elements to byte tensors and concatenating them all ...
# [02/19 14:36:24 d2.data.common]: Serialized dataset takes 2.11 MiB
# [02/19 14:36:25 detectron2]: VALIDATION_LOSS: 1.99838
# [02/19 14:36:26 d2.engine.hooks]: Saved best model as latest eval score for validation_loss is 1.99838, better than last best score 2.07050 @ iteration 629.
# [02/19 14:36:28 d2.utils.events]:  eta: 0:09:47  iter: 779  total_loss: 1.962  loss_cls_stage0: 0.1184  loss_box_reg_stage0: 0.1913  loss_cls_stage1: 0.1006  loss_box_reg_stage1: 0.4499  loss_cls_stage2: 0.1032  loss_box_reg_stage2: 0.6733  loss_mask: 0.1351  loss_rpn_cls: 0.01676  loss_rpn_loc: 0.05818  validation_loss: 1.998  time: 0.2031  last_time: 0.2332  data_time: 0.0023  last_data_time: 0.0014   lr: 0.00025  max_mem: 3224M
# [02/19 14:36:32 d2.utils.events]:  eta: 0:09:43  iter: 799  total_loss: 1.468  loss_cls_stage0: 0.09993  loss_box_reg_stage0: 0.1708  loss_cls_stage1: 0.07247  loss_box_reg_stage1: 0.3607  loss_cls_stage2: 0.0763  loss_box_reg_stage2: 0.5144  loss_mask: 0.1185  loss_rpn_cls: 0.01344  loss_rpn_loc: 0.05504  validation_loss: 1.998  time: 0.2032  last_time: 0.2202  data_time: 0.0032  last_data_time: 0.0026   lr: 0.00025  max_mem: 3224M
# [02/19 14:36:36 d2.utils.events]:  eta: 0:09:40  iter: 819  total_loss: 1.603  loss_cls_stage0: 0.1069  loss_box_reg_stage0: 0.1811  loss_cls_stage1: 0.09651  loss_box_reg_stage1: 0.3503  loss_cls_stage2: 0.09413  loss_box_reg_stage2: 0.5503  loss_mask: 0.1352  loss_rpn_cls: 0.01113  loss_rpn_loc: 0.04896  validation_loss: 1.998  time: 0.2035  last_time: 0.2298  data_time: 0.0025  last_data_time: 0.0024   lr: 0.00025  max_mem: 3224M
# [02/19 14:36:41 d2.utils.events]:  eta: 0:09:36  iter: 839  total_loss: 1.508  loss_cls_stage0: 0.1095  loss_box_reg_stage0: 0.1619  loss_cls_stage1: 0.08101  loss_box_reg_stage1: 0.3401  loss_cls_stage2: 0.08209  loss_box_reg_stage2: 0.5115  loss_mask: 0.1145  loss_rpn_cls: 0.01152  loss_rpn_loc: 0.05321  validation_loss: 1.998  time: 0.2037  last_time: 0.2323  data_time: 0.0024  last_data_time: 0.0005   lr: 0.00025  max_mem: 3224M
# [02/19 14:36:41 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in training: [ResizeShortestEdge(short_edge_length=(1024, 1024), max_size=1024)]
# [02/19 14:36:41 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [02/19 14:36:41 d2.data.common]: Serializing 10 elements to byte tensors and concatenating them all ...
# [02/19 14:36:41 d2.data.common]: Serialized dataset takes 2.11 MiB
# [02/19 14:36:42 detectron2]: VALIDATION_LOSS: 2.05130
# [02/19 14:36:42 d2.engine.hooks]: Not saving as latest eval score for validation_loss is 2.05130, not better than best score 1.99838 @ iteration 769.
# [02/19 14:36:46 d2.utils.events]:  eta: 0:09:31  iter: 859  total_loss: 1.644  loss_cls_stage0: 0.1124  loss_box_reg_stage0: 0.1747  loss_cls_stage1: 0.08257  loss_box_reg_stage1: 0.3678  loss_cls_stage2: 0.07899  loss_box_reg_stage2: 0.5915  loss_mask: 0.1229  loss_rpn_cls: 0.01411  loss_rpn_loc: 0.08069  validation_loss: 2.051  time: 0.2033  last_time: 0.2223  data_time: 0.0030  last_data_time: 0.0017   lr: 0.00025  max_mem: 3224M
# [02/19 14:36:50 d2.utils.events]:  eta: 0:09:27  iter: 879  total_loss: 1.727  loss_cls_stage0: 0.1212  loss_box_reg_stage0: 0.1883  loss_cls_stage1: 0.1002  loss_box_reg_stage1: 0.3549  loss_cls_stage2: 0.09795  loss_box_reg_stage2: 0.5193  loss_mask: 0.1237  loss_rpn_cls: 0.009098  loss_rpn_loc: 0.07652  validation_loss: 2.051  time: 0.2035  last_time: 0.2194  data_time: 0.0030  last_data_time: 0.0027   lr: 0.00025  max_mem: 3224M
# [02/19 14:36:55 d2.utils.events]:  eta: 0:09:23  iter: 899  total_loss: 1.648  loss_cls_stage0: 0.1091  loss_box_reg_stage0: 0.1737  loss_cls_stage1: 0.08256  loss_box_reg_stage1: 0.3774  loss_cls_stage2: 0.08095  loss_box_reg_stage2: 0.5572  loss_mask: 0.1271  loss_rpn_cls: 0.006286  loss_rpn_loc: 0.06112  validation_loss: 2.051  time: 0.2038  last_time: 0.2192  data_time: 0.0066  last_data_time: 0.0005   lr: 0.00025  max_mem: 3224M
# [02/19 14:36:57 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in training: [ResizeShortestEdge(short_edge_length=(1024, 1024), max_size=1024)]
# [02/19 14:36:57 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [02/19 14:36:57 d2.data.common]: Serializing 10 elements to byte tensors and concatenating them all ...
# [02/19 14:36:57 d2.data.common]: Serialized dataset takes 2.11 MiB
# [02/19 14:36:59 detectron2]: VALIDATION_LOSS: 2.02194
# [02/19 14:36:59 d2.engine.hooks]: Not saving as latest eval score for validation_loss is 2.02194, not better than best score 1.99838 @ iteration 769.
# [02/19 14:37:01 d2.utils.events]:  eta: 0:09:19  iter: 919  total_loss: 1.47  loss_cls_stage0: 0.09675  loss_box_reg_stage0: 0.1604  loss_cls_stage1: 0.07174  loss_box_reg_stage1: 0.3416  loss_cls_stage2: 0.0715  loss_box_reg_stage2: 0.5292  loss_mask: 0.1213  loss_rpn_cls: 0.01217  loss_rpn_loc: 0.0544  validation_loss: 2.022  time: 0.2037  last_time: 0.2214  data_time: 0.0034  last_data_time: 0.0120   lr: 0.00025  max_mem: 3224M
# [02/19 14:37:05 d2.utils.events]:  eta: 0:09:15  iter: 939  total_loss: 1.402  loss_cls_stage0: 0.09719  loss_box_reg_stage0: 0.1529  loss_cls_stage1: 0.07695  loss_box_reg_stage1: 0.3095  loss_cls_stage2: 0.0756  loss_box_reg_stage2: 0.4579  loss_mask: 0.1122  loss_rpn_cls: 0.009097  loss_rpn_loc: 0.04494  validation_loss: 2.022  time: 0.2040  last_time: 0.2234  data_time: 0.0033  last_data_time: 0.0028   lr: 0.00025  max_mem: 3224M
# [02/19 14:37:09 d2.utils.events]:  eta: 0:09:11  iter: 959  total_loss: 1.468  loss_cls_stage0: 0.1114  loss_box_reg_stage0: 0.1627  loss_cls_stage1: 0.1003  loss_box_reg_stage1: 0.3267  loss_cls_stage2: 0.09658  loss_box_reg_stage2: 0.46  loss_mask: 0.1205  loss_rpn_cls: 0.009083  loss_rpn_loc: 0.05591  validation_loss: 2.022  time: 0.2040  last_time: 0.1696  data_time: 0.0033  last_data_time: 0.0031   lr: 0.00025  max_mem: 3224M
# [02/19 14:37:13 d2.utils.events]:  eta: 0:09:07  iter: 979  total_loss: 1.617  loss_cls_stage0: 0.1104  loss_box_reg_stage0: 0.1772  loss_cls_stage1: 0.09414  loss_box_reg_stage1: 0.3695  loss_cls_stage2: 0.1031  loss_box_reg_stage2: 0.5609  loss_mask: 0.1228  loss_rpn_cls: 0.01335  loss_rpn_loc: 0.07547  validation_loss: 2.022  time: 0.2042  last_time: 0.2250  data_time: 0.0027  last_data_time: 0.0035   lr: 0.00025  max_mem: 3224M
# [02/19 14:37:14 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in training: [ResizeShortestEdge(short_edge_length=(1024, 1024), max_size=1024)]
# [02/19 14:37:14 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [02/19 14:37:14 d2.data.common]: Serializing 10 elements to byte tensors and concatenating them all ...
# [02/19 14:37:14 d2.data.common]: Serialized dataset takes 2.11 MiB
# ...
# [02/19 14:45:06 d2.data.common]: Serialized dataset takes 2.11 MiB
# [02/19 14:45:07 detectron2]: VALIDATION_LOSS: 2.00211
# [02/19 14:45:07 d2.engine.hooks]: Not saving as latest eval score for validation_loss is 2.00211, not better than best score 1.87510 @ iteration 1609.
# [02/19 14:45:09 d2.utils.events]:  eta: 0:01:43  iter: 3019  total_loss: 1.304  loss_cls_stage0: 0.07479  loss_box_reg_stage0: 0.1448  loss_cls_stage1: 0.04889  loss_box_reg_stage1: 0.3032  loss_cls_stage2: 0.03711  loss_box_reg_stage2: 0.4387  loss_mask: 0.1076  loss_rpn_cls: 0.005655  loss_rpn_loc: 0.05181  validation_loss: 2.002  time: 0.2044  last_time: 0.2171  data_time: 0.0027  last_data_time: 0.0003   lr: 2.5e-06  max_mem: 3224M
# [02/19 14:45:13 d2.utils.events]:  eta: 0:01:39  iter: 3039  total_loss: 1.287  loss_cls_stage0: 0.06081  loss_box_reg_stage0: 0.1328  loss_cls_stage1: 0.05639  loss_box_reg_stage1: 0.3195  loss_cls_stage2: 0.04752  loss_box_reg_stage2: 0.4176  loss_mask: 0.1038  loss_rpn_cls: 0.007995  loss_rpn_loc: 0.04361  validation_loss: 2.002  time: 0.2043  last_time: 0.1604  data_time: 0.0057  last_data_time: 0.0006   lr: 2.5e-06  max_mem: 3224M
# [02/19 14:45:17 d2.utils.events]:  eta: 0:01:35  iter: 3059  total_loss: 1.319  loss_cls_stage0: 0.06737  loss_box_reg_stage0: 0.1473  loss_cls_stage1: 0.05057  loss_box_reg_stage1: 0.3462  loss_cls_stage2: 0.04589  loss_box_reg_stage2: 0.5395  loss_mask: 0.1054  loss_rpn_cls: 0.007166  loss_rpn_loc: 0.05028  validation_loss: 2.002  time: 0.2043  last_time: 0.2176  data_time: 0.0038  last_data_time: 0.0006   lr: 2.5e-06  max_mem: 3224M
# [02/19 14:45:21 d2.utils.events]:  eta: 0:01:30  iter: 3079  total_loss: 1.023  loss_cls_stage0: 0.06687  loss_box_reg_stage0: 0.1224  loss_cls_stage1: 0.06024  loss_box_reg_stage1: 0.2456  loss_cls_stage2: 0.0507  loss_box_reg_stage2: 0.3723  loss_mask: 0.08874  loss_rpn_cls: 0.006801  loss_rpn_loc: 0.0527  validation_loss: 2.002  time: 0.2043  last_time: 0.1677  data_time: 0.0065  last_data_time: 0.0017   lr: 2.5e-06  max_mem: 3224M
# [02/19 14:45:21 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in training: [ResizeShortestEdge(short_edge_length=(1024, 1024), max_size=1024)]
# [02/19 14:45:21 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [02/19 14:45:21 d2.data.common]: Serializing 10 elements to byte tensors and concatenating them all ...
# [02/19 14:45:22 d2.data.common]: Serialized dataset takes 2.11 MiB
# [02/19 14:45:23 detectron2]: VALIDATION_LOSS: 1.99940
# [02/19 14:45:23 d2.engine.hooks]: Not saving as latest eval score for validation_loss is 1.99940, not better than best score 1.87510 @ iteration 1609.
# [02/19 14:45:27 d2.utils.events]:  eta: 0:01:26  iter: 3099  total_loss: 1.345  loss_cls_stage0: 0.06899  loss_box_reg_stage0: 0.1461  loss_cls_stage1: 0.0541  loss_box_reg_stage1: 0.3123  loss_cls_stage2: 0.056  loss_box_reg_stage2: 0.4656  loss_mask: 0.1101  loss_rpn_cls: 0.005246  loss_rpn_loc: 0.05341  validation_loss: 1.999  time: 0.2042  last_time: 0.2061  data_time: 0.0039  last_data_time: 0.0020   lr: 2.5e-06  max_mem: 3224M
# [02/19 14:45:31 d2.utils.events]:  eta: 0:01:22  iter: 3119  total_loss: 1.068  loss_cls_stage0: 0.06141  loss_box_reg_stage0: 0.1244  loss_cls_stage1: 0.04773  loss_box_reg_stage1: 0.2541  loss_cls_stage2: 0.0442  loss_box_reg_stage2: 0.4062  loss_mask: 0.08857  loss_rpn_cls: 0.005751  loss_rpn_loc: 0.03788  validation_loss: 1.999  time: 0.2043  last_time: 0.2523  data_time: 0.0048  last_data_time: 0.0295   lr: 2.5e-06  max_mem: 3224M
# [02/19 14:45:35 d2.utils.events]:  eta: 0:01:17  iter: 3139  total_loss: 1.158  loss_cls_stage0: 0.06945  loss_box_reg_stage0: 0.1408  loss_cls_stage1: 0.0553  loss_box_reg_stage1: 0.2901  loss_cls_stage2: 0.05224  loss_box_reg_stage2: 0.4566  loss_mask: 0.09412  loss_rpn_cls: 0.002995  loss_rpn_loc: 0.04316  validation_loss: 1.999  time: 0.2043  last_time: 0.2153  data_time: 0.0026  last_data_time: 0.0030   lr: 2.5e-06  max_mem: 3224M
# [02/19 14:45:38 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in training: [ResizeShortestEdge(short_edge_length=(1024, 1024), max_size=1024)]
# [02/19 14:45:38 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [02/19 14:45:38 d2.data.common]: Serializing 10 elements to byte tensors and concatenating them all ...
# [02/19 14:45:38 d2.data.common]: Serialized dataset takes 2.11 MiB
# [02/19 14:45:39 detectron2]: VALIDATION_LOSS: 1.98662
# [02/19 14:45:39 d2.engine.hooks]: Not saving as latest eval score for validation_loss is 1.98662, not better than best score 1.87510 @ iteration 1609.
# [02/19 14:45:41 d2.utils.events]:  eta: 0:01:13  iter: 3159  total_loss: 1.123  loss_cls_stage0: 0.06898  loss_box_reg_stage0: 0.1311  loss_cls_stage1: 0.04716  loss_box_reg_stage1: 0.2716  loss_cls_stage2: 0.04073  loss_box_reg_stage2: 0.4015  loss_mask: 0.0953  loss_rpn_cls: 0.004297  loss_rpn_loc: 0.03986  validation_loss: 1.987  time: 0.2043  last_time: 0.1071  data_time: 0.0038  last_data_time: 0.0006   lr: 2.5e-06  max_mem: 3224M
# [02/19 14:45:45 d2.utils.events]:  eta: 0:01:09  iter: 3179  total_loss: 1.282  loss_cls_stage0: 0.06366  loss_box_reg_stage0: 0.1486  loss_cls_stage1: 0.04524  loss_box_reg_stage1: 0.311  loss_cls_stage2: 0.04595  loss_box_reg_stage2: 0.4955  loss_mask: 0.09847  loss_rpn_cls: 0.00393  loss_rpn_loc: 0.03779  validation_loss: 1.987  time: 0.2043  last_time: 0.1874  data_time: 0.0026  last_data_time: 0.0005   lr: 2.5e-06  max_mem: 3224M
# [02/19 14:45:49 d2.utils.events]:  eta: 0:01:04  iter: 3199  total_loss: 1.133  loss_cls_stage0: 0.05933  loss_box_reg_stage0: 0.1377  loss_cls_stage1: 0.03901  loss_box_reg_stage1: 0.2852  loss_cls_stage2: 0.03734  loss_box_reg_stage2: 0.428  loss_mask: 0.09277  loss_rpn_cls: 0.008268  loss_rpn_loc: 0.04751  validation_loss: 1.987  time: 0.2043  last_time: 0.2262  data_time: 0.0033  last_data_time: 0.0025   lr: 2.5e-06  max_mem: 3224M
# [02/19 14:45:54 d2.utils.events]:  eta: 0:01:00  iter: 3219  total_loss: 1.081  loss_cls_stage0: 0.06378  loss_box_reg_stage0: 0.1213  loss_cls_stage1: 0.05552  loss_box_reg_stage1: 0.2566  loss_cls_stage2: 0.04921  loss_box_reg_stage2: 0.3642  loss_mask: 0.09384  loss_rpn_cls: 0.004475  loss_rpn_loc: 0.03774  validation_loss: 1.987  time: 0.2043  last_time: 0.2325  data_time: 0.0034  last_data_time: 0.0016   lr: 2.5e-06  max_mem: 3224M
# [02/19 14:45:54 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in training: [ResizeShortestEdge(short_edge_length=(1024, 1024), max_size=1024)]
# [02/19 14:45:54 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [02/19 14:45:54 d2.data.common]: Serializing 10 elements to byte tensors and concatenating them all ...
# [02/19 14:45:54 d2.data.common]: Serialized dataset takes 2.11 MiB
# [02/19 14:45:55 detectron2]: VALIDATION_LOSS: 2.07532
# [02/19 14:45:55 d2.engine.hooks]: Not saving as latest eval score for validation_loss is 2.07532, not better than best score 1.87510 @ iteration 1609.
# [02/19 14:45:59 d2.utils.events]:  eta: 0:00:56  iter: 3239  total_loss: 1.325  loss_cls_stage0: 0.07209  loss_box_reg_stage0: 0.1629  loss_cls_stage1: 0.05711  loss_box_reg_stage1: 0.328  loss_cls_stage2: 0.05787  loss_box_reg_stage2: 0.4611  loss_mask: 0.1232  loss_rpn_cls: 0.005958  loss_rpn_loc: 0.06226  validation_loss: 2.075  time: 0.2043  last_time: 0.1245  data_time: 0.0053  last_data_time: 0.0024   lr: 2.5e-06  max_mem: 3224M
# [02/19 14:46:03 d2.utils.events]:  eta: 0:00:51  iter: 3259  total_loss: 1.415  loss_cls_stage0: 0.07833  loss_box_reg_stage0: 0.1474  loss_cls_stage1: 0.05697  loss_box_reg_stage1: 0.305  loss_cls_stage2: 0.04967  loss_box_reg_stage2: 0.4477  loss_mask: 0.1077  loss_rpn_cls: 0.00741  loss_rpn_loc: 0.05747  validation_loss: 2.075  time: 0.2042  last_time: 0.2120  data_time: 0.0029  last_data_time: 0.0026   lr: 2.5e-06  max_mem: 3224M
# [02/19 14:46:07 d2.utils.events]:  eta: 0:00:47  iter: 3279  total_loss: 1.143  loss_cls_stage0: 0.07578  loss_box_reg_stage0: 0.1224  loss_cls_stage1: 0.04851  loss_box_reg_stage1: 0.2595  loss_cls_stage2: 0.05027  loss_box_reg_stage2: 0.3515  loss_mask: 0.09517  loss_rpn_cls: 0.01111  loss_rpn_loc: 0.05157  validation_loss: 2.075  time: 0.2042  last_time: 0.2276  data_time: 0.0025  last_data_time: 0.0022   lr: 2.5e-06  max_mem: 3224M
# [02/19 14:46:10 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in training: [ResizeShortestEdge(short_edge_length=(1024, 1024), max_size=1024)]
# [02/19 14:46:10 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [02/19 14:46:10 d2.data.common]: Serializing 10 elements to byte tensors and concatenating them all ...
# [02/19 14:46:10 d2.data.common]: Serialized dataset takes 2.11 MiB
# [02/19 14:46:11 detectron2]: VALIDATION_LOSS: 2.02787
# [02/19 14:46:11 d2.engine.hooks]: Not saving as latest eval score for validation_loss is 2.02787, not better than best score 1.87510 @ iteration 1609.
# [02/19 14:46:13 d2.utils.events]:  eta: 0:00:43  iter: 3299  total_loss: 1.145  loss_cls_stage0: 0.06772  loss_box_reg_stage0: 0.1328  loss_cls_stage1: 0.03493  loss_box_reg_stage1: 0.2817  loss_cls_stage2: 0.03539  loss_box_reg_stage2: 0.4065  loss_mask: 0.108  loss_rpn_cls: 0.008982  loss_rpn_loc: 0.04243  validation_loss: 2.028  time: 0.2043  last_time: 0.2201  data_time: 0.0025  last_data_time: 0.0017   lr: 2.5e-06  max_mem: 3224M
# [02/19 14:46:17 d2.utils.events]:  eta: 0:00:38  iter: 3319  total_loss: 1.319  loss_cls_stage0: 0.06618  loss_box_reg_stage0: 0.1582  loss_cls_stage1: 0.04616  loss_box_reg_stage1: 0.2587  loss_cls_stage2: 0.0494  loss_box_reg_stage2: 0.4116  loss_mask: 0.1098  loss_rpn_cls: 0.01078  loss_rpn_loc: 0.06795  validation_loss: 2.028  time: 0.2042  last_time: 0.1873  data_time: 0.0032  last_data_time: 0.0031   lr: 2.5e-06  max_mem: 3224M
# [02/19 14:46:21 d2.utils.events]:  eta: 0:00:34  iter: 3339  total_loss: 1.321  loss_cls_stage0: 0.07112  loss_box_reg_stage0: 0.1481  loss_cls_stage1: 0.04326  loss_box_reg_stage1: 0.2984  loss_cls_stage2: 0.04724  loss_box_reg_stage2: 0.4067  loss_mask: 0.1078  loss_rpn_cls: 0.002212  loss_rpn_loc: 0.04328  validation_loss: 2.028  time: 0.2042  last_time: 0.2099  data_time: 0.0058  last_data_time: 0.0041   lr: 2.5e-06  max_mem: 3224M
# [02/19 14:46:25 d2.utils.events]:  eta: 0:00:30  iter: 3359  total_loss: 1.05  loss_cls_stage0: 0.07178  loss_box_reg_stage0: 0.1281  loss_cls_stage1: 0.05331  loss_box_reg_stage1: 0.2577  loss_cls_stage2: 0.04721  loss_box_reg_stage2: 0.3871  loss_mask: 0.09429  loss_rpn_cls: 0.006078  loss_rpn_loc: 0.04277  validation_loss: 2.028  time: 0.2042  last_time: 0.2233  data_time: 0.0033  last_data_time: 0.0002   lr: 2.5e-06  max_mem: 3224M
# [02/19 14:46:26 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in training: [ResizeShortestEdge(short_edge_length=(1024, 1024), max_size=1024)]
# [02/19 14:46:26 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [02/19 14:46:26 d2.data.common]: Serializing 10 elements to byte tensors and concatenating them all ...
# [02/19 14:46:26 d2.data.common]: Serialized dataset takes 2.11 MiB
# [02/19 14:46:27 detectron2]: VALIDATION_LOSS: 1.99604
# [02/19 14:46:27 d2.engine.hooks]: Not saving as latest eval score for validation_loss is 1.99604, not better than best score 1.87510 @ iteration 1609.
# [02/19 14:46:31 d2.utils.events]:  eta: 0:00:25  iter: 3379  total_loss: 1.327  loss_cls_stage0: 0.06882  loss_box_reg_stage0: 0.1391  loss_cls_stage1: 0.0486  loss_box_reg_stage1: 0.2985  loss_cls_stage2: 0.0468  loss_box_reg_stage2: 0.4436  loss_mask: 0.1084  loss_rpn_cls: 0.00651  loss_rpn_loc: 0.04714  validation_loss: 1.996  time: 0.2042  last_time: 0.1543  data_time: 0.0027  last_data_time: 0.0034   lr: 2.5e-06  max_mem: 3224M
# [02/19 14:46:35 d2.utils.events]:  eta: 0:00:21  iter: 3399  total_loss: 1.279  loss_cls_stage0: 0.0671  loss_box_reg_stage0: 0.1359  loss_cls_stage1: 0.04199  loss_box_reg_stage1: 0.2814  loss_cls_stage2: 0.04166  loss_box_reg_stage2: 0.4535  loss_mask: 0.1136  loss_rpn_cls: 0.005769  loss_rpn_loc: 0.04781  validation_loss: 1.996  time: 0.2041  last_time: 0.2135  data_time: 0.0048  last_data_time: 0.0028   lr: 2.5e-06  max_mem: 3224M
# [02/19 14:46:39 d2.utils.events]:  eta: 0:00:17  iter: 3419  total_loss: 1.098  loss_cls_stage0: 0.07848  loss_box_reg_stage0: 0.128  loss_cls_stage1: 0.05077  loss_box_reg_stage1: 0.2579  loss_cls_stage2: 0.04507  loss_box_reg_stage2: 0.3752  loss_mask: 0.09719  loss_rpn_cls: 0.006195  loss_rpn_loc: 0.05159  validation_loss: 1.996  time: 0.2040  last_time: 0.2224  data_time: 0.0028  last_data_time: 0.0027   lr: 2.5e-06  max_mem: 3224M
# [02/19 14:46:41 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in training: [ResizeShortestEdge(short_edge_length=(1024, 1024), max_size=1024)]
# [02/19 14:46:41 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [02/19 14:46:41 d2.data.common]: Serializing 10 elements to byte tensors and concatenating them all ...
# [02/19 14:46:42 d2.data.common]: Serialized dataset takes 2.11 MiB
# [02/19 14:46:43 detectron2]: VALIDATION_LOSS: 2.00501
# [02/19 14:46:43 d2.engine.hooks]: Not saving as latest eval score for validation_loss is 2.00501, not better than best score 1.87510 @ iteration 1609.
# [02/19 14:46:45 d2.utils.events]:  eta: 0:00:12  iter: 3439  total_loss: 1.302  loss_cls_stage0: 0.06795  loss_box_reg_stage0: 0.1439  loss_cls_stage1: 0.05309  loss_box_reg_stage1: 0.3433  loss_cls_stage2: 0.04844  loss_box_reg_stage2: 0.4815  loss_mask: 0.1043  loss_rpn_cls: 0.006044  loss_rpn_loc: 0.03472  validation_loss: 2.005  time: 0.2040  last_time: 0.2165  data_time: 0.0050  last_data_time: 0.0020   lr: 2.5e-06  max_mem: 3224M
# [02/19 14:46:49 d2.utils.events]:  eta: 0:00:08  iter: 3459  total_loss: 1.168  loss_cls_stage0: 0.06842  loss_box_reg_stage0: 0.13  loss_cls_stage1: 0.05747  loss_box_reg_stage1: 0.2766  loss_cls_stage2: 0.06173  loss_box_reg_stage2: 0.4032  loss_mask: 0.1001  loss_rpn_cls: 0.01034  loss_rpn_loc: 0.05494  validation_loss: 2.005  time: 0.2040  last_time: 0.2207  data_time: 0.0034  last_data_time: 0.0032   lr: 2.5e-06  max_mem: 3224M
# [02/19 14:46:53 d2.utils.events]:  eta: 0:00:04  iter: 3479  total_loss: 1.297  loss_cls_stage0: 0.07478  loss_box_reg_stage0: 0.1652  loss_cls_stage1: 0.05004  loss_box_reg_stage1: 0.3105  loss_cls_stage2: 0.05534  loss_box_reg_stage2: 0.4485  loss_mask: 0.1266  loss_rpn_cls: 0.007789  loss_rpn_loc: 0.04961  validation_loss: 2.005  time: 0.2040  last_time: 0.2200  data_time: 0.0023  last_data_time: 0.0023   lr: 2.5e-06  max_mem: 3224M
# [02/19 14:46:57 d2.utils.events]:  eta: 0:00:00  iter: 3499  total_loss: 1.18  loss_cls_stage0: 0.07605  loss_box_reg_stage0: 0.1405  loss_cls_stage1: 0.04522  loss_box_reg_stage1: 0.2916  loss_cls_stage2: 0.0493  loss_box_reg_stage2: 0.4421  loss_mask: 0.1034  loss_rpn_cls: 0.006537  loss_rpn_loc: 0.04832  validation_loss: 2.005  time: 0.2040  last_time: 0.2237  data_time: 0.0025  last_data_time: 0.0017   lr: 2.5e-06  max_mem: 3224M
# [02/19 14:46:57 d2.engine.hooks]: Overall training speed: 3498 iterations in 0:11:53 (0.2040 s / it)
# [02/19 14:46:57 d2.engine.hooks]: Total training time: 0:13:32 (0:01:39 on hooks)
# [02/19 14:46:57 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in training: [ResizeShortestEdge(short_edge_length=(1024, 1024), max_size=1024)]
# [02/19 14:46:57 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [02/19 14:46:57 d2.data.common]: Serializing 10 elements to byte tensors and concatenating them all ...
# [02/19 14:46:58 d2.data.common]: Serialized dataset takes 2.11 MiB
# [02/19 14:46:59 detectron2]: VALIDATION_LOSS: 2.04927
# [02/19 14:46:59 d2.engine.hooks]: Not saving as latest eval score for validation_loss is 2.04927, not better than best score 1.87510 @ iteration 1609.

# %% [markdown]
# ### Plot Training and Validation Curves

# %%
def load_json_arr(json_path):
    train, val = [], []
    with open(json_path, 'r') as f:
        for line in f:
            l = json.loads(line)
            if "validation_loss" in l:
                val.append(l)
            elif "total_loss" in l:
                train.append(l)
    return train, val

# %%
train_metrics, val_metrics = load_json_arr(os.path.join(cfg.OUTPUT_DIR, "metrics.json"))
train_metrics = train_metrics[2:]

# %%
train_iters = [x["iteration"] for x in train_metrics]
train_loss = [x["total_loss"] for x in train_metrics]

val_iters = [x["iteration"] for x in val_metrics]
val_loss = [x["validation_loss"] for x in val_metrics]

min_val_loss_idx = np.argmin(val_loss)
print(f"min val loss of {val_loss[min_val_loss_idx]:.2f} at iteration {val_iters[min_val_loss_idx]}")
# Out:
# min val loss of 1.88 at iteration 1609

# %%
plt.plot(train_iters, train_loss)
plt.plot(val_iters, val_loss)
plt.xlabel("iters")
plt.ylabel("loss")
plt.title("train/val loss")
plt.legend(["training loss", "validation loss"], loc="upper right")
plt.show()

# %% [markdown]
# ### Evalatuate Model on Held Out Testset
#
# Using Default Predictor with Threshold of 0.7

# %%
cfg.MODEL.WEIGHTS = os.path.join(cfg.OUTPUT_DIR, "model_best.pth")
cfg.MODEL.ROI_HEADS.SCORE_THRESH_TEST = 0.7
predictor = DefaultPredictor(cfg)
# Out:
# [02/19 14:47:00 d2.checkpoint.detection_checkpoint]: [DetectionCheckpointer] Loading from ./output/model_best.pth ...

# %%
evaluator = COCOEvaluator(dataset_name="test", output_dir=os.path.join(cfg.OUTPUT_DIR, "inference"), allow_cached_coco=False, use_fast_impl=False)
testloader = build_detection_test_loader(cfg, "test")
print(inference_on_dataset(predictor.model, testloader, evaluator))
# Out:
# [02/19 14:47:00 d2.evaluation.coco_evaluation]: Trying to convert 'test' to COCO format ...
# [02/19 14:47:00 d2.data.datasets.coco]: Converting annotations of dataset 'test' to COCO format ...)
# [02/19 14:47:00 d2.data.datasets.coco]: Converting dataset dicts into COCO format
# [02/19 14:47:00 d2.data.datasets.coco]: Conversion finished, #images: 20, #annotations: 788
# [02/19 14:47:00 d2.data.datasets.coco]: Caching COCO format annotations at './output/inference/test_coco_format.json' ...
# [02/19 14:47:01 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in inference: [ResizeShortestEdge(short_edge_length=(800, 800), max_size=1333, sample_style='choice')]
# [02/19 14:47:01 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [02/19 14:47:01 d2.data.common]: Serializing 20 elements to byte tensors and concatenating them all ...
# [02/19 14:47:01 d2.data.common]: Serialized dataset takes 3.57 MiB
# [02/19 14:47:01 d2.evaluation.evaluator]: Start inference on 20 batches
# [02/19 14:47:04 d2.evaluation.evaluator]: Inference done 11/20. Dataloading: 0.0005 s/iter. Inference: 0.0387 s/iter. Eval: 0.0309 s/iter. Total: 0.0701 s/iter. ETA=0:00:00
# [02/19 14:47:06 d2.evaluation.evaluator]: Total inference time: 0:00:03.128002 (0.208533 s / iter per device, on 1 devices)
# [02/19 14:47:06 d2.evaluation.evaluator]: Total inference pure compute time: 0:00:00 (0.042150 s / iter per device, on 1 devices)
# [02/19 14:47:06 d2.evaluation.coco_evaluation]: Preparing results for COCO format ...
# [02/19 14:47:06 d2.evaluation.coco_evaluation]: Saving results to ./output/inference/coco_instances_results.json
# [02/19 14:47:06 d2.evaluation.coco_evaluation]: Evaluating predictions with official COCO API...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.16s).
# Accumulating evaluation results...
# DONE (t=0.01s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.768
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.923
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.890
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.814
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.762
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.794
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.045
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.419
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.820
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.845
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.809
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.841
# [02/19 14:47:07 d2.evaluation.coco_evaluation]: Evaluation results for bbox:
# |   AP   |  AP50  |  AP75  |  APs   |  APm   |  APl   |
# |:------:|:------:|:------:|:------:|:------:|:------:|
# | 76.835 | 92.304 | 88.976 | 81.372 | 76.205 | 79.429 |
# [02/19 14:47:07 d2.evaluation.coco_evaluation]: Per-category bbox AP:
# | category   | AP     | category   | AP     |
# |:-----------|:-------|:-----------|:-------|
# | label      | 76.088 | button     | 77.582 |
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *segm*
# DONE (t=0.18s).
# Accumulating evaluation results...
# DONE (t=0.01s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.753
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.923
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.892
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.726
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.750
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.790
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.044
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.412
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.805
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.783
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.794
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.834
# [02/19 14:47:07 d2.evaluation.coco_evaluation]: Evaluation results for segm:
# |   AP   |  AP50  |  AP75  |  APs   |  APm   |  APl   |
# |:------:|:------:|:------:|:------:|:------:|:------:|
# | 75.253 | 92.317 | 89.203 | 72.609 | 74.980 | 79.013 |
# [02/19 14:47:07 d2.evaluation.coco_evaluation]: Per-category segm AP:
# | category   | AP     | category   | AP     |
# |:-----------|:-------|:-----------|:-------|
# | label      | 75.095 | button     | 75.412 |
# OrderedDict([('bbox', {'AP': 76.83529573714797, 'AP50': 92.30437227914375, 'AP75': 88.9764752603308, 'APs': 81.3716754028344, 'APm': 76.20528135776702, 'APl': 79.42945581650224, 'AP-label': 76.08815312617014, 'AP-button': 77.58243834812582}), ('segm', {'AP': 75.25341597230239, 'AP50': 92.31659975398794, 'AP75': 89.20342095226978, 'APs': 72.6091426071808, 'APm': 74.98039896875395, 'APl': 79.01312342220236, 'AP-label': 75.09464417690258, 'AP-button': 75.41218776770219})])

# %% [markdown]
# ### View Output of Model on Test Images

# %%
testset = get_detection_dataset_dicts("test", filter_empty=False)
for d in random.sample(testset, 5):
    img = cv2.imread(d["file_name"])
    outputs = predictor(img)
    v = Visualizer(img[:, :, ::-1], metadata=MetadataCatalog.get("test"), scale=1.0, instance_mode=ColorMode.SEGMENTATION)
    out = v.draw_instance_predictions(outputs["instances"].to("cpu"))
    plt.imshow(out.get_image())
    plt.axis("off")
    plt.show()
